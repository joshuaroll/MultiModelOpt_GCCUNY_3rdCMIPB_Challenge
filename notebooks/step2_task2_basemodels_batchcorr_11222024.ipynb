# %%
import numpy as np
import pandas as pd
from pycaret.regression import *
from scipy.stats import spearmanr

# Load data
df = pd.read_csv("/home/vmottaqi/cmipb_challenge/vincent_files/training_cellfreq_barchcorr_processed_oct29.csv", index_col=0)

# %%
df.columns
# Out:
# Index(['day_0_specimen_id', 'subject_id', 'specimen_type', 'infancy_vac',
#        'biological_sex', 'ethnicity', 'race', 'dataset', 'age',
#        'day_0_Monocytes', 'day_0_Classical_Monocytes',
#        'day_0_Non-Classical_Monocytes', 'day_0_Intermediate_Monocytes',
#        'day_0_Bcells', 'day_0_CD3CD19neg', 'day_0_CD3 Tcells',
#        'day_0_CD4Tcells', 'day_0_CD8Tcells', 'day_0_TemraCD4',
#        'day_0_NaiveCD4', 'day_0_TemCD4', 'day_0_TcmCD4', 'day_0_TemraCD8',
#        'day_0_NaiveCD8', 'day_0_TemCD8', 'day_0_TcmCD8', 'day_0_NK',
#        'day_0_Basophils', 'day_0_pDC', 'day_0_B cells (CD19+CD3-CD14-CD56-)',
#        'day_0_B cells (CD19+CD20+CD3-CD14-CD56-)', 'day_0_Memory B cells',
#        'day_0_Naive B cells', 'day_0_Proliferating B cells',
#        'day_0_Activated B cells (ABCs)', 'day_0_CD56+CD3+T cells',
#        'day_0_CD4+CD8+ T cells', 'day_0_CD4-CD8- T cells',
#        'day_0_NK cells (CD3-CD19-CD56+)', 'day_0_CD3-CD19-CD56- cells',
#        'day_0_non-pDCs',
#        'day_0_CD3-CD19-CD56-CD14-CD16-CD123-CD11c-HLA-DR+cells',
#        'day_0_Conventional dendritic cells (cDCs)', 'day_0_cDC1', 'day_0_cDC2',
#        'day_0_Activated granulocytes',
#        'day_0_Lineage negative cells (CD3-CD19-CD56-HLA-DR-CD123-CD66b-)',
#        'day_0_CD56high NK cells', 'day_1_specimen_id', 'day_1_Monocytes',
#        'FC_day_0_1_Monocytes'],
#       dtype='object')

# %%
X = df.drop(columns=['day_1_specimen_id', 'day_1_Monocytes', 'FC_day_0_1_Monocytes'])
y = df['day_1_Monocytes']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 0 to 73
# Data columns (total 48 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   day_0_specimen_id                                                 74 non-null     int64
#  1   subject_id                                                        74 non-null     int64
#  2   specimen_type                                                     74 non-null     object
#  3   infancy_vac                                                       74 non-null     object
#  4   biological_sex                                                    74 non-null     object
#  5   ethnicity                                                         74 non-null     object
#  6   race                                                              74 non-null     object
#  7   dataset                                                           74 non-null     object
#  8   age                                                               74 non-null     int64
#  9   day_0_Monocytes                                                   74 non-null     float64
#  10  day_0_Classical_Monocytes                                         74 non-null     float64
#  11  day_0_Non-Classical_Monocytes                                     74 non-null     float64
#  12  day_0_Intermediate_Monocytes                                      74 non-null     float64
#  13  day_0_Bcells                                                      74 non-null     float64
#  14  day_0_CD3CD19neg                                                  74 non-null     float64
#  15  day_0_CD3 Tcells                                                  74 non-null     float64
#  16  day_0_CD4Tcells                                                   74 non-null     float64
#  17  day_0_CD8Tcells                                                   74 non-null     float64
#  18  day_0_TemraCD4                                                    74 non-null     float64
#  19  day_0_NaiveCD4                                                    74 non-null     float64
#  20  day_0_TemCD4                                                      74 non-null     float64
#  21  day_0_TcmCD4                                                      74 non-null     float64
#  22  day_0_TemraCD8                                                    74 non-null     float64
#  23  day_0_NaiveCD8                                                    74 non-null     float64
#  24  day_0_TemCD8                                                      74 non-null     float64
#  25  day_0_TcmCD8                                                      74 non-null     float64
#  26  day_0_NK                                                          74 non-null     float64
#  27  day_0_Basophils                                                   74 non-null     float64
#  28  day_0_pDC                                                         74 non-null     float64
#  29  day_0_B cells (CD19+CD3-CD14-CD56-)                               74 non-null     float64
#  30  day_0_B cells (CD19+CD20+CD3-CD14-CD56-)                          74 non-null     float64
#  31  day_0_Memory B cells                                              74 non-null     float64
#  32  day_0_Naive B cells                                               74 non-null     float64
#  33  day_0_Proliferating B cells                                       74 non-null     float64
#  34  day_0_Activated B cells (ABCs)                                    74 non-null     float64
#  35  day_0_CD56+CD3+T cells                                            74 non-null     float64
#  36  day_0_CD4+CD8+ T cells                                            74 non-null     float64
#  37  day_0_CD4-CD8- T cells                                            74 non-null     float64
#  38  day_0_NK cells (CD3-CD19-CD56+)                                   74 non-null     float64
#  39  day_0_CD3-CD19-CD56- cells                                        74 non-null     float64
#  40  day_0_non-pDCs                                                    74 non-null     float64
#  41  day_0_CD3-CD19-CD56-CD14-CD16-CD123-CD11c-HLA-DR+cells            74 non-null     float64
#  42  day_0_Conventional dendritic cells (cDCs)                         74 non-null     float64
#  43  day_0_cDC1                                                        74 non-null     float64
#  44  day_0_cDC2                                                        74 non-null     float64
#  45  day_0_Activated granulocytes                                      74 non-null     float64
#  46  day_0_Lineage negative cells (CD3-CD19-CD56-HLA-DR-CD123-CD66b-)  74 non-null     float64
#  47  day_0_CD56high NK cells                                           74 non-null     float64
# dtypes: float64(39), int64(3), object(6)
# memory usage: 28.3+ KB

# %%
cat_feat = ['specimen_type', 'infancy_vac', 'biological_sex', 'ethnicity', 'race', 'dataset']

# %%
# Define features and target
# Combine features and target for PyCaret input
data = X.copy()
target = 'day_1_Monocytes'
data[target] = y

# Initialize PyCaret with the dataset and target column
regression_setup = setup(
    data=data,
    target=target,
    categorical_features=cat_feat,  # Specify any categorical features
    session_id=1,
    fold=5
)

# Custom Spearman correlation function
def spearman_metric(y_true, y_pred):
    return spearmanr(y_true, y_pred)[0]  # Return the Spearman correlation coefficient

# Adding the custom Spearman metric
add_metric(
    'Spearman', 
    'Spearman Correlation', 
    spearman_metric, 
    greater_is_better=True
)

# Compare models using a supported metric (e.g., R2)
top_models = compare_models(sort='R2', n_select=15)  # Select top models based on R2, adjust as needed

# Calculate Spearman correlation for each top model
spearman_results = []
for model in top_models:
    predictions = predict_model(model)  # Get predictions
    
    # Identify the correct prediction column
    prediction_column = 'Label' if 'Label' in predictions.columns else predictions.columns[-1]
    
    # Calculate Spearman correlation
    spearman_corr = spearman_metric(predictions[target], predictions[prediction_column])
    spearman_results.append((model, spearman_corr))

# Sort and display models by Spearman correlation
sorted_spearman_results = sorted(spearman_results, key=lambda x: x[1], reverse=True)
for model, spearman_corr in sorted_spearman_results:
    print(f"Model: {model}, Spearman Correlation: {spearman_corr}")
# Out:
# <style type="text/css">
# #T_871a1_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_871a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_871a1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_871a1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_871a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_871a1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_871a1_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_871a1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_871a1_row1_col1" class="data row1 col1" >day_1_Monocytes</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_871a1_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_871a1_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_871a1_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_871a1_row3_col1" class="data row3 col1" >(74, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_871a1_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_871a1_row4_col1" class="data row4 col1" >(74, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_871a1_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_871a1_row5_col1" class="data row5 col1" >(51, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_871a1_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_871a1_row6_col1" class="data row6 col1" >(23, 55)</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_871a1_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_871a1_row7_col1" class="data row7 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_871a1_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_871a1_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_871a1_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_871a1_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_871a1_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_871a1_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_871a1_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_871a1_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_871a1_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_871a1_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_871a1_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_871a1_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_871a1_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_871a1_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_871a1_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_871a1_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_871a1_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_871a1_row16_col1" class="data row16 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_871a1_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_871a1_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_871a1_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_871a1_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_871a1_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_871a1_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_871a1_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_871a1_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_871a1_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_871a1_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_871a1_row21_col1" class="data row21 col1" >5a0f</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_483b3 th {
#   text-align: left;
# }
# #T_483b3_row0_col0, #T_483b3_row0_col1, #T_483b3_row0_col2, #T_483b3_row1_col0, #T_483b3_row1_col3, #T_483b3_row1_col4, #T_483b3_row1_col5, #T_483b3_row1_col6, #T_483b3_row2_col0, #T_483b3_row2_col1, #T_483b3_row2_col2, #T_483b3_row2_col3, #T_483b3_row2_col4, #T_483b3_row2_col5, #T_483b3_row2_col6, #T_483b3_row3_col0, #T_483b3_row3_col1, #T_483b3_row3_col2, #T_483b3_row3_col3, #T_483b3_row3_col4, #T_483b3_row3_col5, #T_483b3_row3_col6, #T_483b3_row4_col0, #T_483b3_row4_col1, #T_483b3_row4_col2, #T_483b3_row4_col3, #T_483b3_row4_col4, #T_483b3_row4_col5, #T_483b3_row4_col6, #T_483b3_row5_col0, #T_483b3_row5_col1, #T_483b3_row5_col2, #T_483b3_row5_col3, #T_483b3_row5_col4, #T_483b3_row5_col5, #T_483b3_row5_col6, #T_483b3_row6_col0, #T_483b3_row6_col1, #T_483b3_row6_col2, #T_483b3_row6_col3, #T_483b3_row6_col4, #T_483b3_row6_col5, #T_483b3_row6_col6, #T_483b3_row7_col0, #T_483b3_row7_col1, #T_483b3_row7_col2, #T_483b3_row7_col3, #T_483b3_row7_col4, #T_483b3_row7_col5, #T_483b3_row7_col6, #T_483b3_row8_col0, #T_483b3_row8_col1, #T_483b3_row8_col2, #T_483b3_row8_col3, #T_483b3_row8_col4, #T_483b3_row8_col5, #T_483b3_row8_col6, #T_483b3_row9_col0, #T_483b3_row9_col1, #T_483b3_row9_col2, #T_483b3_row9_col3, #T_483b3_row9_col4, #T_483b3_row9_col5, #T_483b3_row9_col6, #T_483b3_row10_col0, #T_483b3_row10_col1, #T_483b3_row10_col2, #T_483b3_row10_col3, #T_483b3_row10_col4, #T_483b3_row10_col5, #T_483b3_row10_col6, #T_483b3_row11_col0, #T_483b3_row11_col1, #T_483b3_row11_col2, #T_483b3_row11_col3, #T_483b3_row11_col4, #T_483b3_row11_col5, #T_483b3_row11_col6, #T_483b3_row12_col0, #T_483b3_row12_col1, #T_483b3_row12_col2, #T_483b3_row12_col3, #T_483b3_row12_col4, #T_483b3_row12_col5, #T_483b3_row12_col6, #T_483b3_row13_col0, #T_483b3_row13_col1, #T_483b3_row13_col2, #T_483b3_row13_col3, #T_483b3_row13_col4, #T_483b3_row13_col5, #T_483b3_row13_col6, #T_483b3_row14_col0, #T_483b3_row14_col1, #T_483b3_row14_col2, #T_483b3_row14_col3, #T_483b3_row14_col4, #T_483b3_row14_col5, #T_483b3_row14_col6, #T_483b3_row15_col0, #T_483b3_row15_col1, #T_483b3_row15_col2, #T_483b3_row15_col3, #T_483b3_row15_col4, #T_483b3_row15_col5, #T_483b3_row15_col6, #T_483b3_row16_col0, #T_483b3_row16_col1, #T_483b3_row16_col2, #T_483b3_row16_col3, #T_483b3_row16_col4, #T_483b3_row16_col5, #T_483b3_row16_col6, #T_483b3_row17_col0, #T_483b3_row17_col1, #T_483b3_row17_col2, #T_483b3_row17_col3, #T_483b3_row17_col4, #T_483b3_row17_col5, #T_483b3_row17_col6 {
#   text-align: left;
# }
# #T_483b3_row0_col3, #T_483b3_row0_col4, #T_483b3_row0_col5, #T_483b3_row0_col6, #T_483b3_row0_col7, #T_483b3_row1_col1, #T_483b3_row1_col2, #T_483b3_row1_col7, #T_483b3_row2_col7, #T_483b3_row3_col7, #T_483b3_row4_col7, #T_483b3_row5_col7, #T_483b3_row6_col7, #T_483b3_row7_col7, #T_483b3_row8_col7, #T_483b3_row9_col7, #T_483b3_row10_col7, #T_483b3_row11_col7, #T_483b3_row12_col7, #T_483b3_row13_col7, #T_483b3_row14_col7, #T_483b3_row15_col7, #T_483b3_row16_col7, #T_483b3_row17_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_483b3_row0_col8, #T_483b3_row1_col8, #T_483b3_row2_col8, #T_483b3_row3_col8, #T_483b3_row4_col8, #T_483b3_row5_col8, #T_483b3_row6_col8, #T_483b3_row7_col8, #T_483b3_row9_col8, #T_483b3_row12_col8, #T_483b3_row13_col8, #T_483b3_row14_col8, #T_483b3_row15_col8, #T_483b3_row16_col8, #T_483b3_row17_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_483b3_row8_col8, #T_483b3_row10_col8, #T_483b3_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_483b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_483b3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_483b3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_483b3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_483b3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_483b3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_483b3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_483b3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_483b3_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#       <th id="T_483b3_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_483b3_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_483b3_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_483b3_row0_col1" class="data row0 col1" >0.3000</td>
#       <td id="T_483b3_row0_col2" class="data row0 col2" >0.1514</td>
#       <td id="T_483b3_row0_col3" class="data row0 col3" >0.3630</td>
#       <td id="T_483b3_row0_col4" class="data row0 col4" >0.1212</td>
#       <td id="T_483b3_row0_col5" class="data row0 col5" >0.1656</td>
#       <td id="T_483b3_row0_col6" class="data row0 col6" >0.2954</td>
#       <td id="T_483b3_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_483b3_row0_col8" class="data row0 col8" >0.2400</td>
#     </tr>
#     <tr>
#       <th id="T_483b3_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_483b3_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_483b3_row1_col1" class="data row1 col1" >0.2972</td>
#       <td id="T_483b3_row1_col2" class="data row1 col2" >0.1499</td>
#       <td id="T_483b3_row1_col3" class="data row1 col3" >0.3632</td>
#       <td id="T_483b3_row1_col4" class="data row1 col4" >0.0773</td>
#       <td id="T_483b3_row1_col5" class="data row1 col5" >0.1678</td>
#       <td id="T_483b3_row1_col6" class="data row1 col6" >0.3022</td>
#       <td id="T_483b3_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_483b3_row1_col8" class="data row1 col8" >0.2420</td>
#     </tr>
#     <tr>
#       <th id="T_483b3_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_483b3_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_483b3_row2_col1" class="data row2 col1" >0.3052</td>
#       <td id="T_483b3_row2_col2" class="data row2 col2" >0.1689</td>
#       <td id="T_483b3_row2_col3" class="data row2 col3" >0.3830</td>
#       <td id="T_483b3_row2_col4" class="data row2 col4" >0.0498</td>
#       <td id="T_483b3_row2_col5" class="data row2 col5" >0.1748</td>
#       <td id="T_483b3_row2_col6" class="data row2 col6" >0.3069</td>
#       <td id="T_483b3_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_483b3_row2_col8" class="data row2 col8" >0.2300</td>
#     </tr>
#     <tr>
#       <th id="T_483b3_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_483b3_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_483b3_row3_col1" class="data row3 col1" >0.3028</td>
#       <td id="T_483b3_row3_col2" class="data row3 col2" >0.1652</td>
#       <td id="T_483b3_row3_col3" class="data row3 col3" >0.3831</td>
#       <td id="T_483b3_row3_col4" class="data row3 col4" >-0.0236</td>
#       <td id="T_483b3_row3_col5" class="data row3 col5" >0.1716</td>
#       <td id="T_483b3_row3_col6" class="data row3 col6" >0.2979</td>
#       <td id="T_483b3_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_483b3_row3_col8" class="data row3 col8" >0.5260</td>
#     </tr>
#     <tr>
#       <th id="T_483b3_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_483b3_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_483b3_row4_col1" class="data row4 col1" >0.3099</td>
#       <td id="T_483b3_row4_col2" class="data row4 col2" >0.1563</td>
#       <td id="T_483b3_row4_col3" class="data row4 col3" >0.3785</td>
#       <td id="T_483b3_row4_col4" class="data row4 col4" >-0.0383</td>
#       <td id="T_483b3_row4_col5" class="data row4 col5" >0.1739</td>
#       <td id="T_483b3_row4_col6" class="data row4 col6" >0.3086</td>
#       <td id="T_483b3_row4_col7" class="da
# <style type="text/css">
# </style>
# <table id="T_ba507">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba507_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ba507_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ba507_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ba507_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ba507_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ba507_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ba507_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ba507_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba507_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba507_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_ba507_row0_col1" class="data row0 col1" >0.3065</td>
#       <td id="T_ba507_row0_col2" class="data row0 col2" >0.1469</td>
#       <td id="T_ba507_row0_col3" class="data row0 col3" >0.3833</td>
#       <td id="T_ba507_row0_col4" class="data row0 col4" >0.4359</td>
#       <td id="T_ba507_row0_col5" class="data row0 col5" >0.1785</td>
#       <td id="T_ba507_row0_col6" class="data row0 col6" >0.3502</td>
#       <td id="T_ba507_row0_col7" class="data row0 col7" >0.6443</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_bcb44">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcb44_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bcb44_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bcb44_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bcb44_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bcb44_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bcb44_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bcb44_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_bcb44_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcb44_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bcb44_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_bcb44_row0_col1" class="data row0 col1" >0.3107</td>
#       <td id="T_bcb44_row0_col2" class="data row0 col2" >0.1560</td>
#       <td id="T_bcb44_row0_col3" class="data row0 col3" >0.3949</td>
#       <td id="T_bcb44_row0_col4" class="data row0 col4" >0.4013</td>
#       <td id="T_bcb44_row0_col5" class="data row0 col5" >0.1795</td>
#       <td id="T_bcb44_row0_col6" class="data row0 col6" >0.3422</td>
#       <td id="T_bcb44_row0_col7" class="data row0 col7" >0.6423</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_8a354">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a354_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8a354_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8a354_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8a354_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8a354_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8a354_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8a354_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_8a354_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a354_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a354_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_8a354_row0_col1" class="data row0 col1" >0.3193</td>
#       <td id="T_8a354_row0_col2" class="data row0 col2" >0.2070</td>
#       <td id="T_8a354_row0_col3" class="data row0 col3" >0.4550</td>
#       <td id="T_8a354_row0_col4" class="data row0 col4" >0.2054</td>
#       <td id="T_8a354_row0_col5" class="data row0 col5" >0.2034</td>
#       <td id="T_8a354_row0_col6" class="data row0 col6" >0.3586</td>
#       <td id="T_8a354_row0_col7" class="data row0 col7" >0.5435</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_aeb46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aeb46_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_aeb46_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_aeb46_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_aeb46_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_aeb46_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_aeb46_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_aeb46_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_aeb46_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aeb46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aeb46_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_aeb46_row0_col1" class="data row0 col1" >0.3434</td>
#       <td id="T_aeb46_row0_col2" class="data row0 col2" >0.1797</td>
#       <td id="T_aeb46_row0_col3" class="data row0 col3" >0.4240</td>
#       <td id="T_aeb46_row0_col4" class="data row0 col4" >0.3099</td>
#       <td id="T_aeb46_row0_col5" class="data row0 col5" >0.1972</td>
#       <td id="T_aeb46_row0_col6" class="data row0 col6" >0.3917</td>
#       <td id="T_aeb46_row0_col7" class="data row0 col7" >0.5761</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_caab2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_caab2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_caab2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_caab2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_caab2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_caab2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_caab2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_caab2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_caab2_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_caab2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_caab2_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_caab2_row0_col1" class="data row0 col1" >0.3180</td>
#       <td id="T_caab2_row0_col2" class="data row0 col2" >0.1514</td>
#       <td id="T_caab2_row0_col3" class="data row0 col3" >0.3891</td>
#       <td id="T_caab2_row0_col4" class="data row0 col4" >0.4189</td>
#       <td id="T_caab2_row0_col5" class="data row0 col5" >0.1798</td>
#       <td id="T_caab2_row0_col6" class="data row0 col6" >0.3516</td>
#       <td id="T_caab2_row0_col7" class="data row0 col7" >0.6247</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d3b05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3b05_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d3b05_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d3b05_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d3b05_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d3b05_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d3b05_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d3b05_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d3b05_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3b05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3b05_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_d3b05_row0_col1" class="data row0 col1" >0.3142</td>
#       <td id="T_d3b05_row0_col2" class="data row0 col2" >0.1679</td>
#       <td id="T_d3b05_row0_col3" class="data row0 col3" >0.4098</td>
#       <td id="T_d3b05_row0_col4" class="data row0 col4" >0.3554</td>
#       <td id="T_d3b05_row0_col5" class="data row0 col5" >0.1898</td>
#       <td id="T_d3b05_row0_col6" class="data row0 col6" >0.3598</td>
#       <td id="T_d3b05_row0_col7" class="data row0 col7" >0.6087</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_faf94">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_faf94_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_faf94_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_faf94_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_faf94_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_faf94_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_faf94_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_faf94_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_faf94_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_faf94_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_faf94_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_faf94_row0_col1" class="data row0 col1" >0.4213</td>
#       <td id="T_faf94_row0_col2" class="data row0 col2" >0.2605</td>
#       <td id="T_faf94_row0_col3" class="data row0 col3" >0.5104</td>
#       <td id="T_faf94_row0_col4" class="data row0 col4" >-0.0001</td>
#       <td id="T_faf94_row0_col5" class="data row0 col5" >0.2326</td>
#       <td id="T_faf94_row0_col6" class="data row0 col6" >0.4572</td>
#       <td id="T_faf94_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_5a937">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a937_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5a937_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5a937_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5a937_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5a937_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5a937_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5a937_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5a937_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a937_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a937_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_5a937_row0_col1" class="data row0 col1" >0.4290</td>
#       <td id="T_5a937_row0_col2" class="data row0 col2" >0.2648</td>
#       <td id="T_5a937_row0_col3" class="data row0 col3" >0.5146</td>
#       <td id="T_5a937_row0_col4" class="data row0 col4" >-0.0168</td>
#       <td id="T_5a937_row0_col5" class="data row0 col5" >0.2331</td>
#       <td id="T_5a937_row0_col6" class="data row0 col6" >0.4532</td>
#       <td id="T_5a937_row0_col7" class="data row0 col7" >0.1413</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6a6b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a6b5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6a6b5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6a6b5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6a6b5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6a6b5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6a6b5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6a6b5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6a6b5_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a6b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a6b5_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_6a6b5_row0_col1" class="data row0 col1" >0.4290</td>
#       <td id="T_6a6b5_row0_col2" class="data row0 col2" >0.2648</td>
#       <td id="T_6a6b5_row0_col3" class="data row0 col3" >0.5146</td>
#       <td id="T_6a6b5_row0_col4" class="data row0 col4" >-0.0168</td>
#       <td id="T_6a6b5_row0_col5" class="data row0 col5" >0.2331</td>
#       <td id="T_6a6b5_row0_col6" class="data row0 col6" >0.4532</td>
#       <td id="T_6a6b5_row0_col7" class="data row0 col7" >0.1413</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6ae91">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ae91_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6ae91_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6ae91_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6ae91_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6ae91_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6ae91_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6ae91_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6ae91_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ae91_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ae91_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_6ae91_row0_col1" class="data row0 col1" >0.4287</td>
#       <td id="T_6ae91_row0_col2" class="data row0 col2" >0.2645</td>
#       <td id="T_6ae91_row0_col3" class="data row0 col3" >0.5143</td>
#       <td id="T_6ae91_row0_col4" class="data row0 col4" >-0.0156</td>
#       <td id="T_6ae91_row0_col5" class="data row0 col5" >0.2329</td>
#       <td id="T_6ae91_row0_col6" class="data row0 col6" >0.4523</td>
#       <td id="T_6ae91_row0_col7" class="data row0 col7" >0.1591</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c117e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c117e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c117e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c117e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c117e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c117e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c117e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c117e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c117e_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c117e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c117e_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_c117e_row0_col1" class="data row0 col1" >0.4195</td>
#       <td id="T_c117e_row0_col2" class="data row0 col2" >0.2609</td>
#       <td id="T_c117e_row0_col3" class="data row0 col3" >0.5107</td>
#       <td id="T_c117e_row0_col4" class="data row0 col4" >-0.0014</td>
#       <td id="T_c117e_row0_col5" class="data row0 col5" >0.2277</td>
#       <td id="T_c117e_row0_col6" class="data row0 col6" >0.4168</td>
#       <td id="T_c117e_row0_col7" class="data row0 col7" >0.1838</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_33aea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33aea_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_33aea_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_33aea_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_33aea_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_33aea_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_33aea_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_33aea_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_33aea_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33aea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33aea_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_33aea_row0_col1" class="data row0 col1" >0.4572</td>
#       <td id="T_33aea_row0_col2" class="data row0 col2" >0.4005</td>
#       <td id="T_33aea_row0_col3" class="data row0 col3" >0.6328</td>
#       <td id="T_33aea_row0_col4" class="data row0 col4" >-0.5374</td>
#       <td id="T_33aea_row0_col5" class="data row0 col5" >0.2637</td>
#       <td id="T_33aea_row0_col6" class="data row0 col6" >0.5065</td>
#       <td id="T_33aea_row0_col7" class="data row0 col7" >0.5534</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_fefb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fefb8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fefb8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fefb8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fefb8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fefb8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fefb8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fefb8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fefb8_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fefb8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fefb8_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_fefb8_row0_col1" class="data row0 col1" >0.4410</td>
#       <td id="T_fefb8_row0_col2" class="data row0 col2" >0.3216</td>
#       <td id="T_fefb8_row0_col3" class="data row0 col3" >0.5671</td>
#       <td id="T_fefb8_row0_col4" class="data row0 col4" >-0.2344</td>
#       <td id="T_fefb8_row0_col5" class="data row0 col5" >0.2484</td>
#       <td id="T_fefb8_row0_col6" class="data row0 col6" >0.4432</td>
#       <td id="T_fefb8_row0_col7" class="data row0 col7" >0.3955</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_736be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_736be_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_736be_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_736be_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_736be_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_736be_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_736be_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_736be_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_736be_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_736be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_736be_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_736be_row0_col1" class="data row0 col1" >0.3768</td>
#       <td id="T_736be_row0_col2" class="data row0 col2" >0.2496</td>
#       <td id="T_736be_row0_col3" class="data row0 col3" >0.4996</td>
#       <td id="T_736be_row0_col4" class="data row0 col4" >0.0419</td>
#       <td id="T_736be_row0_col5" class="data row0 col5" >0.2235</td>
#       <td id="T_736be_row0_col6" class="data row0 col6" >0.4269</td>
#       <td id="T_736be_row0_col7" class="data row0 col7" >0.5227</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ec07f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec07f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ec07f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ec07f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ec07f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ec07f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ec07f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ec07f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ec07f_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec07f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec07f_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_ec07f_row0_col1" class="data row0 col1" >0.4145</td>
#       <td id="T_ec07f_row0_col2" class="data row0 col2" >0.2737</td>
#       <td id="T_ec07f_row0_col3" class="data row0 col3" >0.5232</td>
#       <td id="T_ec07f_row0_col4" class="data row0 col4" >-0.0507</td>
#       <td id="T_ec07f_row0_col5" class="data row0 col5" >0.2427</td>
#       <td id="T_ec07f_row0_col6" class="data row0 col6" >0.4844</td>
#       <td id="T_ec07f_row0_col7" class="data row0 col7" >0.0104</td>
#     </tr>
#   </tbody>
# </table>
# Model: ExtraTreesRegressor(n_jobs=-1, random_state=1), Spearman Correlation: 0.6442687747035574
# Model: RandomForestRegressor(n_jobs=-1, random_state=1), Spearman Correlation: 0.642292490118577
# Model: AdaBoostRegressor(random_state=1), Spearman Correlation: 0.6246602612245414
# Model: BayesianRidge(), Spearman Correlation: 0.608695652173913
# Model: LGBMRegressor(n_jobs=-1, random_state=1), Spearman Correlation: 0.5760869565217391
# Model: GradientBoostingRegressor(random_state=1), Spearman Correlation: 0.5434782608695652
# Model: DummyRegressor(), Spearman Correlation: nan
# Model: Ridge(random_state=1), Spearman Correlation: 0.5533596837944664
# Model: HuberRegressor(), Spearman Correlation: 0.5227272727272728
# Model: DecisionTreeRegressor(random_state=1), Spearman Correlation: 0.3955453299592544
# Model: OrthogonalMatchingPursuit(), Spearman Correlation: 0.18379446640316205
# Model: ElasticNet(random_state=1), Spearman Correlation: 0.1590909090909091
# Model: LassoLars(random_state=1), Spearman Correlation: 0.14130434782608697
# Model: Lasso(random_state=1), Spearman Correlation: 0.14130434782608697
# Model: KNeighborsRegressor(n_jobs=-1), Spearman Correlation: 0.010393482557345343

# %%
# Check the pearson correlation of predictions
pearson_results = []
for model in top_models:
    predictions = predict_model(model)  # Get predictions
    
    # Identify the correct prediction column
    prediction_column = 'Label' if 'Label' in predictions.columns else predictions.columns[-1]
    
    # Calculate Spearman correlation
    pearson_corr = np.corrcoef(predictions[target], predictions[prediction_column])[0,1]
    pearson_results.append((model, pearson_corr))
    
    # Print Spearman correlation
    print(f"Model: {model}, Pearson Correlation: {pearson_corr}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a8f55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8f55_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a8f55_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a8f55_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a8f55_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a8f55_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a8f55_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a8f55_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a8f55_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8f55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8f55_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_a8f55_row0_col1" class="data row0 col1" >0.3065</td>
#       <td id="T_a8f55_row0_col2" class="data row0 col2" >0.1469</td>
#       <td id="T_a8f55_row0_col3" class="data row0 col3" >0.3833</td>
#       <td id="T_a8f55_row0_col4" class="data row0 col4" >0.4359</td>
#       <td id="T_a8f55_row0_col5" class="data row0 col5" >0.1785</td>
#       <td id="T_a8f55_row0_col6" class="data row0 col6" >0.3502</td>
#       <td id="T_a8f55_row0_col7" class="data row0 col7" >0.6443</td>
#     </tr>
#   </tbody>
# </table>
# Model: ExtraTreesRegressor(n_jobs=-1, random_state=1), Pearson Correlation: 0.680082690446901
# <style type="text/css">
# </style>
# <table id="T_00c40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00c40_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_00c40_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_00c40_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_00c40_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_00c40_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_00c40_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_00c40_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_00c40_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00c40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00c40_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_00c40_row0_col1" class="data row0 col1" >0.3107</td>
#       <td id="T_00c40_row0_col2" class="data row0 col2" >0.1560</td>
#       <td id="T_00c40_row0_col3" class="data row0 col3" >0.3949</td>
#       <td id="T_00c40_row0_col4" class="data row0 col4" >0.4013</td>
#       <td id="T_00c40_row0_col5" class="data row0 col5" >0.1795</td>
#       <td id="T_00c40_row0_col6" class="data row0 col6" >0.3422</td>
#       <td id="T_00c40_row0_col7" class="data row0 col7" >0.6423</td>
#     </tr>
#   </tbody>
# </table>
# Model: RandomForestRegressor(n_jobs=-1, random_state=1), Pearson Correlation: 0.6435056735535511
# <style type="text/css">
# </style>
# <table id="T_edfff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edfff_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_edfff_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_edfff_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_edfff_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_edfff_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_edfff_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_edfff_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_edfff_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edfff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edfff_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_edfff_row0_col1" class="data row0 col1" >0.3193</td>
#       <td id="T_edfff_row0_col2" class="data row0 col2" >0.2070</td>
#       <td id="T_edfff_row0_col3" class="data row0 col3" >0.4550</td>
#       <td id="T_edfff_row0_col4" class="data row0 col4" >0.2054</td>
#       <td id="T_edfff_row0_col5" class="data row0 col5" >0.2034</td>
#       <td id="T_edfff_row0_col6" class="data row0 col6" >0.3586</td>
#       <td id="T_edfff_row0_col7" class="data row0 col7" >0.5435</td>
#     </tr>
#   </tbody>
# </table>
# Model: GradientBoostingRegressor(random_state=1), Pearson Correlation: 0.49743189850660874
# <style type="text/css">
# </style>
# <table id="T_e7366">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7366_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e7366_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e7366_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e7366_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e7366_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e7366_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e7366_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e7366_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7366_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7366_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e7366_row0_col1" class="data row0 col1" >0.3434</td>
#       <td id="T_e7366_row0_col2" class="data row0 col2" >0.1797</td>
#       <td id="T_e7366_row0_col3" class="data row0 col3" >0.4240</td>
#       <td id="T_e7366_row0_col4" class="data row0 col4" >0.3099</td>
#       <td id="T_e7366_row0_col5" class="data row0 col5" >0.1972</td>
#       <td id="T_e7366_row0_col6" class="data row0 col6" >0.3917</td>
#       <td id="T_e7366_row0_col7" class="data row0 col7" >0.5761</td>
#     </tr>
#   </tbody>
# </table>
# Model: LGBMRegressor(n_jobs=-1, random_state=1), Pearson Correlation: 0.5787300360074287
# <style type="text/css">
# </style>
# <table id="T_a1836">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1836_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a1836_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a1836_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a1836_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a1836_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a1836_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a1836_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a1836_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1836_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1836_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_a1836_row0_col1" class="data row0 col1" >0.3180</td>
#       <td id="T_a1836_row0_col2" class="data row0 col2" >0.1514</td>
#       <td id="T_a1836_row0_col3" class="data row0 col3" >0.3891</td>
#       <td id="T_a1836_row0_col4" class="data row0 col4" >0.4189</td>
#       <td id="T_a1836_row0_col5" class="data row0 col5" >0.1798</td>
#       <td id="T_a1836_row0_col6" class="data row0 col6" >0.3516</td>
#       <td id="T_a1836_row0_col7" class="data row0 col7" >0.6247</td>
#     </tr>
#   </tbody>
# </table>
# Model: AdaBoostRegressor(random_state=1), Pearson Correlation: 0.6628564172287155
# <style type="text/css">
# </style>
# <table id="T_bd99c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd99c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bd99c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bd99c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bd99c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bd99c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bd99c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bd99c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_bd99c_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd99c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd99c_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_bd99c_row0_col1" class="data row0 col1" >0.3142</td>
#       <td id="T_bd99c_row0_col2" class="data row0 col2" >0.1679</td>
#       <td id="T_bd99c_row0_col3" class="data row0 col3" >0.4098</td>
#       <td id="T_bd99c_row0_col4" class="data row0 col4" >0.3554</td>
#       <td id="T_bd99c_row0_col5" class="data row0 col5" >0.1898</td>
#       <td id="T_bd99c_row0_col6" class="data row0 col6" >0.3598</td>
#       <td id="T_bd99c_row0_col7" class="data row0 col7" >0.6087</td>
#     </tr>
#   </tbody>
# </table>
# Model: BayesianRidge(), Pearson Correlation: 0.6184213181583382
# <style type="text/css">
# </style>
# <table id="T_ffefb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffefb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ffefb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ffefb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ffefb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ffefb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ffefb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ffefb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ffefb_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffefb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ffefb_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_ffefb_row0_col1" class="data row0 col1" >0.4213</td>
#       <td id="T_ffefb_row0_col2" class="data row0 col2" >0.2605</td>
#       <td id="T_ffefb_row0_col3" class="data row0 col3" >0.5104</td>
#       <td id="T_ffefb_row0_col4" class="data row0 col4" >-0.0001</td>
#       <td id="T_ffefb_row0_col5" class="data row0 col5" >0.2326</td>
#       <td id="T_ffefb_row0_col6" class="data row0 col6" >0.4572</td>
#       <td id="T_ffefb_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Model: DummyRegressor(), Pearson Correlation: nan
# <style type="text/css">
# </style>
# <table id="T_4abca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4abca_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4abca_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4abca_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4abca_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4abca_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4abca_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4abca_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4abca_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4abca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4abca_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_4abca_row0_col1" class="data row0 col1" >0.4290</td>
#       <td id="T_4abca_row0_col2" class="data row0 col2" >0.2648</td>
#       <td id="T_4abca_row0_col3" class="data row0 col3" >0.5146</td>
#       <td id="T_4abca_row0_col4" class="data row0 col4" >-0.0168</td>
#       <td id="T_4abca_row0_col5" class="data row0 col5" >0.2331</td>
#       <td id="T_4abca_row0_col6" class="data row0 col6" >0.4532</td>
#       <td id="T_4abca_row0_col7" class="data row0 col7" >0.1413</td>
#     </tr>
#   </tbody>
# </table>
# Model: LassoLars(random_state=1), Pearson Correlation: -0.03754221631656104
# <style type="text/css">
# </style>
# <table id="T_f32d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f32d4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f32d4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f32d4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f32d4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f32d4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f32d4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f32d4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f32d4_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f32d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f32d4_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_f32d4_row0_col1" class="data row0 col1" >0.4290</td>
#       <td id="T_f32d4_row0_col2" class="data row0 col2" >0.2648</td>
#       <td id="T_f32d4_row0_col3" class="data row0 col3" >0.5146</td>
#       <td id="T_f32d4_row0_col4" class="data row0 col4" >-0.0168</td>
#       <td id="T_f32d4_row0_col5" class="data row0 col5" >0.2331</td>
#       <td id="T_f32d4_row0_col6" class="data row0 col6" >0.4532</td>
#       <td id="T_f32d4_row0_col7" class="data row0 col7" >0.1413</td>
#     </tr>
#   </tbody>
# </table>
# Model: Lasso(random_state=1), Pearson Correlation: -0.037542216316561156
# <style type="text/css">
# </style>
# <table id="T_c5341">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5341_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c5341_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c5341_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c5341_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c5341_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c5341_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c5341_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c5341_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5341_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5341_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_c5341_row0_col1" class="data row0 col1" >0.4287</td>
#       <td id="T_c5341_row0_col2" class="data row0 col2" >0.2645</td>
#       <td id="T_c5341_row0_col3" class="data row0 col3" >0.5143</td>
#       <td id="T_c5341_row0_col4" class="data row0 col4" >-0.0156</td>
#       <td id="T_c5341_row0_col5" class="data row0 col5" >0.2329</td>
#       <td id="T_c5341_row0_col6" class="data row0 col6" >0.4523</td>
#       <td id="T_c5341_row0_col7" class="data row0 col7" >0.1591</td>
#     </tr>
#   </tbody>
# </table>
# Model: ElasticNet(random_state=1), Pearson Correlation: -0.02529191896218707
# <style type="text/css">
# </style>
# <table id="T_c14bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c14bd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c14bd_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c14bd_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c14bd_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c14bd_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c14bd_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c14bd_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c14bd_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c14bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c14bd_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_c14bd_row0_col1" class="data row0 col1" >0.4195</td>
#       <td id="T_c14bd_row0_col2" class="data row0 col2" >0.2609</td>
#       <td id="T_c14bd_row0_col3" class="data row0 col3" >0.5107</td>
#       <td id="T_c14bd_row0_col4" class="data row0 col4" >-0.0014</td>
#       <td id="T_c14bd_row0_col5" class="data row0 col5" >0.2277</td>
#       <td id="T_c14bd_row0_col6" class="data row0 col6" >0.4168</td>
#       <td id="T_c14bd_row0_col7" class="data row0 col7" >0.1838</td>
#     </tr>
#   </tbody>
# </table>
# Model: OrthogonalMatchingPursuit(), Pearson Correlation: 0.16315866314024347
# <style type="text/css">
# </style>
# <table id="T_f8d43">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8d43_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f8d43_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f8d43_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f8d43_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f8d43_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f8d43_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f8d43_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f8d43_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8d43_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8d43_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_f8d43_row0_col1" class="data row0 col1" >0.4572</td>
#       <td id="T_f8d43_row0_col2" class="data row0 col2" >0.4005</td>
#       <td id="T_f8d43_row0_col3" class="data row0 col3" >0.6328</td>
#       <td id="T_f8d43_row0_col4" class="data row0 col4" >-0.5374</td>
#       <td id="T_f8d43_row0_col5" class="data row0 col5" >0.2637</td>
#       <td id="T_f8d43_row0_col6" class="data row0 col6" >0.5065</td>
#       <td id="T_f8d43_row0_col7" class="data row0 col7" >0.5534</td>
#     </tr>
#   </tbody>
# </table>
# Model: Ridge(random_state=1), Pearson Correlation: 0.4747896170631824
# <style type="text/css">
# </style>
# <table id="T_26669">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26669_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_26669_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_26669_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_26669_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_26669_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_26669_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_26669_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_26669_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26669_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26669_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_26669_row0_col1" class="data row0 col1" >0.4410</td>
#       <td id="T_26669_row0_col2" class="data row0 col2" >0.3216</td>
#       <td id="T_26669_row0_col3" class="data row0 col3" >0.5671</td>
#       <td id="T_26669_row0_col4" class="data row0 col4" >-0.2344</td>
#       <td id="T_26669_row0_col5" class="data row0 col5" >0.2484</td>
#       <td id="T_26669_row0_col6" class="data row0 col6" >0.4432</td>
#       <td id="T_26669_row0_col7" class="data row0 col7" >0.3955</td>
#     </tr>
#   </tbody>
# </table>
# Model: DecisionTreeRegressor(random_state=1), Pearson Correlation: 0.2916028494541159
# <style type="text/css">
# </style>
# <table id="T_9a13d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a13d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9a13d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9a13d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9a13d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9a13d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9a13d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9a13d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9a13d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a13d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a13d_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_9a13d_row0_col1" class="data row0 col1" >0.3768</td>
#       <td id="T_9a13d_row0_col2" class="data row0 col2" >0.2496</td>
#       <td id="T_9a13d_row0_col3" class="data row0 col3" >0.4996</td>
#       <td id="T_9a13d_row0_col4" class="data row0 col4" >0.0419</td>
#       <td id="T_9a13d_row0_col5" class="data row0 col5" >0.2235</td>
#       <td id="T_9a13d_row0_col6" class="data row0 col6" >0.4269</td>
#       <td id="T_9a13d_row0_col7" class="data row0 col7" >0.5227</td>
#     </tr>
#   </tbody>
# </table>
# Model: HuberRegressor(), Pearson Correlation: 0.5399235413089805
# <style type="text/css">
# </style>
# <table id="T_de5ec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de5ec_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_de5ec_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_de5ec_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_de5ec_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_de5ec_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_de5ec_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_de5ec_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_de5ec_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de5ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de5ec_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_de5ec_row0_col1" class="data row0 col1" >0.4145</td>
#       <td id="T_de5ec_row0_col2" class="data row0 col2" >0.2737</td>
#       <td id="T_de5ec_row0_col3" class="data row0 col3" >0.5232</td>
#       <td id="T_de5ec_row0_col4" class="data row0 col4" >-0.0507</td>
#       <td id="T_de5ec_row0_col5" class="data row0 col5" >0.2427</td>
#       <td id="T_de5ec_row0_col6" class="data row0 col6" >0.4844</td>
#       <td id="T_de5ec_row0_col7" class="data row0 col7" >0.0104</td>
#     </tr>
#   </tbody>
# </table>
# Model: KNeighborsRegressor(n_jobs=-1), Pearson Correlation: 0.06962299103803224

# %%
top_models[0]
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=1)

# %%
# save top_models[0]
save_model(top_models[0], 'task21_best_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['day_0_specimen_id', 'subject_id',
#                                               'age', 'day_0_Monocytes',
#                                               'day_0_Classical_Monocytes',
#                                               'day_0_Non-Classical_Monocytes',
#                                               'day_0_Intermediate_Monocytes',
#                                               'day_0_Bcells', 'day_0_CD3CD19neg',
#                                               'day_0_CD3 Tcells',
#                                               'day_0_CD4Tcells',
#                                               'day_0_CD8Tcells',
#                                               'day_0_TemraCD4', 'da...
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['specimen_type', 'race',
#                                               'dataset'],
#                                      transformer=OneHotEncoder(cols=['specimen_type',
#                                                                      'race',
#                                                                      'dataset'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('trained_model',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=1))]),
#  'task21_best_model.pkl')

# %% [markdown]
# # Exploring more features

# %%
import numpy as np
import pandas as pd
from pycaret.regression import *
from scipy.stats import spearmanr

exp_feats = ['day_0_specimen_id', 'subject_id', 'specimen_type', 'infancy_vac',
       'biological_sex', 'ethnicity', 'race', 'dataset', 'age', 'day_0_IgG_PT',
       'day_0_IgG_PRN', 'day_0_IgG_FHA', 'day_0_IgG1_PT', 'day_0_IgG1_PRN',
       'day_0_IgG1_FHA', 'day_0_IgG1_FIM2/3', 'day_0_IgG1_TT', 'day_0_IgG1_DT',
       'day_0_IgG1_OVA', 'day_0_IgG2_PT', 'day_0_IgG2_PRN', 'day_0_IgG2_FHA',
       'day_0_IgG2_FIM2/3', 'day_0_IgG2_TT', 'day_0_IgG2_DT', 'day_0_IgG2_OVA',
       'day_0_IgG3_PT', 'day_0_IgG3_PRN', 'day_0_IgG3_FHA',
       'day_0_IgG3_FIM2/3', 'day_0_IgG3_TT', 'day_0_IgG3_DT', 'day_0_IgG3_OVA',
       'day_0_IgG4_PT', 'day_0_IgG4_PRN', 'day_0_IgG4_FHA',
       'day_0_IgG4_FIM2/3', 'day_0_IgG4_TT', 'day_0_IgG4_DT', 'day_0_IgG4_OVA']

# %%
# Load data
df = pd.read_csv("/home/vmottaqi/cmipb_challenge/vincent_files/training_abtier_batchcorrected_processed_oct24.csv", index_col=0)
df = df[df['FC_day_0_14_IgG_PT'] >= 0]

# Define features and target
X = df[exp_feats]
y = df['FC_day_0_14_IgG_PT']

# Combine features and target for PyCaret input
data = X.copy()
data['FC_day_0_14_IgG_PT'] = y

# Initialize PyCaret with the dataset and target column
regression_setup = setup(
    data=data,
    target='FC_day_0_14_IgG_PT',
    categorical_features=['specimen_type', 'infancy_vac', 'biological_sex', 'ethnicity', 'race', 'dataset'],  # Specify any categorical features
    session_id=1,
    fold=5
)

# Custom Spearman correlation function
def spearman_metric(y_true, y_pred):
    return spearmanr(y_true, y_pred)[0]  # Return the Spearman correlation coefficient

# Adding the custom Spearman metric
add_metric(
    'Spearman', 
    'Spearman Correlation', 
    spearman_metric, 
    greater_is_better=True
)

# Compare models using a supported metric (e.g., R2)
top_models = compare_models(sort='R2', n_select=15)  # Select top models based on R2, adjust as needed

# Calculate Spearman correlation for each top model
spearman_results = []
for model in top_models:
    predictions = predict_model(model)  # Get predictions
    
    # Identify the correct prediction column
    prediction_column = 'Label' if 'Label' in predictions.columns else predictions.columns[-1]
    
    # Calculate Spearman correlation
    spearman_corr = spearman_metric(predictions['FC_day_0_14_IgG_PT'], predictions[prediction_column])
    spearman_results.append((model, spearman_corr))

# Sort and display models by Spearman correlation
sorted_spearman_results = sorted(spearman_results, key=lambda x: x[1], reverse=True)
for model, spearman_corr in sorted_spearman_results:
    print(f"Model: {model}, Spearman Correlation: {spearman_corr}")
# Out:
# <style type="text/css">
# #T_5bcb0_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5bcb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bcb0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5bcb0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bcb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bcb0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5bcb0_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5bcb0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5bcb0_row1_col1" class="data row1 col1" >FC_day_0_14_IgG_PT</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5bcb0_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5bcb0_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5bcb0_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5bcb0_row3_col1" class="data row3 col1" >(93, 41)</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5bcb0_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5bcb0_row4_col1" class="data row4 col1" >(93, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5bcb0_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5bcb0_row5_col1" class="data row5 col1" >(65, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5bcb0_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5bcb0_row6_col1" class="data row6 col1" >(28, 50)</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5bcb0_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5bcb0_row7_col1" class="data row7 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5bcb0_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_5bcb0_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5bcb0_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_5bcb0_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5bcb0_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_5bcb0_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5bcb0_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_5bcb0_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5bcb0_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_5bcb0_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5bcb0_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_5bcb0_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5bcb0_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_5bcb0_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5bcb0_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_5bcb0_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5bcb0_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_5bcb0_row16_col1" class="data row16 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5bcb0_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_5bcb0_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5bcb0_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_5bcb0_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5bcb0_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_5bcb0_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5bcb0_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_5bcb0_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5bcb0_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5bcb0_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_5bcb0_row21_col1" class="data row21 col1" >cb5c</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7bed7 th {
#   text-align: left;
# }
# #T_7bed7_row0_col0, #T_7bed7_row0_col1, #T_7bed7_row0_col5, #T_7bed7_row0_col6, #T_7bed7_row1_col0, #T_7bed7_row1_col1, #T_7bed7_row1_col2, #T_7bed7_row1_col3, #T_7bed7_row1_col4, #T_7bed7_row1_col5, #T_7bed7_row1_col6, #T_7bed7_row2_col0, #T_7bed7_row2_col2, #T_7bed7_row2_col3, #T_7bed7_row2_col4, #T_7bed7_row2_col5, #T_7bed7_row2_col6, #T_7bed7_row3_col0, #T_7bed7_row3_col1, #T_7bed7_row3_col2, #T_7bed7_row3_col3, #T_7bed7_row3_col4, #T_7bed7_row3_col5, #T_7bed7_row3_col6, #T_7bed7_row4_col0, #T_7bed7_row4_col1, #T_7bed7_row4_col2, #T_7bed7_row4_col3, #T_7bed7_row4_col4, #T_7bed7_row4_col5, #T_7bed7_row4_col6, #T_7bed7_row5_col0, #T_7bed7_row5_col1, #T_7bed7_row5_col2, #T_7bed7_row5_col3, #T_7bed7_row5_col4, #T_7bed7_row5_col5, #T_7bed7_row5_col6, #T_7bed7_row6_col0, #T_7bed7_row6_col1, #T_7bed7_row6_col2, #T_7bed7_row6_col3, #T_7bed7_row6_col4, #T_7bed7_row6_col5, #T_7bed7_row6_col6, #T_7bed7_row7_col0, #T_7bed7_row7_col1, #T_7bed7_row7_col2, #T_7bed7_row7_col3, #T_7bed7_row7_col4, #T_7bed7_row7_col5, #T_7bed7_row7_col6, #T_7bed7_row8_col0, #T_7bed7_row8_col1, #T_7bed7_row8_col2, #T_7bed7_row8_col3, #T_7bed7_row8_col4, #T_7bed7_row8_col6, #T_7bed7_row9_col0, #T_7bed7_row9_col1, #T_7bed7_row9_col2, #T_7bed7_row9_col3, #T_7bed7_row9_col4, #T_7bed7_row9_col5, #T_7bed7_row10_col0, #T_7bed7_row10_col1, #T_7bed7_row10_col2, #T_7bed7_row10_col3, #T_7bed7_row10_col4, #T_7bed7_row10_col5, #T_7bed7_row10_col6, #T_7bed7_row11_col0, #T_7bed7_row11_col1, #T_7bed7_row11_col2, #T_7bed7_row11_col3, #T_7bed7_row11_col4, #T_7bed7_row11_col5, #T_7bed7_row11_col6, #T_7bed7_row12_col0, #T_7bed7_row12_col1, #T_7bed7_row12_col2, #T_7bed7_row12_col3, #T_7bed7_row12_col4, #T_7bed7_row12_col5, #T_7bed7_row12_col6, #T_7bed7_row13_col0, #T_7bed7_row13_col1, #T_7bed7_row13_col2, #T_7bed7_row13_col3, #T_7bed7_row13_col4, #T_7bed7_row13_col5, #T_7bed7_row13_col6, #T_7bed7_row14_col0, #T_7bed7_row14_col1, #T_7bed7_row14_col2, #T_7bed7_row14_col3, #T_7bed7_row14_col4, #T_7bed7_row14_col5, #T_7bed7_row14_col6, #T_7bed7_row15_col0, #T_7bed7_row15_col1, #T_7bed7_row15_col2, #T_7bed7_row15_col3, #T_7bed7_row15_col4, #T_7bed7_row15_col5, #T_7bed7_row15_col6, #T_7bed7_row16_col0, #T_7bed7_row16_col1, #T_7bed7_row16_col2, #T_7bed7_row16_col3, #T_7bed7_row16_col4, #T_7bed7_row16_col5, #T_7bed7_row16_col6, #T_7bed7_row17_col0, #T_7bed7_row17_col1, #T_7bed7_row17_col2, #T_7bed7_row17_col3, #T_7bed7_row17_col4, #T_7bed7_row17_col5, #T_7bed7_row17_col6 {
#   text-align: left;
# }
# #T_7bed7_row0_col2, #T_7bed7_row0_col3, #T_7bed7_row0_col4, #T_7bed7_row0_col7, #T_7bed7_row1_col7, #T_7bed7_row2_col1, #T_7bed7_row2_col7, #T_7bed7_row3_col7, #T_7bed7_row4_col7, #T_7bed7_row5_col7, #T_7bed7_row6_col7, #T_7bed7_row7_col7, #T_7bed7_row8_col5, #T_7bed7_row8_col7, #T_7bed7_row9_col6, #T_7bed7_row9_col7, #T_7bed7_row10_col7, #T_7bed7_row11_col7, #T_7bed7_row12_col7, #T_7bed7_row13_col7, #T_7bed7_row14_col7, #T_7bed7_row15_col7, #T_7bed7_row16_col7, #T_7bed7_row17_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7bed7_row0_col8, #T_7bed7_row1_col8, #T_7bed7_row2_col8, #T_7bed7_row3_col8, #T_7bed7_row4_col8, #T_7bed7_row5_col8, #T_7bed7_row6_col8, #T_7bed7_row7_col8, #T_7bed7_row8_col8, #T_7bed7_row9_col8, #T_7bed7_row10_col8, #T_7bed7_row12_col8, #T_7bed7_row13_col8, #T_7bed7_row14_col8, #T_7bed7_row15_col8, #T_7bed7_row16_col8, #T_7bed7_row17_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7bed7_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7bed7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bed7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7bed7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7bed7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7bed7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7bed7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7bed7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7bed7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7bed7_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#       <th id="T_7bed7_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bed7_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_7bed7_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_7bed7_row0_col1" class="data row0 col1" >8.2899</td>
#       <td id="T_7bed7_row0_col2" class="data row0 col2" >304.2340</td>
#       <td id="T_7bed7_row0_col3" class="data row0 col3" >14.4331</td>
#       <td id="T_7bed7_row0_col4" class="data row0 col4" >-0.6856</td>
#       <td id="T_7bed7_row0_col5" class="data row0 col5" >0.8898</td>
#       <td id="T_7bed7_row0_col6" class="data row0 col6" >2.5197</td>
#       <td id="T_7bed7_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_7bed7_row0_col8" class="data row0 col8" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_7bed7_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_7bed7_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_7bed7_row1_col1" class="data row1 col1" >9.9649</td>
#       <td id="T_7bed7_row1_col2" class="data row1 col2" >372.4152</td>
#       <td id="T_7bed7_row1_col3" class="data row1 col3" >15.8866</td>
#       <td id="T_7bed7_row1_col4" class="data row1 col4" >-1.2296</td>
#       <td id="T_7bed7_row1_col5" class="data row1 col5" >0.9985</td>
#       <td id="T_7bed7_row1_col6" class="data row1 col6" >3.0019</td>
#       <td id="T_7bed7_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_7bed7_row1_col8" class="data row1 col8" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_7bed7_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_7bed7_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_7bed7_row2_col1" class="data row2 col1" >8.2793</td>
#       <td id="T_7bed7_row2_col2" class="data row2 col2" >333.1955</td>
#       <td id="T_7bed7_row2_col3" class="data row2 col3" >14.8631</td>
#       <td id="T_7bed7_row2_col4" class="data row2 col4" >-1.3967</td>
#       <td id="T_7bed7_row2_col5" class="data row2 col5" >0.8767</td>
#       <td id="T_7bed7_row2_col6" class="data row2 col6" >2.5708</td>
#       <td id="T_7bed7_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_7bed7_row2_col8" class="data row2 col8" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_7bed7_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_7bed7_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_7bed7_row3_col1" class="data row3 col1" >11.7580</td>
#       <td id="T_7bed7_row3_col2" class="data row3 col2" >443.7684</td>
#       <td id="T_7bed7_row3_col3" class="data row3 col3" >17.6791</td>
#       <td id="T_7bed7_row3_col4" class="data row3 col4" >-1.6908</td>
#       <td id="T_7bed7_row3_col5" class="data row3 col5" >1.2512</td>
#       <td id="T_7bed7_row3_col6" class="data row3 col6" >4.4298</td>
#       <td id="T_7bed7_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_7bed7_row3_col8" class="data row3 col8" >0.2120</td>
#     </tr>
#     <tr>
#       <th id="T_7bed7_level0_row4" class="row_heading level0 row4" >dummy</th>
#       <td id="T_7bed7_row4_col0" class="data row4 col0" >Dummy Regressor</td>
#       <td id="T_7bed7_row4_col1" class="data row4 col1" >11.8398</td>
#       <td id="T_7bed7_row4_col2" class="data row4 col2" >450.3617</td>
#       <td id="T_7bed7_row4_col3" class="data row4 col3" >17.7636</td>
#       <td id="T_7bed7_row4_col4" class="data row4 col4" >-1.6909</td>
#       <td id="T_7bed7_row4_col5" class="data row4 col5" >1.2705</td>
#       <td id="T_7bed7_row4_col6" class="data row4 col6" >4.5486</td>
#       <td id="T_7bed7_row4_col7" class="data row4 col7"
# <style type="text/css">
# </style>
# <table id="T_a38c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a38c9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a38c9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a38c9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a38c9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a38c9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a38c9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a38c9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a38c9_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a38c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a38c9_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_a38c9_row0_col1" class="data row0 col1" >7.4131</td>
#       <td id="T_a38c9_row0_col2" class="data row0 col2" >139.8895</td>
#       <td id="T_a38c9_row0_col3" class="data row0 col3" >11.8275</td>
#       <td id="T_a38c9_row0_col4" class="data row0 col4" >0.3780</td>
#       <td id="T_a38c9_row0_col5" class="data row0 col5" >0.7140</td>
#       <td id="T_a38c9_row0_col6" class="data row0 col6" >1.1994</td>
#       <td id="T_a38c9_row0_col7" class="data row0 col7" >0.7991</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_eb82e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb82e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eb82e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_eb82e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_eb82e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_eb82e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_eb82e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_eb82e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_eb82e_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb82e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb82e_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_eb82e_row0_col1" class="data row0 col1" >10.5108</td>
#       <td id="T_eb82e_row0_col2" class="data row0 col2" >211.4003</td>
#       <td id="T_eb82e_row0_col3" class="data row0 col3" >14.5396</td>
#       <td id="T_eb82e_row0_col4" class="data row0 col4" >0.0601</td>
#       <td id="T_eb82e_row0_col5" class="data row0 col5" >0.9012</td>
#       <td id="T_eb82e_row0_col6" class="data row0 col6" >1.8426</td>
#       <td id="T_eb82e_row0_col7" class="data row0 col7" >0.5627</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_12dba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12dba_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_12dba_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_12dba_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_12dba_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_12dba_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_12dba_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_12dba_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_12dba_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12dba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12dba_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_12dba_row0_col1" class="data row0 col1" >8.4416</td>
#       <td id="T_12dba_row0_col2" class="data row0 col2" >148.5780</td>
#       <td id="T_12dba_row0_col3" class="data row0 col3" >12.1893</td>
#       <td id="T_12dba_row0_col4" class="data row0 col4" >0.3394</td>
#       <td id="T_12dba_row0_col5" class="data row0 col5" >0.7576</td>
#       <td id="T_12dba_row0_col6" class="data row0 col6" >1.2519</td>
#       <td id="T_12dba_row0_col7" class="data row0 col7" >0.7219</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_cdf74">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdf74_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cdf74_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cdf74_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cdf74_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cdf74_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cdf74_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cdf74_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cdf74_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdf74_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cdf74_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_cdf74_row0_col1" class="data row0 col1" >10.6591</td>
#       <td id="T_cdf74_row0_col2" class="data row0 col2" >229.6061</td>
#       <td id="T_cdf74_row0_col3" class="data row0 col3" >15.1528</td>
#       <td id="T_cdf74_row0_col4" class="data row0 col4" >-0.0209</td>
#       <td id="T_cdf74_row0_col5" class="data row0 col5" >1.0606</td>
#       <td id="T_cdf74_row0_col6" class="data row0 col6" >2.3707</td>
#       <td id="T_cdf74_row0_col7" class="data row0 col7" >0.4921</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_5170d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5170d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5170d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5170d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5170d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5170d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5170d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5170d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5170d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5170d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5170d_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_5170d_row0_col1" class="data row0 col1" >10.7162</td>
#       <td id="T_5170d_row0_col2" class="data row0 col2" >230.9339</td>
#       <td id="T_5170d_row0_col3" class="data row0 col3" >15.1965</td>
#       <td id="T_5170d_row0_col4" class="data row0 col4" >-0.0268</td>
#       <td id="T_5170d_row0_col5" class="data row0 col5" >1.0673</td>
#       <td id="T_5170d_row0_col6" class="data row0 col6" >2.4033</td>
#       <td id="T_5170d_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_5dd93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dd93_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5dd93_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5dd93_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5dd93_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5dd93_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5dd93_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5dd93_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5dd93_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dd93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5dd93_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_5dd93_row0_col1" class="data row0 col1" >10.3184</td>
#       <td id="T_5dd93_row0_col2" class="data row0 col2" >190.1402</td>
#       <td id="T_5dd93_row0_col3" class="data row0 col3" >13.7891</td>
#       <td id="T_5dd93_row0_col4" class="data row0 col4" >0.1546</td>
#       <td id="T_5dd93_row0_col5" class="data row0 col5" >0.9662</td>
#       <td id="T_5dd93_row0_col6" class="data row0 col6" >2.4282</td>
#       <td id="T_5dd93_row0_col7" class="data row0 col7" >0.5435</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f2ebf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2ebf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f2ebf_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f2ebf_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f2ebf_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f2ebf_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f2ebf_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f2ebf_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f2ebf_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2ebf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2ebf_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_f2ebf_row0_col1" class="data row0 col1" >13.1406</td>
#       <td id="T_f2ebf_row0_col2" class="data row0 col2" >315.9076</td>
#       <td id="T_f2ebf_row0_col3" class="data row0 col3" >17.7738</td>
#       <td id="T_f2ebf_row0_col4" class="data row0 col4" >-0.4046</td>
#       <td id="T_f2ebf_row0_col5" class="data row0 col5" >1.1388</td>
#       <td id="T_f2ebf_row0_col6" class="data row0 col6" >2.3171</td>
#       <td id="T_f2ebf_row0_col7" class="data row0 col7" >0.0515</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_86753">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86753_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_86753_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_86753_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_86753_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_86753_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_86753_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_86753_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_86753_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86753_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86753_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_86753_row0_col1" class="data row0 col1" >11.2362</td>
#       <td id="T_86753_row0_col2" class="data row0 col2" >255.9252</td>
#       <td id="T_86753_row0_col3" class="data row0 col3" >15.9977</td>
#       <td id="T_86753_row0_col4" class="data row0 col4" >-0.1379</td>
#       <td id="T_86753_row0_col5" class="data row0 col5" >0.9976</td>
#       <td id="T_86753_row0_col6" class="data row0 col6" >2.0770</td>
#       <td id="T_86753_row0_col7" class="data row0 col7" >0.5064</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3b103">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b103_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3b103_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3b103_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3b103_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3b103_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3b103_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3b103_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3b103_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b103_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b103_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_3b103_row0_col1" class="data row0 col1" >10.2576</td>
#       <td id="T_3b103_row0_col2" class="data row0 col2" >304.9197</td>
#       <td id="T_3b103_row0_col3" class="data row0 col3" >17.4620</td>
#       <td id="T_3b103_row0_col4" class="data row0 col4" >-0.3557</td>
#       <td id="T_3b103_row0_col5" class="data row0 col5" >0.8382</td>
#       <td id="T_3b103_row0_col6" class="data row0 col6" >1.6082</td>
#       <td id="T_3b103_row0_col7" class="data row0 col7" >0.7701</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_cff81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cff81_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cff81_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cff81_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cff81_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cff81_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cff81_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cff81_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cff81_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cff81_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cff81_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_cff81_row0_col1" class="data row0 col1" >10.5972</td>
#       <td id="T_cff81_row0_col2" class="data row0 col2" >225.2064</td>
#       <td id="T_cff81_row0_col3" class="data row0 col3" >15.0069</td>
#       <td id="T_cff81_row0_col4" class="data row0 col4" >-0.0013</td>
#       <td id="T_cff81_row0_col5" class="data row0 col5" >1.0220</td>
#       <td id="T_cff81_row0_col6" class="data row0 col6" >1.8016</td>
#       <td id="T_cff81_row0_col7" class="data row0 col7" >0.3852</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_850f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_850f2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_850f2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_850f2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_850f2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_850f2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_850f2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_850f2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_850f2_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_850f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_850f2_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_850f2_row0_col1" class="data row0 col1" >15.9162</td>
#       <td id="T_850f2_row0_col2" class="data row0 col2" >1128.7836</td>
#       <td id="T_850f2_row0_col3" class="data row0 col3" >33.5974</td>
#       <td id="T_850f2_row0_col4" class="data row0 col4" >-4.0187</td>
#       <td id="T_850f2_row0_col5" class="data row0 col5" >1.0322</td>
#       <td id="T_850f2_row0_col6" class="data row0 col6" >1.0058</td>
#       <td id="T_850f2_row0_col7" class="data row0 col7" >0.6190</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9fde6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fde6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9fde6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9fde6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9fde6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9fde6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9fde6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9fde6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9fde6_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fde6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fde6_row0_col0" class="data row0 col0" >Passive Aggressive Regressor</td>
#       <td id="T_9fde6_row0_col1" class="data row0 col1" >16.3921</td>
#       <td id="T_9fde6_row0_col2" class="data row0 col2" >857.3976</td>
#       <td id="T_9fde6_row0_col3" class="data row0 col3" >29.2814</td>
#       <td id="T_9fde6_row0_col4" class="data row0 col4" >-2.8121</td>
#       <td id="T_9fde6_row0_col5" class="data row0 col5" >1.1645</td>
#       <td id="T_9fde6_row0_col6" class="data row0 col6" >2.4894</td>
#       <td id="T_9fde6_row0_col7" class="data row0 col7" >0.3125</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3ee0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ee0a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3ee0a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3ee0a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3ee0a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3ee0a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3ee0a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3ee0a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3ee0a_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ee0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ee0a_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_3ee0a_row0_col1" class="data row0 col1" >15.8792</td>
#       <td id="T_3ee0a_row0_col2" class="data row0 col2" >388.2278</td>
#       <td id="T_3ee0a_row0_col3" class="data row0 col3" >19.7035</td>
#       <td id="T_3ee0a_row0_col4" class="data row0 col4" >-0.7261</td>
#       <td id="T_3ee0a_row0_col5" class="data row0 col5" >1.2881</td>
#       <td id="T_3ee0a_row0_col6" class="data row0 col6" >4.3655</td>
#       <td id="T_3ee0a_row0_col7" class="data row0 col7" >0.3793</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_46f18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46f18_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_46f18_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_46f18_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_46f18_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_46f18_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_46f18_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_46f18_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_46f18_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46f18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46f18_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_46f18_row0_col1" class="data row0 col1" >15.8758</td>
#       <td id="T_46f18_row0_col2" class="data row0 col2" >403.2669</td>
#       <td id="T_46f18_row0_col3" class="data row0 col3" >20.0815</td>
#       <td id="T_46f18_row0_col4" class="data row0 col4" >-0.7930</td>
#       <td id="T_46f18_row0_col5" class="data row0 col5" >1.2958</td>
#       <td id="T_46f18_row0_col6" class="data row0 col6" >4.8665</td>
#       <td id="T_46f18_row0_col7" class="data row0 col7" >0.4559</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4222b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4222b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4222b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4222b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4222b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4222b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4222b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4222b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4222b_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4222b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4222b_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_4222b_row0_col1" class="data row0 col1" >15.8759</td>
#       <td id="T_4222b_row0_col2" class="data row0 col2" >403.2671</td>
#       <td id="T_4222b_row0_col3" class="data row0 col3" >20.0815</td>
#       <td id="T_4222b_row0_col4" class="data row0 col4" >-0.7930</td>
#       <td id="T_4222b_row0_col5" class="data row0 col5" >1.2958</td>
#       <td id="T_4222b_row0_col6" class="data row0 col6" >4.8666</td>
#       <td id="T_4222b_row0_col7" class="data row0 col7" >0.4559</td>
#     </tr>
#   </tbody>
# </table>
# Model: AdaBoostRegressor(random_state=1), Spearman Correlation: 0.7991238351089663
# Model: RandomForestRegressor(n_jobs=-1, random_state=1), Spearman Correlation: 0.7219485495347564
# Model: DummyRegressor(), Spearman Correlation: nan
# Model: GradientBoostingRegressor(random_state=1), Spearman Correlation: 0.7701149425287356
# Model: DecisionTreeRegressor(random_state=1), Spearman Correlation: 0.6190360485809107
# Model: ExtraTreesRegressor(n_jobs=-1, random_state=1), Spearman Correlation: 0.5626710454296661
# Model: LGBMRegressor(n_jobs=-1, random_state=1), Spearman Correlation: 0.5435139573070608
# Model: OrthogonalMatchingPursuit(), Spearman Correlation: 0.5063637655192589
# Model: BayesianRidge(), Spearman Correlation: 0.4920634920634921
# Model: LassoLars(random_state=1), Spearman Correlation: 0.4559386973180077
# Model: Lasso(random_state=1), Spearman Correlation: 0.4559386973180077
# Model: KNeighborsRegressor(n_jobs=-1), Spearman Correlation: 0.38521563823397276
# Model: ElasticNet(random_state=1), Spearman Correlation: 0.37931034482758613
# Model: PassiveAggressiveRegressor(random_state=1), Spearman Correlation: 0.31253420908593316
# Model: HuberRegressor(), Spearman Correlation: 0.051450465243568694

# %%
sorted_spearman_results
# Out:
# [(AdaBoostRegressor(random_state=1), 0.7991238351089663),
#  (RandomForestRegressor(n_jobs=-1, random_state=1), 0.7219485495347564),
#  (DummyRegressor(), nan),
#  (GradientBoostingRegressor(random_state=1), 0.7701149425287356),
#  (DecisionTreeRegressor(random_state=1), 0.6190360485809107),
#  (ExtraTreesRegressor(n_jobs=-1, random_state=1), 0.5626710454296661),
#  (LGBMRegressor(n_jobs=-1, random_state=1), 0.5435139573070608),
#  (OrthogonalMatchingPursuit(), 0.5063637655192589),
#  (BayesianRidge(), 0.4920634920634921),
#  (LassoLars(random_state=1), 0.4559386973180077),
#  (Lasso(random_state=1), 0.4559386973180077),
#  (KNeighborsRegressor(n_jobs=-1), 0.38521563823397276),
#  (ElasticNet(random_state=1), 0.37931034482758613),
#  (PassiveAggressiveRegressor(random_state=1), 0.31253420908593316),
#  (HuberRegressor(), 0.051450465243568694)]

# %%
# Get top model and save it:
best_scc_model = sorted_spearman_results[0][0]

# %%
# save out best_scc_model
save_model(best_scc_model, '/home/jrollins/cmipb-challenge/task1-2_best_scc_model.pkl')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['day_0_specimen_id', 'subject_id',
#                                               'age', 'day_0_IgG_PT',
#                                               'day_0_IgG_PRN', 'day_0_IgG_FHA',
#                                               'day_0_IgG1_PT', 'day_0_IgG1_PRN',
#                                               'day_0_IgG1_FHA',
#                                               'day_0_IgG1_FIM2/3',
#                                               'day_0_IgG1_TT', 'day_0_IgG1_DT',
#                                               'day_0_IgG1_OVA', 'day_0_IgG2_PT',
#                                               'day_0_IgG2_PRN', 'day_0_IgG2_FHA',
#                                               '...
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['specimen_type', 'ethnicity',
#                                               'race', 'dataset'],
#                                      transformer=OneHotEncoder(cols=['specimen_type',
#                                                                      'ethnicity',
#                                                                      'race',
#                                                                      'dataset'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('trained_model', AdaBoostRegressor(random_state=1))]),
#  '/home/jrollins/cmipb-challenge/task1-2_best_scc_model.pkl.pkl')

# %%
# Optimize the AdaBoost model
tuned_model = tune_model(best_scc_model, optimize='R2')
# Out:
# <style type="text/css">
# #T_8929c_row5_col0, #T_8929c_row5_col1, #T_8929c_row5_col2, #T_8929c_row5_col3, #T_8929c_row5_col4, #T_8929c_row5_col5, #T_8929c_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8929c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8929c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8929c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8929c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8929c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8929c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8929c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_8929c_level0_col6" class="col_heading level0 col6" >Spearman Correlation</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8929c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8929c_row0_col0" class="data row0 col0" >6.0123</td>
#       <td id="T_8929c_row0_col1" class="data row0 col1" >96.9703</td>
#       <td id="T_8929c_row0_col2" class="data row0 col2" >9.8474</td>
#       <td id="T_8929c_row0_col3" class="data row0 col3" >0.4554</td>
#       <td id="T_8929c_row0_col4" class="data row0 col4" >0.5920</td>
#       <td id="T_8929c_row0_col5" class="data row0 col5" >0.8164</td>
#       <td id="T_8929c_row0_col6" class="data row0 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8929c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8929c_row1_col0" class="data row1 col0" >8.5368</td>
#       <td id="T_8929c_row1_col1" class="data row1 col1" >288.5051</td>
#       <td id="T_8929c_row1_col2" class="data row1 col2" >16.9854</td>
#       <td id="T_8929c_row1_col3" class="data row1 col3" >-0.3545</td>
#       <td id="T_8929c_row1_col4" class="data row1 col4" >1.1287</td>
#       <td id="T_8929c_row1_col5" class="data row1 col5" >4.9657</td>
#       <td id="T_8929c_row1_col6" class="data row1 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8929c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8929c_row2_col0" class="data row2 col0" >15.9394</td>
#       <td id="T_8929c_row2_col1" class="data row2 col1" >1124.6020</td>
#       <td id="T_8929c_row2_col2" class="data row2 col2" >33.5351</td>
#       <td id="T_8929c_row2_col3" class="data row2 col3" >0.2293</td>
#       <td id="T_8929c_row2_col4" class="data row2 col4" >0.8739</td>
#       <td id="T_8929c_row2_col5" class="data row2 col5" >1.3954</td>
#       <td id="T_8929c_row2_col6" class="data row2 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8929c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8929c_row3_col0" class="data row3 col0" >4.8094</td>
#       <td id="T_8929c_row3_col1" class="data row3 col1" >41.2148</td>
#       <td id="T_8929c_row3_col2" class="data row3 col2" >6.4199</td>
#       <td id="T_8929c_row3_col3" class="data row3 col3" >0.6160</td>
#       <td id="T_8929c_row3_col4" class="data row3 col4" >0.8098</td>
#       <td id="T_8929c_row3_col5" class="data row3 col5" >2.5701</td>
#       <td id="T_8929c_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8929c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8929c_row4_col0" class="data row4 col0" >4.1713</td>
#       <td id="T_8929c_row4_col1" class="data row4 col1" >20.6261</td>
#       <td id="T_8929c_row4_col2" class="data row4 col2" >4.5416</td>
#       <td id="T_8929c_row4_col3" class="data row4 col3" >-1.2363</td>
#       <td id="T_8929c_row4_col4" class="data row4 col4" >0.8041</td>
#       <td id="T_8929c_row4_col5" class="data row4 col5" >1.8054</td>
#       <td id="T_8929c_row4_col6" class="data row4 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8929c_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_8929c_row5_col0" class="data row5 col0" >7.8938</td>
#       <td id="T_8929c_row5_col1" class="data row5 col1" >314.3837</td>
#       <td id="T_8929c_row5_col2" class="data row5 col2" >14.2659</td>
#       <td id="T_8929c_row5_col3" class="data row5 col3" >-0.0580</td>
#       <td id="T_8929c_row5_col4" class="data row5 col4" >0.8417</td>
#       <td id="T_8929c_row5_col5" class="data row5 col5" >2.3106</td>
#       <td id="T_8929c_row5_col6" class="data row5 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_8929c_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_8929c_row6_col0" class="data row6 col0" >4.2908</td>
#       <td id="T_8929c_row6_col1" class="data row6 col1" >416.0064</td>
#       <td id="T_8929c_row6_col2" class="data row6 col2" >10.5294</td>
#       <td id="T_8929c_row6_col3" class="data row6 col3" >0.6748</td>
#       <td id="T_8929c_row6_col4" class="data row6 col4" >0.1721</td>
#       <td id="T_8929c_row6_col5" class="data row6 col5" >1.4452</td>
#       <td id="T_8929c_row6_col6" class="data row6 col6" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
# Get the spearman correlation of the tuned model
predictions = predict_model(tuned_model)
spearman_corr = spearman_metric(predictions['FC_day_0_14_IgG_PT'], predictions['prediction_label'])
print(f"Tuned Model: {spearman_corr}, Spearman Correlation")
# Out:
# <style type="text/css">
# </style>
# <table id="T_64efd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64efd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_64efd_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_64efd_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_64efd_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_64efd_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_64efd_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_64efd_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_64efd_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64efd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64efd_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_64efd_row0_col1" class="data row0 col1" >8.0445</td>
#       <td id="T_64efd_row0_col2" class="data row0 col2" >162.3859</td>
#       <td id="T_64efd_row0_col3" class="data row0 col3" >12.7431</td>
#       <td id="T_64efd_row0_col4" class="data row0 col4" >0.2780</td>
#       <td id="T_64efd_row0_col5" class="data row0 col5" >0.7731</td>
#       <td id="T_64efd_row0_col6" class="data row0 col6" >1.2295</td>
#       <td id="T_64efd_row0_col7" class="data row0 col7" >0.7043</td>
#     </tr>
#   </tbody>
# </table>
# Tuned Model: 0.7042717375933771, Spearman Correlation

# %% [markdown]
# # Vincent's comparison code

# %%
import numpy as np
import pandas as pd
import catboost as cb
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.metrics import mean_squared_error, r2_score
from scipy.stats import spearmanr
from joblib import Parallel, delayed

# Load data
df = pd.read_csv("~/cmipb_challenge/vincent_files/training_abtier_normalized_processed.csv", index_col=0)
df = df[df['FC_day_0_14_IgG_PT'] >= 0]

features = ['infancy_vac', 'biological_sex', 'age', 'day_0_IgG_PT', 'day_0_IgG4_PRN', 'day_0_IgG1_PRN']
X = df[features]
y = df['FC_day_0_14_IgG_PT']
categorical_features_indices = np.where((X.dtypes != np.float64) & (X.dtypes != np.int64))[0]

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Define parameter grid
param_grid = {
    'iterations': [25, 50, 75],
    'learning_rate': [0.01, 0.03, 0.05],
    'depth': [2, 3, 4, 5, 6],
    'l2_leaf_reg': [0, 1]
}
parameter_grid = list(ParameterGrid(param_grid))

# Function to train and evaluate a model
def evaluate_model(params, X_train, y_train, X_test, y_test, cat_features):
    train_data = Pool(data=X_train, label=y_train, cat_features=cat_features)
    test_data = Pool(data=X_test, label=y_test, cat_features=cat_features)
    model = CatBoostRegressor(**params, loss_function='RMSE', verbose=False)
    model.fit(train_data)
    preds = model.predict(test_data)
    rmse = np.sqrt(mean_squared_error(y_test, preds))
    r2 = r2_score(y_test, preds)
    spearman_corr, _ = spearmanr(y_test, preds)
    return rmse, r2, spearman_corr, params

# Parallel execution of grid search
results = Parallel(n_jobs=100)(delayed(evaluate_model)(params, X_train, y_train, X_test, y_test, categorical_features_indices) for params in parameter_grid)

# Find the best parameters based on RMSE or another metric
best_result = min(results, key=lambda x: x[0])
print("Best RMSE:", best_result[0])
print("R2 Score:", best_result[1])
print("Spearman Correlation:", best_result[2])
print("Best Hyperparameters:", best_result[3])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/jrollins/cmipb-challenge/basemodels_11042024.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/basemodels_11042024.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import numpy as np
#       <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/basemodels_11042024.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import pandas as pd
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/basemodels_11042024.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> import catboost as cb
#       <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/basemodels_11042024.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> from catboost import CatBoostRegressor, Pool
#       <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/basemodels_11042024.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> from sklearn.model_selection import train_test_split, ParameterGrid
#
# File ~/miniforge3/lib/python3.12/site-packages/catboost/__init__.py:1
# ----> 1 from .core import (
#       2     FeaturesData, EFstrType, EShapCalcType, EFeaturesSelectionAlgorithm, EFeaturesSelectionGrouping,
#       3     Pool, CatBoost, CatBoostClassifier, CatBoostRegressor, CatBoostRanker, CatBoostError, cv, sample_gaussian_process, train,
#       4     sum_models, _have_equal_features, to_regressor, to_classifier, to_ranker, MultiRegressionCustomMetric,
#       5     MultiRegressionCustomObjective, MultiTargetCustomMetric, MultiTargetCustomObjective
#       6 )  # noqa
#       7 from .version import VERSION as __version__  # noqa
#       8 __all__ = [
#       9     'FeaturesData', 'EFstrType', 'EShapCalcType', 'EFeaturesSelectionAlgorithm', 'EFeaturesSelectionGrouping',
#      10     'Pool', 'CatBoost', 'CatBoostClassifier', 'CatBoostRegressor', 'CatBoostRanker', 'CatboostError',
#    (...)
#      13     'MultiTargetCustomMetric', 'MultiTargetCustomObjective'
#      14 ]
#
# File ~/miniforge3/lib/python3.12/site-packages/catboost/core.py:42
#      39     class Series(object):
#      40         pass
# ---> 42 import scipy.sparse
#      45 from .plot_helpers import save_plot_file, try_plot_offline, OfflineMetricVisualizer
#      46 from . import _catboost
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/sparse/__init__.py:293
#     287 # Original code by Travis Oliphant.
#     288 # Modified and extended by Ed Schofield, Robert Cimrman,
#     289 # Nathan Bell, and Jake Vanderplas.
#     291 import warnings as _warnings
# --> 293 from ._base import *
#     294 from ._csr import *
#     295 from ._csc import *
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/sparse/_base.py:5
#       1 """Base class for sparse matrices"""
#       3 import numpy as np
# ----> 5 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       6                        get_sum_dtype, isdense, isscalarlike,
#       7                        matrix, validateaxis,)
#       9 from ._matrix import spmatrix
#      11 __all__ = ['isspmatrix', 'issparse', 'sparray',
#      12            'SparseWarning', 'SparseEfficiencyWarning']
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/sparse/_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype']
#      16 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      17                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      18                     np.float32, np.float64, np.longdouble,
#      19                     np.complex64, np.complex128, np.clongdouble]
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/_lib/_util.py:18
#      10 from typing import (
#      11     Optional,
#      12     Union,
#      13     TYPE_CHECKING,
#      14     TypeVar,
#      15 )
#      17 import numpy as np
# ---> 18 from scipy._lib._array_api import array_namespace, is_numpy, size as xp_size
#      21 AxisError: type[Exception]
#      22 ComplexWarning: type[Warning]
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/_lib/_array_api.py:21
#      18 import numpy.typing as npt
#      20 from scipy._lib import array_api_compat
# ---> 21 from scipy._lib.array_api_compat import (
#      22     is_array_api_obj,
#      23     size,
#      24     numpy as np_compat,
#      25     device
#      26 )
#      28 __all__ = ['array_namespace', '_asarray', 'size', 'device']
#      31 # To enable array API and strict array-like input validation
#
# File ~/miniforge3/lib/python3.12/site-packages/scipy/_lib/array_api_compat/numpy/__init__.py:1
# ----> 1 from numpy import * # noqa: F403
#       3 # from numpy import * doesn't overwrite these builtin names
#       4 from numpy import abs, max, min, round # noqa: F401
#
# File ~/miniforge3/lib/python3.12/site-packages/numpy/__init__.py:379, in __getattr__(attr)
#     377 def _mac_os_check():
#     378     """
# --> 379     Quick Sanity check for Mac OS look for accelerate build bugs.
#     380     Testing numpy polyfit calls init_dgelsd(LAPACK)
#     381     """
#     382     try:
#     383         c = array([3., 2., 1.])
#
# ModuleNotFoundError: No module named 'numpy.strings'
