# %% [markdown]
# # Check features

# %%
import numpy as np
import pandas as pd
from pycaret.regression import *
from scipy.stats import spearmanr

# Load data to train with
df = pd.read_csv("/home/vmottaqi/cmipb_challenge/vincent_files/training_t_cell_processed_task4.1_nov5.csv", index_col=0)

# Load data to process
df = pd.read_csv('/home/vmottaqi/cmipb_challenge/challenge_data_processed/challenge_t_cell_processed_task4.1_nov11.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['day_0_specimen_id', 'subject_id', 'infancy_vac', 'biological_sex',
#        'dataset', 'age', 'day_0_IL17A_DMSO', 'day_0_IL17A_PHA',
#        'day_0_IL17A_PT', 'day_0_Th1_DMSO', 'day_0_Th1_PHA', 'day_0_Th1_PT',
#        'day_0_Th2_DMSO', 'day_0_Th2_PHA', 'day_0_Th2_PT',
#        'day_0_DMSO_activation', 'day_0_PHA_activation', 'day_0_PT_activation',
#        'day_0_TT_activation'],
#       dtype='object')

# %% [markdown]
# Use ['day_0_specimen_id', 'subject_id', 'infancy_vac', 'biological_sex',
#        'dataset', 'age', 'day_0_IL17A_DMSO', 'day_0_IL17A_PHA',
#        'day_0_IL17A_PT', 'day_0_Th1_DMSO', 'day_0_Th1_PHA', 'day_0_Th1_PT',
#        'day_0_Th2_DMSO', 'day_0_Th2_PHA', 'day_0_Th2_PT',
#        'day_0_DMSO_activation', 'day_0_PHA_activation', 'day_0_PT_activation',
#        'day_0_TT_activation']

# %%
sel_feat = ['day_0_Th2_PHA', 'day_0_IL17A_PT', 'biological_sex', 'day_0_Th2_PT', 'day_0_IL17A_PHA', 'day_0_Th1_PHA', 'day_0_Th1_PT', 'age', 'infancy_vac']

# %%
cat_feat = ['infancy_vac', 'biological_sex']

# %% [markdown]
# # Run models for task 4.1

# %%
import numpy as np
import pandas as pd
from pycaret.regression import *
from scipy.stats import spearmanr, rankdata

# Load data
df = pd.read_csv("/home/vmottaqi/cmipb_challenge/vincent_files/training_t_cell_processed_task4.1_nov5.csv", index_col=0)
df = df[df['FC_day_30_Th1/Th2'] >= 0]

# Define features and target
X = df[sel_feat]
y = df['FC_day_30_Th1/Th2']

# Combine features and target for PyCaret input
data = X.copy()
data['FC_day_30_Th1/Th2'] = y

# Initialize PyCaret with the dataset and target column
regression_setup = setup(
    data=data,
    target='FC_day_30_Th1/Th2',
    categorical_features=cat_feat,  # Specify any categorical features
    session_id=1,
    fold=5
)

# Custom Spearman correlation function with zero variance handling
def spearman_metric(y_true, y_pred):
    # Rank the data
    y_true_ranked = rankdata(y_true)
    y_pred_ranked = rankdata(y_pred)
    
    # Check for zero variance in ranks (constant values)
    if np.std(y_true_ranked) == 0 or np.std(y_pred_ranked) == 0:
        return np.nan  # If there's no variance, return NaN
    
    # Calculate Spearman correlation on ranked data
    return spearmanr(y_true_ranked, y_pred_ranked)[0]  # Only return the correlation coefficient

# Adding the custom Spearman metric
add_metric(
    'Spearman', 
    'Spearman Correlation', 
    spearman_metric, 
    greater_is_better=True
)

# Compare models using a supported metric (e.g., R2)
top_models = compare_models(sort='R2', n_select=15)  # Select top models based on R2, adjust as needed

# Calculate Spearman correlation for each top model
spearman_results = []
for model in top_models:
    predictions = predict_model(model)  # Get predictions
    
    # Identify the correct prediction column
    prediction_column = 'Label' if 'Label' in predictions.columns else predictions.columns[-1]
    
    # Calculate Spearman correlation, ensuring the target column exists in predictions
    if 'FC_day_30_Th1/Th2' in predictions.columns:
        spearman_corr = spearman_metric(predictions['FC_day_30_Th1/Th2'], predictions[prediction_column])
        spearman_results.append((model, spearman_corr))

# Sort and display models by Spearman correlation
sorted_spearman_results = sorted(spearman_results, key=lambda x: x[1] if x[1] is not None else -1, reverse=True)
for model, spearman_corr in sorted_spearman_results:
    print(f"Model: {model}, Spearman Correlation: {spearman_corr}")
# Out:
# <style type="text/css">
# #T_e4459_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e4459">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4459_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e4459_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4459_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4459_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e4459_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4459_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e4459_row1_col1" class="data row1 col1" >FC_day_30_Th1/Th2</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4459_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e4459_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4459_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e4459_row3_col1" class="data row3 col1" >(41, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e4459_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e4459_row4_col1" class="data row4 col1" >(41, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e4459_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e4459_row5_col1" class="data row5 col1" >(28, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e4459_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e4459_row6_col1" class="data row6 col1" >(13, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e4459_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e4459_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e4459_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_e4459_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e4459_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_e4459_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e4459_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_e4459_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e4459_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_e4459_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e4459_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_e4459_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e4459_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_e4459_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e4459_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_e4459_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e4459_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_e4459_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e4459_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_e4459_row16_col1" class="data row16 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e4459_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_e4459_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e4459_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_e4459_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e4459_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_e4459_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e4459_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_e4459_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e4459_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e4459_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_e4459_row21_col1" class="data row21 col1" >e431</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_037aa th {
#   text-align: left;
# }
# #T_037aa_row0_col0, #T_037aa_row0_col5, #T_037aa_row0_col6, #T_037aa_row1_col0, #T_037aa_row1_col5, #T_037aa_row1_col6, #T_037aa_row2_col0, #T_037aa_row2_col1, #T_037aa_row2_col2, #T_037aa_row2_col3, #T_037aa_row2_col4, #T_037aa_row2_col5, #T_037aa_row2_col6, #T_037aa_row3_col0, #T_037aa_row3_col1, #T_037aa_row3_col2, #T_037aa_row3_col3, #T_037aa_row3_col4, #T_037aa_row3_col5, #T_037aa_row3_col6, #T_037aa_row4_col0, #T_037aa_row4_col1, #T_037aa_row4_col2, #T_037aa_row4_col3, #T_037aa_row4_col4, #T_037aa_row4_col5, #T_037aa_row4_col6, #T_037aa_row5_col0, #T_037aa_row5_col1, #T_037aa_row5_col2, #T_037aa_row5_col3, #T_037aa_row5_col4, #T_037aa_row5_col5, #T_037aa_row5_col6, #T_037aa_row6_col0, #T_037aa_row6_col1, #T_037aa_row6_col2, #T_037aa_row6_col3, #T_037aa_row6_col4, #T_037aa_row6_col5, #T_037aa_row6_col6, #T_037aa_row7_col0, #T_037aa_row7_col1, #T_037aa_row7_col2, #T_037aa_row7_col3, #T_037aa_row7_col4, #T_037aa_row7_col5, #T_037aa_row7_col6, #T_037aa_row8_col0, #T_037aa_row8_col1, #T_037aa_row8_col2, #T_037aa_row8_col3, #T_037aa_row8_col4, #T_037aa_row8_col5, #T_037aa_row8_col6, #T_037aa_row9_col0, #T_037aa_row9_col1, #T_037aa_row9_col2, #T_037aa_row9_col3, #T_037aa_row9_col4, #T_037aa_row9_col5, #T_037aa_row9_col6, #T_037aa_row10_col0, #T_037aa_row10_col1, #T_037aa_row10_col2, #T_037aa_row10_col3, #T_037aa_row10_col4, #T_037aa_row10_col5, #T_037aa_row10_col6, #T_037aa_row11_col0, #T_037aa_row11_col1, #T_037aa_row11_col2, #T_037aa_row11_col3, #T_037aa_row11_col4, #T_037aa_row12_col0, #T_037aa_row12_col1, #T_037aa_row12_col2, #T_037aa_row12_col3, #T_037aa_row12_col4, #T_037aa_row12_col5, #T_037aa_row12_col6, #T_037aa_row13_col0, #T_037aa_row13_col1, #T_037aa_row13_col2, #T_037aa_row13_col3, #T_037aa_row13_col4, #T_037aa_row13_col5, #T_037aa_row13_col6, #T_037aa_row14_col0, #T_037aa_row14_col1, #T_037aa_row14_col2, #T_037aa_row14_col3, #T_037aa_row14_col4, #T_037aa_row14_col5, #T_037aa_row14_col6, #T_037aa_row15_col0, #T_037aa_row15_col1, #T_037aa_row15_col2, #T_037aa_row15_col3, #T_037aa_row15_col4, #T_037aa_row15_col5, #T_037aa_row15_col6, #T_037aa_row16_col0, #T_037aa_row16_col1, #T_037aa_row16_col2, #T_037aa_row16_col3, #T_037aa_row16_col4, #T_037aa_row16_col5, #T_037aa_row16_col6, #T_037aa_row17_col0, #T_037aa_row17_col1, #T_037aa_row17_col2, #T_037aa_row17_col3, #T_037aa_row17_col4, #T_037aa_row17_col5, #T_037aa_row17_col6 {
#   text-align: left;
# }
# #T_037aa_row0_col1, #T_037aa_row0_col2, #T_037aa_row0_col3, #T_037aa_row0_col4, #T_037aa_row0_col7, #T_037aa_row1_col1, #T_037aa_row1_col2, #T_037aa_row1_col3, #T_037aa_row1_col4, #T_037aa_row1_col7, #T_037aa_row2_col7, #T_037aa_row3_col7, #T_037aa_row4_col7, #T_037aa_row5_col7, #T_037aa_row6_col7, #T_037aa_row7_col7, #T_037aa_row8_col7, #T_037aa_row9_col7, #T_037aa_row10_col7, #T_037aa_row11_col5, #T_037aa_row11_col6, #T_037aa_row11_col7, #T_037aa_row12_col7, #T_037aa_row13_col7, #T_037aa_row14_col7, #T_037aa_row15_col7, #T_037aa_row16_col7, #T_037aa_row17_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_037aa_row0_col8, #T_037aa_row1_col8, #T_037aa_row2_col8, #T_037aa_row3_col8, #T_037aa_row4_col8, #T_037aa_row5_col8, #T_037aa_row6_col8, #T_037aa_row7_col8, #T_037aa_row8_col8, #T_037aa_row9_col8, #T_037aa_row10_col8, #T_037aa_row12_col8, #T_037aa_row13_col8, #T_037aa_row14_col8, #T_037aa_row15_col8, #T_037aa_row16_col8, #T_037aa_row17_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_037aa_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_037aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_037aa_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_037aa_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_037aa_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_037aa_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_037aa_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_037aa_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_037aa_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_037aa_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#       <th id="T_037aa_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_037aa_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_037aa_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_037aa_row0_col1" class="data row0 col1" >4.8184</td>
#       <td id="T_037aa_row0_col2" class="data row0 col2" >44.5722</td>
#       <td id="T_037aa_row0_col3" class="data row0 col3" >6.3610</td>
#       <td id="T_037aa_row0_col4" class="data row0 col4" >-0.3762</td>
#       <td id="T_037aa_row0_col5" class="data row0 col5" >1.1133</td>
#       <td id="T_037aa_row0_col6" class="data row0 col6" >403.6571</td>
#       <td id="T_037aa_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_037aa_row0_col8" class="data row0 col8" >0.1020</td>
#     </tr>
#     <tr>
#       <th id="T_037aa_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_037aa_row1_col0" class="data row1 col0" >Dummy Regressor</td>
#       <td id="T_037aa_row1_col1" class="data row1 col1" >4.8184</td>
#       <td id="T_037aa_row1_col2" class="data row1 col2" >44.5722</td>
#       <td id="T_037aa_row1_col3" class="data row1 col3" >6.3610</td>
#       <td id="T_037aa_row1_col4" class="data row1 col4" >-0.3762</td>
#       <td id="T_037aa_row1_col5" class="data row1 col5" >1.1133</td>
#       <td id="T_037aa_row1_col6" class="data row1 col6" >403.6571</td>
#       <td id="T_037aa_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_037aa_row1_col8" class="data row1 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_037aa_level0_row2" class="row_heading level0 row2" >omp</th>
#       <td id="T_037aa_row2_col0" class="data row2 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_037aa_row2_col1" class="data row2 col1" >5.0767</td>
#       <td id="T_037aa_row2_col2" class="data row2 col2" >51.7874</td>
#       <td id="T_037aa_row2_col3" class="data row2 col3" >6.6579</td>
#       <td id="T_037aa_row2_col4" class="data row2 col4" >-0.3890</td>
#       <td id="T_037aa_row2_col5" class="data row2 col5" >1.1429</td>
#       <td id="T_037aa_row2_col6" class="data row2 col6" >887.4784</td>
#       <td id="T_037aa_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_037aa_row2_col8" class="data row2 col8" >0.2040</td>
#     </tr>
#     <tr>
#       <th id="T_037aa_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_037aa_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_037aa_row3_col1" class="data row3 col1" >5.0203</td>
#       <td id="T_037aa_row3_col2" class="data row3 col2" >56.0410</td>
#       <td id="T_037aa_row3_col3" class="data row3 col3" >6.8178</td>
#       <td id="T_037aa_row3_col4" class="data row3 col4" >-0.4404</td>
#       <td id="T_037aa_row3_col5" class="data row3 col5" >1.1807</td>
#       <td id="T_037aa_row3_col6" class="data row3 col6" >363.7226</td>
#       <td id="T_037aa_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_037aa_row3_col8" class="data row3 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_037aa_level0_row4" class="row_heading level0 row4" >en</th>
#       <td id="T_037aa_row4_col0" class="data row4 col0" >Elastic Net</td>
#       <td id="T_037aa_row4_col1" class="data row4 col1" >5.4421</td>
#       <td id="T_037aa_row4_col2" class="data row4 col2" >56.5869</td>
#       <td id="T_037aa_row4_col3" class="data row4 col3" >6.9423</td>
#       <td id="T_037aa_row4_col4" class="data row4 col4" >-0.4614</td>
#       <td id="T_037aa_row4_col5" class="data row4 col5" >1.2003</td>
#       <td id="T_037aa_row4_col6" class="data row4 col6" >653.6781</td>
#       <td id="T_037aa_row4_col7" cl
# <style type="text/css">
# </style>
# <table id="T_9cfcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cfcf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9cfcf_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9cfcf_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9cfcf_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9cfcf_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9cfcf_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9cfcf_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9cfcf_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cfcf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9cfcf_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9cfcf_row0_col1" class="data row0 col1" >7.4093</td>
#       <td id="T_9cfcf_row0_col2" class="data row0 col2" >115.6577</td>
#       <td id="T_9cfcf_row0_col3" class="data row0 col3" >10.7544</td>
#       <td id="T_9cfcf_row0_col4" class="data row0 col4" >-0.0728</td>
#       <td id="T_9cfcf_row0_col5" class="data row0 col5" >1.2021</td>
#       <td id="T_9cfcf_row0_col6" class="data row0 col6" >13.5925</td>
#       <td id="T_9cfcf_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6b080">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b080_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6b080_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6b080_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6b080_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6b080_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6b080_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6b080_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6b080_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b080_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b080_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_6b080_row0_col1" class="data row0 col1" >7.4093</td>
#       <td id="T_6b080_row0_col2" class="data row0 col2" >115.6577</td>
#       <td id="T_6b080_row0_col3" class="data row0 col3" >10.7544</td>
#       <td id="T_6b080_row0_col4" class="data row0 col4" >-0.0728</td>
#       <td id="T_6b080_row0_col5" class="data row0 col5" >1.2021</td>
#       <td id="T_6b080_row0_col6" class="data row0 col6" >13.5925</td>
#       <td id="T_6b080_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_17a9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17a9a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_17a9a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_17a9a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_17a9a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_17a9a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_17a9a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_17a9a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_17a9a_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17a9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17a9a_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_17a9a_row0_col1" class="data row0 col1" >7.3990</td>
#       <td id="T_17a9a_row0_col2" class="data row0 col2" >126.5555</td>
#       <td id="T_17a9a_row0_col3" class="data row0 col3" >11.2497</td>
#       <td id="T_17a9a_row0_col4" class="data row0 col4" >-0.1739</td>
#       <td id="T_17a9a_row0_col5" class="data row0 col5" >1.2055</td>
#       <td id="T_17a9a_row0_col6" class="data row0 col6" >10.7477</td>
#       <td id="T_17a9a_row0_col7" class="data row0 col7" >0.1018</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7f202">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f202_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7f202_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7f202_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7f202_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7f202_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7f202_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7f202_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7f202_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f202_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f202_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_7f202_row0_col1" class="data row0 col1" >7.2423</td>
#       <td id="T_7f202_row0_col2" class="data row0 col2" >115.5199</td>
#       <td id="T_7f202_row0_col3" class="data row0 col3" >10.7480</td>
#       <td id="T_7f202_row0_col4" class="data row0 col4" >-0.0716</td>
#       <td id="T_7f202_row0_col5" class="data row0 col5" >1.0813</td>
#       <td id="T_7f202_row0_col6" class="data row0 col6" >5.3663</td>
#       <td id="T_7f202_row0_col7" class="data row0 col7" >0.4066</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_80ca4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80ca4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_80ca4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_80ca4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_80ca4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_80ca4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_80ca4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_80ca4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_80ca4_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80ca4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80ca4_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_80ca4_row0_col1" class="data row0 col1" >7.0899</td>
#       <td id="T_80ca4_row0_col2" class="data row0 col2" >118.4627</td>
#       <td id="T_80ca4_row0_col3" class="data row0 col3" >10.8841</td>
#       <td id="T_80ca4_row0_col4" class="data row0 col4" >-0.0989</td>
#       <td id="T_80ca4_row0_col5" class="data row0 col5" >1.1046</td>
#       <td id="T_80ca4_row0_col6" class="data row0 col6" >8.9562</td>
#       <td id="T_80ca4_row0_col7" class="data row0 col7" >0.4615</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e47b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e47b3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e47b3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e47b3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e47b3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e47b3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e47b3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e47b3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e47b3_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e47b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e47b3_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_e47b3_row0_col1" class="data row0 col1" >7.0538</td>
#       <td id="T_e47b3_row0_col2" class="data row0 col2" >117.7586</td>
#       <td id="T_e47b3_row0_col3" class="data row0 col3" >10.8517</td>
#       <td id="T_e47b3_row0_col4" class="data row0 col4" >-0.0923</td>
#       <td id="T_e47b3_row0_col5" class="data row0 col5" >1.1079</td>
#       <td id="T_e47b3_row0_col6" class="data row0 col6" >9.7627</td>
#       <td id="T_e47b3_row0_col7" class="data row0 col7" >0.4341</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ec5b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec5b3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ec5b3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ec5b3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ec5b3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ec5b3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ec5b3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ec5b3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ec5b3_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec5b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec5b3_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_ec5b3_row0_col1" class="data row0 col1" >7.0538</td>
#       <td id="T_ec5b3_row0_col2" class="data row0 col2" >117.7586</td>
#       <td id="T_ec5b3_row0_col3" class="data row0 col3" >10.8517</td>
#       <td id="T_ec5b3_row0_col4" class="data row0 col4" >-0.0923</td>
#       <td id="T_ec5b3_row0_col5" class="data row0 col5" >1.1079</td>
#       <td id="T_ec5b3_row0_col6" class="data row0 col6" >9.7627</td>
#       <td id="T_ec5b3_row0_col7" class="data row0 col7" >0.4341</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7c113">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c113_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7c113_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7c113_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7c113_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7c113_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7c113_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7c113_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7c113_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c113_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c113_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_7c113_row0_col1" class="data row0 col1" >7.3513</td>
#       <td id="T_7c113_row0_col2" class="data row0 col2" >114.9071</td>
#       <td id="T_7c113_row0_col3" class="data row0 col3" >10.7195</td>
#       <td id="T_7c113_row0_col4" class="data row0 col4" >-0.0659</td>
#       <td id="T_7c113_row0_col5" class="data row0 col5" >1.1783</td>
#       <td id="T_7c113_row0_col6" class="data row0 col6" >12.7497</td>
#       <td id="T_7c113_row0_col7" class="data row0 col7" >0.3901</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4ab90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ab90_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4ab90_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4ab90_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4ab90_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4ab90_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4ab90_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4ab90_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4ab90_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ab90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ab90_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_4ab90_row0_col1" class="data row0 col1" >7.7493</td>
#       <td id="T_4ab90_row0_col2" class="data row0 col2" >120.1216</td>
#       <td id="T_4ab90_row0_col3" class="data row0 col3" >10.9600</td>
#       <td id="T_4ab90_row0_col4" class="data row0 col4" >-0.1143</td>
#       <td id="T_4ab90_row0_col5" class="data row0 col5" >1.1828</td>
#       <td id="T_4ab90_row0_col6" class="data row0 col6" >7.6785</td>
#       <td id="T_4ab90_row0_col7" class="data row0 col7" >0.3022</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_5be46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5be46_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5be46_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5be46_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5be46_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5be46_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5be46_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5be46_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5be46_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5be46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5be46_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_5be46_row0_col1" class="data row0 col1" >7.0453</td>
#       <td id="T_5be46_row0_col2" class="data row0 col2" >123.0997</td>
#       <td id="T_5be46_row0_col3" class="data row0 col3" >11.0950</td>
#       <td id="T_5be46_row0_col4" class="data row0 col4" >-0.1419</td>
#       <td id="T_5be46_row0_col5" class="data row0 col5" >1.1590</td>
#       <td id="T_5be46_row0_col6" class="data row0 col6" >3.1242</td>
#       <td id="T_5be46_row0_col7" class="data row0 col7" >0.4890</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c1e11">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1e11_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c1e11_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c1e11_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c1e11_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c1e11_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c1e11_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c1e11_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c1e11_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1e11_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1e11_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_c1e11_row0_col1" class="data row0 col1" >6.6826</td>
#       <td id="T_c1e11_row0_col2" class="data row0 col2" >101.4000</td>
#       <td id="T_c1e11_row0_col3" class="data row0 col3" >10.0698</td>
#       <td id="T_c1e11_row0_col4" class="data row0 col4" >0.0594</td>
#       <td id="T_c1e11_row0_col5" class="data row0 col5" >1.0473</td>
#       <td id="T_c1e11_row0_col6" class="data row0 col6" >12.5123</td>
#       <td id="T_c1e11_row0_col7" class="data row0 col7" >0.4343</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_84fee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84fee_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_84fee_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_84fee_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_84fee_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_84fee_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_84fee_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_84fee_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_84fee_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84fee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84fee_row0_col0" class="data row0 col0" >Passive Aggressive Regressor</td>
#       <td id="T_84fee_row0_col1" class="data row0 col1" >7.1495</td>
#       <td id="T_84fee_row0_col2" class="data row0 col2" >143.3104</td>
#       <td id="T_84fee_row0_col3" class="data row0 col3" >11.9712</td>
#       <td id="T_84fee_row0_col4" class="data row0 col4" >-0.3294</td>
#       <td id="T_84fee_row0_col5" class="data row0 col5" >1.3398</td>
#       <td id="T_84fee_row0_col6" class="data row0 col6" >2.4277</td>
#       <td id="T_84fee_row0_col7" class="data row0 col7" >0.3626</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_a4ba5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4ba5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a4ba5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a4ba5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a4ba5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a4ba5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a4ba5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a4ba5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a4ba5_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4ba5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4ba5_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_a4ba5_row0_col1" class="data row0 col1" >8.0102</td>
#       <td id="T_a4ba5_row0_col2" class="data row0 col2" >121.7924</td>
#       <td id="T_a4ba5_row0_col3" class="data row0 col3" >11.0360</td>
#       <td id="T_a4ba5_row0_col4" class="data row0 col4" >-0.1298</td>
#       <td id="T_a4ba5_row0_col5" class="data row0 col5" >1.2302</td>
#       <td id="T_a4ba5_row0_col6" class="data row0 col6" >8.2973</td>
#       <td id="T_a4ba5_row0_col7" class="data row0 col7" >0.1758</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e3a69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3a69_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e3a69_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e3a69_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e3a69_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e3a69_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e3a69_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e3a69_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e3a69_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3a69_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3a69_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_e3a69_row0_col1" class="data row0 col1" >7.9448</td>
#       <td id="T_e3a69_row0_col2" class="data row0 col2" >144.5561</td>
#       <td id="T_e3a69_row0_col3" class="data row0 col3" >12.0231</td>
#       <td id="T_e3a69_row0_col4" class="data row0 col4" >-0.3409</td>
#       <td id="T_e3a69_row0_col5" class="data row0 col5" >1.3520</td>
#       <td id="T_e3a69_row0_col6" class="data row0 col6" >3.7241</td>
#       <td id="T_e3a69_row0_col7" class="data row0 col7" >0.0165</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7c9df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c9df_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7c9df_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7c9df_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7c9df_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7c9df_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7c9df_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7c9df_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7c9df_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c9df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c9df_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_7c9df_row0_col1" class="data row0 col1" >5.9309</td>
#       <td id="T_7c9df_row0_col2" class="data row0 col2" >106.4564</td>
#       <td id="T_7c9df_row0_col3" class="data row0 col3" >10.3178</td>
#       <td id="T_7c9df_row0_col4" class="data row0 col4" >0.0125</td>
#       <td id="T_7c9df_row0_col5" class="data row0 col5" >0.9940</td>
#       <td id="T_7c9df_row0_col6" class="data row0 col6" >5.1086</td>
#       <td id="T_7c9df_row0_col7" class="data row0 col7" >0.5207</td>
#     </tr>
#   </tbody>
# </table>
# Model: LGBMRegressor(n_jobs=-1, random_state=1), Spearman Correlation: nan
# Model: DummyRegressor(), Spearman Correlation: nan
# Model: AdaBoostRegressor(random_state=1), Spearman Correlation: 0.5206631326947936
# Model: GradientBoostingRegressor(random_state=1), Spearman Correlation: 0.48901098901098894
# Model: ElasticNet(random_state=1), Spearman Correlation: 0.46153846153846156
# Model: KNeighborsRegressor(n_jobs=-1), Spearman Correlation: 0.4343119072478333
# Model: Lasso(random_state=1), Spearman Correlation: 0.4340659340659341
# Model: LassoLars(random_state=1), Spearman Correlation: 0.4340659340659341
# Model: RandomForestRegressor(n_jobs=-1, random_state=1), Spearman Correlation: 0.40659340659340654
# Model: BayesianRidge(), Spearman Correlation: 0.39010989010989006
# Model: PassiveAggressiveRegressor(random_state=1), Spearman Correlation: 0.3626373626373627
# Model: Ridge(random_state=1), Spearman Correlation: 0.3021978021978022
# Model: LinearRegression(n_jobs=-1), Spearman Correlation: 0.1758241758241758
# Model: OrthogonalMatchingPursuit(), Spearman Correlation: 0.10178826685793495
# Model: HuberRegressor(), Spearman Correlation: 0.016483516483516484

# %%
# Check the pearson correlation of predictions
pearson_results = []
for model in top_models:
    predictions = predict_model(model)  # Get predictions
    
    # Identify the correct prediction column
    prediction_column = 'Label' if 'Label' in predictions.columns else predictions.columns[-1]
    
    # Calculate Spearman correlation
    pearson_corr = np.corrcoef(predictions['FC_day_30_Th1/Th2'], predictions[prediction_column])[0,1]
    pearson_results.append((model, pearson_corr))
    
    # Print Spearman correlation
    print(f"Model: {model}, Pearson Correlation: {pearson_corr}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_cc460">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc460_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cc460_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cc460_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cc460_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cc460_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cc460_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cc460_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cc460_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc460_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc460_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cc460_row0_col1" class="data row0 col1" >7.4093</td>
#       <td id="T_cc460_row0_col2" class="data row0 col2" >115.6577</td>
#       <td id="T_cc460_row0_col3" class="data row0 col3" >10.7544</td>
#       <td id="T_cc460_row0_col4" class="data row0 col4" >-0.0728</td>
#       <td id="T_cc460_row0_col5" class="data row0 col5" >1.2021</td>
#       <td id="T_cc460_row0_col6" class="data row0 col6" >13.5925</td>
#       <td id="T_cc460_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Model: LGBMRegressor(n_jobs=-1, random_state=1), Pearson Correlation: nan
# <style type="text/css">
# </style>
# <table id="T_d6f6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6f6f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d6f6f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d6f6f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d6f6f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d6f6f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d6f6f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d6f6f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d6f6f_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6f6f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6f6f_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_d6f6f_row0_col1" class="data row0 col1" >7.4093</td>
#       <td id="T_d6f6f_row0_col2" class="data row0 col2" >115.6577</td>
#       <td id="T_d6f6f_row0_col3" class="data row0 col3" >10.7544</td>
#       <td id="T_d6f6f_row0_col4" class="data row0 col4" >-0.0728</td>
#       <td id="T_d6f6f_row0_col5" class="data row0 col5" >1.2021</td>
#       <td id="T_d6f6f_row0_col6" class="data row0 col6" >13.5925</td>
#       <td id="T_d6f6f_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Model: DummyRegressor(), Pearson Correlation: nan
# <style type="text/css">
# </style>
# <table id="T_14164">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14164_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_14164_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_14164_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_14164_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_14164_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_14164_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_14164_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_14164_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14164_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14164_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_14164_row0_col1" class="data row0 col1" >7.3990</td>
#       <td id="T_14164_row0_col2" class="data row0 col2" >126.5555</td>
#       <td id="T_14164_row0_col3" class="data row0 col3" >11.2497</td>
#       <td id="T_14164_row0_col4" class="data row0 col4" >-0.1739</td>
#       <td id="T_14164_row0_col5" class="data row0 col5" >1.2055</td>
#       <td id="T_14164_row0_col6" class="data row0 col6" >10.7477</td>
#       <td id="T_14164_row0_col7" class="data row0 col7" >0.1018</td>
#     </tr>
#   </tbody>
# </table>
# Model: OrthogonalMatchingPursuit(), Pearson Correlation: -0.15006006125336813
# <style type="text/css">
# </style>
# <table id="T_07215">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07215_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_07215_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_07215_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_07215_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_07215_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_07215_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_07215_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_07215_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07215_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07215_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_07215_row0_col1" class="data row0 col1" >7.2423</td>
#       <td id="T_07215_row0_col2" class="data row0 col2" >115.5199</td>
#       <td id="T_07215_row0_col3" class="data row0 col3" >10.7480</td>
#       <td id="T_07215_row0_col4" class="data row0 col4" >-0.0716</td>
#       <td id="T_07215_row0_col5" class="data row0 col5" >1.0813</td>
#       <td id="T_07215_row0_col6" class="data row0 col6" >5.3663</td>
#       <td id="T_07215_row0_col7" class="data row0 col7" >0.4066</td>
#     </tr>
#   </tbody>
# </table>
# Model: RandomForestRegressor(n_jobs=-1, random_state=1), Pearson Correlation: 0.16983301845179918
# <style type="text/css">
# </style>
# <table id="T_48744">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48744_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_48744_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_48744_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_48744_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_48744_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_48744_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_48744_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_48744_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48744_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48744_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_48744_row0_col1" class="data row0 col1" >7.0899</td>
#       <td id="T_48744_row0_col2" class="data row0 col2" >118.4627</td>
#       <td id="T_48744_row0_col3" class="data row0 col3" >10.8841</td>
#       <td id="T_48744_row0_col4" class="data row0 col4" >-0.0989</td>
#       <td id="T_48744_row0_col5" class="data row0 col5" >1.1046</td>
#       <td id="T_48744_row0_col6" class="data row0 col6" >8.9562</td>
#       <td id="T_48744_row0_col7" class="data row0 col7" >0.4615</td>
#     </tr>
#   </tbody>
# </table>
# Model: ElasticNet(random_state=1), Pearson Correlation: 0.09694969170216512
# <style type="text/css">
# </style>
# <table id="T_85f13">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85f13_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_85f13_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_85f13_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_85f13_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_85f13_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_85f13_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_85f13_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_85f13_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85f13_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85f13_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_85f13_row0_col1" class="data row0 col1" >7.0538</td>
#       <td id="T_85f13_row0_col2" class="data row0 col2" >117.7586</td>
#       <td id="T_85f13_row0_col3" class="data row0 col3" >10.8517</td>
#       <td id="T_85f13_row0_col4" class="data row0 col4" >-0.0923</td>
#       <td id="T_85f13_row0_col5" class="data row0 col5" >1.1079</td>
#       <td id="T_85f13_row0_col6" class="data row0 col6" >9.7627</td>
#       <td id="T_85f13_row0_col7" class="data row0 col7" >0.4341</td>
#     </tr>
#   </tbody>
# </table>
# Model: Lasso(random_state=1), Pearson Correlation: 0.10512960224647364
# <style type="text/css">
# </style>
# <table id="T_4d1e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d1e2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4d1e2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4d1e2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4d1e2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4d1e2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4d1e2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4d1e2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4d1e2_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d1e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4d1e2_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_4d1e2_row0_col1" class="data row0 col1" >7.0538</td>
#       <td id="T_4d1e2_row0_col2" class="data row0 col2" >117.7586</td>
#       <td id="T_4d1e2_row0_col3" class="data row0 col3" >10.8517</td>
#       <td id="T_4d1e2_row0_col4" class="data row0 col4" >-0.0923</td>
#       <td id="T_4d1e2_row0_col5" class="data row0 col5" >1.1079</td>
#       <td id="T_4d1e2_row0_col6" class="data row0 col6" >9.7627</td>
#       <td id="T_4d1e2_row0_col7" class="data row0 col7" >0.4341</td>
#     </tr>
#   </tbody>
# </table>
# Model: LassoLars(random_state=1), Pearson Correlation: 0.10512948069804548
# <style type="text/css">
# </style>
# <table id="T_7b48d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b48d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7b48d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7b48d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7b48d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7b48d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7b48d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7b48d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7b48d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b48d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b48d_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_7b48d_row0_col1" class="data row0 col1" >7.3513</td>
#       <td id="T_7b48d_row0_col2" class="data row0 col2" >114.9071</td>
#       <td id="T_7b48d_row0_col3" class="data row0 col3" >10.7195</td>
#       <td id="T_7b48d_row0_col4" class="data row0 col4" >-0.0659</td>
#       <td id="T_7b48d_row0_col5" class="data row0 col5" >1.1783</td>
#       <td id="T_7b48d_row0_col6" class="data row0 col6" >12.7497</td>
#       <td id="T_7b48d_row0_col7" class="data row0 col7" >0.3901</td>
#     </tr>
#   </tbody>
# </table>
# Model: BayesianRidge(), Pearson Correlation: 0.10851318390831553
# <style type="text/css">
# </style>
# <table id="T_b06ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b06ed_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b06ed_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b06ed_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b06ed_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b06ed_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b06ed_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b06ed_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_b06ed_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b06ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b06ed_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_b06ed_row0_col1" class="data row0 col1" >7.7493</td>
#       <td id="T_b06ed_row0_col2" class="data row0 col2" >120.1216</td>
#       <td id="T_b06ed_row0_col3" class="data row0 col3" >10.9600</td>
#       <td id="T_b06ed_row0_col4" class="data row0 col4" >-0.1143</td>
#       <td id="T_b06ed_row0_col5" class="data row0 col5" >1.1828</td>
#       <td id="T_b06ed_row0_col6" class="data row0 col6" >7.6785</td>
#       <td id="T_b06ed_row0_col7" class="data row0 col7" >0.3022</td>
#     </tr>
#   </tbody>
# </table>
# Model: Ridge(random_state=1), Pearson Correlation: 0.06619237333446101
# <style type="text/css">
# </style>
# <table id="T_cbf45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbf45_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cbf45_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cbf45_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cbf45_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cbf45_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cbf45_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cbf45_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cbf45_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbf45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbf45_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_cbf45_row0_col1" class="data row0 col1" >7.0453</td>
#       <td id="T_cbf45_row0_col2" class="data row0 col2" >123.0997</td>
#       <td id="T_cbf45_row0_col3" class="data row0 col3" >11.0950</td>
#       <td id="T_cbf45_row0_col4" class="data row0 col4" >-0.1419</td>
#       <td id="T_cbf45_row0_col5" class="data row0 col5" >1.1590</td>
#       <td id="T_cbf45_row0_col6" class="data row0 col6" >3.1242</td>
#       <td id="T_cbf45_row0_col7" class="data row0 col7" >0.4890</td>
#     </tr>
#   </tbody>
# </table>
# Model: GradientBoostingRegressor(random_state=1), Pearson Correlation: 0.18740420793967247
# <style type="text/css">
# </style>
# <table id="T_22815">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22815_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_22815_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_22815_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_22815_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_22815_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_22815_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_22815_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_22815_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22815_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22815_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_22815_row0_col1" class="data row0 col1" >6.6826</td>
#       <td id="T_22815_row0_col2" class="data row0 col2" >101.4000</td>
#       <td id="T_22815_row0_col3" class="data row0 col3" >10.0698</td>
#       <td id="T_22815_row0_col4" class="data row0 col4" >0.0594</td>
#       <td id="T_22815_row0_col5" class="data row0 col5" >1.0473</td>
#       <td id="T_22815_row0_col6" class="data row0 col6" >12.5123</td>
#       <td id="T_22815_row0_col7" class="data row0 col7" >0.4343</td>
#     </tr>
#   </tbody>
# </table>
# Model: KNeighborsRegressor(n_jobs=-1), Pearson Correlation: 0.528370563557106
# <style type="text/css">
# </style>
# <table id="T_9ce92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ce92_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9ce92_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9ce92_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9ce92_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9ce92_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9ce92_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9ce92_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9ce92_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ce92_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ce92_row0_col0" class="data row0 col0" >Passive Aggressive Regressor</td>
#       <td id="T_9ce92_row0_col1" class="data row0 col1" >7.1495</td>
#       <td id="T_9ce92_row0_col2" class="data row0 col2" >143.3104</td>
#       <td id="T_9ce92_row0_col3" class="data row0 col3" >11.9712</td>
#       <td id="T_9ce92_row0_col4" class="data row0 col4" >-0.3294</td>
#       <td id="T_9ce92_row0_col5" class="data row0 col5" >1.3398</td>
#       <td id="T_9ce92_row0_col6" class="data row0 col6" >2.4277</td>
#       <td id="T_9ce92_row0_col7" class="data row0 col7" >0.3626</td>
#     </tr>
#   </tbody>
# </table>
# Model: PassiveAggressiveRegressor(random_state=1), Pearson Correlation: 0.2069168707638107
# <style type="text/css">
# </style>
# <table id="T_fae30">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fae30_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fae30_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fae30_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fae30_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fae30_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fae30_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fae30_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fae30_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fae30_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fae30_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_fae30_row0_col1" class="data row0 col1" >8.0102</td>
#       <td id="T_fae30_row0_col2" class="data row0 col2" >121.7924</td>
#       <td id="T_fae30_row0_col3" class="data row0 col3" >11.0360</td>
#       <td id="T_fae30_row0_col4" class="data row0 col4" >-0.1298</td>
#       <td id="T_fae30_row0_col5" class="data row0 col5" >1.2302</td>
#       <td id="T_fae30_row0_col6" class="data row0 col6" >8.2973</td>
#       <td id="T_fae30_row0_col7" class="data row0 col7" >0.1758</td>
#     </tr>
#   </tbody>
# </table>
# Model: LinearRegression(n_jobs=-1), Pearson Correlation: 0.030535247252223164
# <style type="text/css">
# </style>
# <table id="T_1a781">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a781_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1a781_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1a781_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1a781_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1a781_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1a781_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1a781_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1a781_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a781_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a781_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_1a781_row0_col1" class="data row0 col1" >7.9448</td>
#       <td id="T_1a781_row0_col2" class="data row0 col2" >144.5561</td>
#       <td id="T_1a781_row0_col3" class="data row0 col3" >12.0231</td>
#       <td id="T_1a781_row0_col4" class="data row0 col4" >-0.3409</td>
#       <td id="T_1a781_row0_col5" class="data row0 col5" >1.3520</td>
#       <td id="T_1a781_row0_col6" class="data row0 col6" >3.7241</td>
#       <td id="T_1a781_row0_col7" class="data row0 col7" >0.0165</td>
#     </tr>
#   </tbody>
# </table>
# Model: HuberRegressor(), Pearson Correlation: -0.11884463803987726
# <style type="text/css">
# </style>
# <table id="T_71c35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71c35_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_71c35_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_71c35_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_71c35_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_71c35_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_71c35_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_71c35_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_71c35_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71c35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71c35_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_71c35_row0_col1" class="data row0 col1" >5.9309</td>
#       <td id="T_71c35_row0_col2" class="data row0 col2" >106.4564</td>
#       <td id="T_71c35_row0_col3" class="data row0 col3" >10.3178</td>
#       <td id="T_71c35_row0_col4" class="data row0 col4" >0.0125</td>
#       <td id="T_71c35_row0_col5" class="data row0 col5" >0.9940</td>
#       <td id="T_71c35_row0_col6" class="data row0 col6" >5.1086</td>
#       <td id="T_71c35_row0_col7" class="data row0 col7" >0.5207</td>
#     </tr>
#   </tbody>
# </table>
# Model: AdaBoostRegressor(random_state=1), Pearson Correlation: 0.42462796818358783

# %% [markdown]
# # Exploring more features

# %%
import numpy as np
import pandas as pd
from pycaret.regression import *
from scipy.stats import spearmanr

exp_feats = ['day_0_specimen_id', 'subject_id', 'specimen_type', 'infancy_vac',
       'biological_sex', 'ethnicity', 'race', 'dataset', 'age', 'day_0_IgG_PT',
       'day_0_IgG_PRN', 'day_0_IgG_FHA', 'day_0_IgG1_PT', 'day_0_IgG1_PRN',
       'day_0_IgG1_FHA', 'day_0_IgG1_FIM2/3', 'day_0_IgG1_TT', 'day_0_IgG1_DT',
       'day_0_IgG1_OVA', 'day_0_IgG2_PT', 'day_0_IgG2_PRN', 'day_0_IgG2_FHA',
       'day_0_IgG2_FIM2/3', 'day_0_IgG2_TT', 'day_0_IgG2_DT', 'day_0_IgG2_OVA',
       'day_0_IgG3_PT', 'day_0_IgG3_PRN', 'day_0_IgG3_FHA',
       'day_0_IgG3_FIM2/3', 'day_0_IgG3_TT', 'day_0_IgG3_DT', 'day_0_IgG3_OVA',
       'day_0_IgG4_PT', 'day_0_IgG4_PRN', 'day_0_IgG4_FHA',
       'day_0_IgG4_FIM2/3', 'day_0_IgG4_TT', 'day_0_IgG4_DT', 'day_0_IgG4_OVA']

# %%
# Load data
df = pd.read_csv("/home/vmottaqi/cmipb_challenge/vincent_files/training_t_cell_processed_task4.1_nov5.csv", index_col=0)
df = df[df['FC_day_30_Th1/Th2'] >= 0]

# Define features and target
X = df[sel_feat]
y1 = df['day_30_Th1_PT']
y2 = df['day_30_Th2_PT']

# Combine features and separate targets for PyCaret input
data_Th1 = X.copy()
data_Th1['day_30_Th1_PT'] = y1

data_Th2 = X.copy()
data_Th2['day_30_Th2_PT'] = y2

# %%
# Custom Spearman correlation function
def spearman_metric(y_true, y_pred):
    return spearmanr(y_true, y_pred)[0]  # Return the Spearman correlation coefficient

# Initialize PyCaret setup for predicting 'day_30_Th1_PT'
setup_Th1 = setup(
    data=data_Th1,
    target='day_30_Th1_PT',
    categorical_features=cat_feat,
    session_id=1,
    fold=5
)
add_metric(
    'Spearman', 
    'Spearman Correlation', 
    spearman_metric, 
    greater_is_better=True
)

#Compare models using a supported metric (e.g., R2) for both targets
top_models_Th1 = compare_models(sort='R2', n_select=15)


# Initialize PyCaret setup for predicting 'day_30_Th2_PT'
setup_Th2 = setup(
    data=data_Th2,
    target='day_30_Th2_PT',
    categorical_features=cat_feat,
    session_id=2,
    fold=5
)


# Add the custom Spearman metric
add_metric(
    'Spearman', 
    'Spearman Correlation', 
    spearman_metric, 
    greater_is_better=True
)

top_models_Th2 = compare_models(sort='R2', n_select=15)
# Out:
# <style type="text/css">
# #T_4d0b5_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4d0b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d0b5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4d0b5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d0b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4d0b5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4d0b5_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4d0b5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4d0b5_row1_col1" class="data row1 col1" >day_30_Th1_PT</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4d0b5_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4d0b5_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4d0b5_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4d0b5_row3_col1" class="data row3 col1" >(41, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4d0b5_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4d0b5_row4_col1" class="data row4 col1" >(41, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4d0b5_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4d0b5_row5_col1" class="data row5 col1" >(28, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4d0b5_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4d0b5_row6_col1" class="data row6 col1" >(13, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4d0b5_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4d0b5_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4d0b5_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_4d0b5_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4d0b5_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_4d0b5_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4d0b5_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_4d0b5_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4d0b5_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_4d0b5_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4d0b5_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_4d0b5_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4d0b5_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_4d0b5_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4d0b5_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_4d0b5_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4d0b5_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_4d0b5_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4d0b5_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_4d0b5_row16_col1" class="data row16 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4d0b5_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_4d0b5_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4d0b5_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_4d0b5_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4d0b5_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_4d0b5_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4d0b5_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_4d0b5_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4d0b5_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4d0b5_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_4d0b5_row21_col1" class="data row21 col1" >a86f</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ff877 th {
#   text-align: left;
# }
# #T_ff877_row0_col0, #T_ff877_row0_col1, #T_ff877_row0_col5, #T_ff877_row0_col6, #T_ff877_row1_col0, #T_ff877_row1_col1, #T_ff877_row1_col2, #T_ff877_row1_col3, #T_ff877_row1_col4, #T_ff877_row1_col6, #T_ff877_row2_col0, #T_ff877_row2_col2, #T_ff877_row2_col3, #T_ff877_row2_col4, #T_ff877_row2_col5, #T_ff877_row2_col6, #T_ff877_row3_col0, #T_ff877_row3_col1, #T_ff877_row3_col2, #T_ff877_row3_col3, #T_ff877_row3_col4, #T_ff877_row3_col5, #T_ff877_row3_col6, #T_ff877_row4_col0, #T_ff877_row4_col1, #T_ff877_row4_col2, #T_ff877_row4_col3, #T_ff877_row4_col4, #T_ff877_row4_col5, #T_ff877_row4_col6, #T_ff877_row5_col0, #T_ff877_row5_col1, #T_ff877_row5_col2, #T_ff877_row5_col3, #T_ff877_row5_col4, #T_ff877_row5_col5, #T_ff877_row5_col6, #T_ff877_row6_col0, #T_ff877_row6_col1, #T_ff877_row6_col2, #T_ff877_row6_col3, #T_ff877_row6_col4, #T_ff877_row6_col5, #T_ff877_row6_col6, #T_ff877_row7_col0, #T_ff877_row7_col1, #T_ff877_row7_col2, #T_ff877_row7_col3, #T_ff877_row7_col4, #T_ff877_row7_col5, #T_ff877_row7_col6, #T_ff877_row8_col0, #T_ff877_row8_col1, #T_ff877_row8_col2, #T_ff877_row8_col3, #T_ff877_row8_col4, #T_ff877_row8_col5, #T_ff877_row8_col6, #T_ff877_row9_col0, #T_ff877_row9_col1, #T_ff877_row9_col2, #T_ff877_row9_col3, #T_ff877_row9_col4, #T_ff877_row9_col5, #T_ff877_row9_col6, #T_ff877_row10_col0, #T_ff877_row10_col1, #T_ff877_row10_col2, #T_ff877_row10_col3, #T_ff877_row10_col4, #T_ff877_row10_col5, #T_ff877_row10_col6, #T_ff877_row11_col0, #T_ff877_row11_col1, #T_ff877_row11_col2, #T_ff877_row11_col3, #T_ff877_row11_col4, #T_ff877_row11_col5, #T_ff877_row12_col0, #T_ff877_row12_col1, #T_ff877_row12_col2, #T_ff877_row12_col3, #T_ff877_row12_col4, #T_ff877_row12_col5, #T_ff877_row12_col6, #T_ff877_row13_col0, #T_ff877_row13_col1, #T_ff877_row13_col2, #T_ff877_row13_col3, #T_ff877_row13_col4, #T_ff877_row13_col5, #T_ff877_row13_col6, #T_ff877_row14_col0, #T_ff877_row14_col1, #T_ff877_row14_col2, #T_ff877_row14_col3, #T_ff877_row14_col4, #T_ff877_row14_col5, #T_ff877_row14_col6, #T_ff877_row15_col0, #T_ff877_row15_col1, #T_ff877_row15_col2, #T_ff877_row15_col3, #T_ff877_row15_col4, #T_ff877_row15_col5, #T_ff877_row15_col6, #T_ff877_row16_col0, #T_ff877_row16_col1, #T_ff877_row16_col2, #T_ff877_row16_col3, #T_ff877_row16_col4, #T_ff877_row16_col5, #T_ff877_row16_col6, #T_ff877_row17_col0, #T_ff877_row17_col1, #T_ff877_row17_col2, #T_ff877_row17_col3, #T_ff877_row17_col4, #T_ff877_row17_col5, #T_ff877_row17_col6 {
#   text-align: left;
# }
# #T_ff877_row0_col2, #T_ff877_row0_col3, #T_ff877_row0_col4, #T_ff877_row0_col7, #T_ff877_row1_col5, #T_ff877_row1_col7, #T_ff877_row2_col1, #T_ff877_row2_col7, #T_ff877_row3_col7, #T_ff877_row4_col7, #T_ff877_row5_col7, #T_ff877_row6_col7, #T_ff877_row7_col7, #T_ff877_row8_col7, #T_ff877_row9_col7, #T_ff877_row10_col7, #T_ff877_row11_col6, #T_ff877_row11_col7, #T_ff877_row12_col7, #T_ff877_row13_col7, #T_ff877_row14_col7, #T_ff877_row15_col7, #T_ff877_row16_col7, #T_ff877_row17_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ff877_row0_col8, #T_ff877_row1_col8, #T_ff877_row2_col8, #T_ff877_row3_col8, #T_ff877_row4_col8, #T_ff877_row5_col8, #T_ff877_row6_col8, #T_ff877_row7_col8, #T_ff877_row8_col8, #T_ff877_row9_col8, #T_ff877_row10_col8, #T_ff877_row11_col8, #T_ff877_row12_col8, #T_ff877_row14_col8, #T_ff877_row15_col8, #T_ff877_row16_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ff877_row13_col8, #T_ff877_row17_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ff877">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff877_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff877_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ff877_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ff877_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ff877_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ff877_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ff877_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ff877_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#       <th id="T_ff877_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff877_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_ff877_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_ff877_row0_col1" class="data row0 col1" >1.0905</td>
#       <td id="T_ff877_row0_col2" class="data row0 col2" >1.7102</td>
#       <td id="T_ff877_row0_col3" class="data row0 col3" >1.2791</td>
#       <td id="T_ff877_row0_col4" class="data row0 col4" >-0.4150</td>
#       <td id="T_ff877_row0_col5" class="data row0 col5" >0.5983</td>
#       <td id="T_ff877_row0_col6" class="data row0 col6" >12.3483</td>
#       <td id="T_ff877_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_ff877_row0_col8" class="data row0 col8" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_ff877_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_ff877_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_ff877_row1_col1" class="data row1 col1" >1.2294</td>
#       <td id="T_ff877_row1_col2" class="data row1 col2" >1.9940</td>
#       <td id="T_ff877_row1_col3" class="data row1 col3" >1.3540</td>
#       <td id="T_ff877_row1_col4" class="data row1 col4" >-0.4213</td>
#       <td id="T_ff877_row1_col5" class="data row1 col5" >0.5744</td>
#       <td id="T_ff877_row1_col6" class="data row1 col6" >17.1393</td>
#       <td id="T_ff877_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_ff877_row1_col8" class="data row1 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_ff877_level0_row2" class="row_heading level0 row2" >gbr</th>
#       <td id="T_ff877_row2_col0" class="data row2 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ff877_row2_col1" class="data row2 col1" >1.0558</td>
#       <td id="T_ff877_row2_col2" class="data row2 col2" >1.8937</td>
#       <td id="T_ff877_row2_col3" class="data row2 col3" >1.3323</td>
#       <td id="T_ff877_row2_col4" class="data row2 col4" >-0.6124</td>
#       <td id="T_ff877_row2_col5" class="data row2 col5" >0.5985</td>
#       <td id="T_ff877_row2_col6" class="data row2 col6" >8.0375</td>
#       <td id="T_ff877_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_ff877_row2_col8" class="data row2 col8" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_ff877_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_ff877_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_ff877_row3_col1" class="data row3 col1" >1.1389</td>
#       <td id="T_ff877_row3_col2" class="data row3 col2" >1.8469</td>
#       <td id="T_ff877_row3_col3" class="data row3 col3" >1.3222</td>
#       <td id="T_ff877_row3_col4" class="data row3 col4" >-0.9015</td>
#       <td id="T_ff877_row3_col5" class="data row3 col5" >0.6303</td>
#       <td id="T_ff877_row3_col6" class="data row3 col6" >13.6733</td>
#       <td id="T_ff877_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_ff877_row3_col8" class="data row3 col8" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_ff877_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_ff877_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_ff877_row4_col1" class="data row4 col1" >1.3586</td>
#       <td id="T_ff877_row4_col2" class="data row4 col2" >2.2397</td>
#       <td id="T_ff877_row4_col3" class="data row4 col3" >1.4863</td>
#       <td id="T_ff877_row4_col4" class="data row4 col4" >-0.9426</td>
#       <td id="T_ff877_row4_col5" class="data row4 col5" >0.6428</td>
#       <td id="T_ff877_row4_col6" class="data row4 col6" >19.8801</td>
#       <td id="T_ff877_row4_col7" class="data
# <style type="text/css">
# #T_1cd56_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1cd56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1cd56_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1cd56_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cd56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1cd56_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1cd56_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1cd56_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1cd56_row1_col1" class="data row1 col1" >day_30_Th2_PT</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1cd56_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1cd56_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1cd56_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_1cd56_row3_col1" class="data row3 col1" >(41, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1cd56_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_1cd56_row4_col1" class="data row4 col1" >(41, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1cd56_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_1cd56_row5_col1" class="data row5 col1" >(28, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1cd56_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_1cd56_row6_col1" class="data row6 col1" >(13, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1cd56_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_1cd56_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1cd56_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_1cd56_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1cd56_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_1cd56_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1cd56_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_1cd56_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1cd56_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_1cd56_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1cd56_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_1cd56_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1cd56_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_1cd56_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1cd56_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_1cd56_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1cd56_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_1cd56_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1cd56_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_1cd56_row16_col1" class="data row16 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1cd56_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_1cd56_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1cd56_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_1cd56_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1cd56_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_1cd56_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1cd56_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_1cd56_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1cd56_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1cd56_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_1cd56_row21_col1" class="data row21 col1" >5411</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_685eb th {
#   text-align: left;
# }
# #T_685eb_row0_col0, #T_685eb_row0_col1, #T_685eb_row0_col2, #T_685eb_row0_col3, #T_685eb_row0_col5, #T_685eb_row1_col0, #T_685eb_row1_col4, #T_685eb_row1_col6, #T_685eb_row2_col0, #T_685eb_row2_col1, #T_685eb_row2_col2, #T_685eb_row2_col3, #T_685eb_row2_col4, #T_685eb_row2_col5, #T_685eb_row2_col6, #T_685eb_row3_col0, #T_685eb_row3_col1, #T_685eb_row3_col2, #T_685eb_row3_col3, #T_685eb_row3_col4, #T_685eb_row3_col5, #T_685eb_row3_col6, #T_685eb_row4_col0, #T_685eb_row4_col1, #T_685eb_row4_col2, #T_685eb_row4_col3, #T_685eb_row4_col4, #T_685eb_row4_col5, #T_685eb_row4_col6, #T_685eb_row5_col0, #T_685eb_row5_col1, #T_685eb_row5_col2, #T_685eb_row5_col3, #T_685eb_row5_col4, #T_685eb_row5_col5, #T_685eb_row5_col6, #T_685eb_row6_col0, #T_685eb_row6_col1, #T_685eb_row6_col2, #T_685eb_row6_col3, #T_685eb_row6_col4, #T_685eb_row6_col5, #T_685eb_row6_col6, #T_685eb_row7_col0, #T_685eb_row7_col1, #T_685eb_row7_col2, #T_685eb_row7_col3, #T_685eb_row7_col4, #T_685eb_row7_col5, #T_685eb_row7_col6, #T_685eb_row8_col0, #T_685eb_row8_col1, #T_685eb_row8_col2, #T_685eb_row8_col3, #T_685eb_row8_col4, #T_685eb_row8_col5, #T_685eb_row8_col6, #T_685eb_row9_col0, #T_685eb_row9_col1, #T_685eb_row9_col2, #T_685eb_row9_col3, #T_685eb_row9_col4, #T_685eb_row9_col5, #T_685eb_row9_col6, #T_685eb_row10_col0, #T_685eb_row10_col1, #T_685eb_row10_col2, #T_685eb_row10_col3, #T_685eb_row10_col4, #T_685eb_row10_col5, #T_685eb_row10_col6, #T_685eb_row11_col0, #T_685eb_row11_col1, #T_685eb_row11_col2, #T_685eb_row11_col3, #T_685eb_row11_col4, #T_685eb_row11_col5, #T_685eb_row11_col6, #T_685eb_row12_col0, #T_685eb_row12_col1, #T_685eb_row12_col2, #T_685eb_row12_col3, #T_685eb_row12_col4, #T_685eb_row12_col5, #T_685eb_row12_col6, #T_685eb_row13_col0, #T_685eb_row13_col1, #T_685eb_row13_col2, #T_685eb_row13_col3, #T_685eb_row13_col4, #T_685eb_row13_col5, #T_685eb_row13_col6, #T_685eb_row14_col0, #T_685eb_row14_col1, #T_685eb_row14_col2, #T_685eb_row14_col3, #T_685eb_row14_col4, #T_685eb_row14_col5, #T_685eb_row14_col6, #T_685eb_row15_col0, #T_685eb_row15_col1, #T_685eb_row15_col2, #T_685eb_row15_col3, #T_685eb_row15_col4, #T_685eb_row15_col5, #T_685eb_row15_col6, #T_685eb_row16_col0, #T_685eb_row16_col1, #T_685eb_row16_col2, #T_685eb_row16_col3, #T_685eb_row16_col4, #T_685eb_row16_col5, #T_685eb_row16_col6, #T_685eb_row17_col0, #T_685eb_row17_col1, #T_685eb_row17_col2, #T_685eb_row17_col3, #T_685eb_row17_col4, #T_685eb_row17_col5, #T_685eb_row17_col6 {
#   text-align: left;
# }
# #T_685eb_row0_col4, #T_685eb_row0_col6, #T_685eb_row0_col7, #T_685eb_row1_col1, #T_685eb_row1_col2, #T_685eb_row1_col3, #T_685eb_row1_col5, #T_685eb_row1_col7, #T_685eb_row2_col7, #T_685eb_row3_col7, #T_685eb_row4_col7, #T_685eb_row5_col7, #T_685eb_row6_col7, #T_685eb_row7_col7, #T_685eb_row8_col7, #T_685eb_row9_col7, #T_685eb_row10_col7, #T_685eb_row11_col7, #T_685eb_row12_col7, #T_685eb_row13_col7, #T_685eb_row14_col7, #T_685eb_row15_col7, #T_685eb_row16_col7, #T_685eb_row17_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_685eb_row0_col8, #T_685eb_row1_col8, #T_685eb_row2_col8, #T_685eb_row4_col8, #T_685eb_row5_col8, #T_685eb_row6_col8, #T_685eb_row7_col8, #T_685eb_row8_col8, #T_685eb_row10_col8, #T_685eb_row11_col8, #T_685eb_row12_col8, #T_685eb_row13_col8, #T_685eb_row14_col8, #T_685eb_row15_col8, #T_685eb_row16_col8, #T_685eb_row17_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_685eb_row3_col8, #T_685eb_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_685eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_685eb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_685eb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_685eb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_685eb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_685eb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_685eb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_685eb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_685eb_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#       <th id="T_685eb_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_685eb_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_685eb_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_685eb_row0_col1" class="data row0 col1" >1.0709</td>
#       <td id="T_685eb_row0_col2" class="data row0 col2" >3.4850</td>
#       <td id="T_685eb_row0_col3" class="data row0 col3" >1.5084</td>
#       <td id="T_685eb_row0_col4" class="data row0 col4" >-0.3855</td>
#       <td id="T_685eb_row0_col5" class="data row0 col5" >0.4726</td>
#       <td id="T_685eb_row0_col6" class="data row0 col6" >1.9474</td>
#       <td id="T_685eb_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_685eb_row0_col8" class="data row0 col8" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_685eb_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_685eb_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_685eb_row1_col1" class="data row1 col1" >0.8665</td>
#       <td id="T_685eb_row1_col2" class="data row1 col2" >1.9431</td>
#       <td id="T_685eb_row1_col3" class="data row1 col3" >1.1934</td>
#       <td id="T_685eb_row1_col4" class="data row1 col4" >-0.4283</td>
#       <td id="T_685eb_row1_col5" class="data row1 col5" >0.4270</td>
#       <td id="T_685eb_row1_col6" class="data row1 col6" >2.1533</td>
#       <td id="T_685eb_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_685eb_row1_col8" class="data row1 col8" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_685eb_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_685eb_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_685eb_row2_col1" class="data row2 col1" >0.9522</td>
#       <td id="T_685eb_row2_col2" class="data row2 col2" >2.6725</td>
#       <td id="T_685eb_row2_col3" class="data row2 col3" >1.2985</td>
#       <td id="T_685eb_row2_col4" class="data row2 col4" >-0.6548</td>
#       <td id="T_685eb_row2_col5" class="data row2 col5" >0.4630</td>
#       <td id="T_685eb_row2_col6" class="data row2 col6" >2.8740</td>
#       <td id="T_685eb_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_685eb_row2_col8" class="data row2 col8" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_685eb_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_685eb_row3_col0" class="data row3 col0" >Decision Tree Regressor</td>
#       <td id="T_685eb_row3_col1" class="data row3 col1" >1.3352</td>
#       <td id="T_685eb_row3_col2" class="data row3 col2" >4.8850</td>
#       <td id="T_685eb_row3_col3" class="data row3 col3" >1.8225</td>
#       <td id="T_685eb_row3_col4" class="data row3 col4" >-1.0703</td>
#       <td id="T_685eb_row3_col5" class="data row3 col5" >0.6063</td>
#       <td id="T_685eb_row3_col6" class="data row3 col6" >2.9804</td>
#       <td id="T_685eb_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_685eb_row3_col8" class="data row3 col8" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_685eb_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_685eb_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_685eb_row4_col1" class="data row4 col1" >1.1335</td>
#       <td id="T_685eb_row4_col2" class="data row4 col2" >3.4456</td>
#       <td id="T_685eb_row4_col3" class="data row4 col3" >1.5803</td>
#       <td id="T_685eb_row4_col4" class="data row4 col4" >-1.4431</td>
#       <td id="T_685eb_row4_col5" class="data row4 col5" >0.5406</td>
#       <td id="T_685eb_row4_col6" class="data row4 col6" >2.9466</td>
#       <td id="T_685eb_row4_col7" class="data row4 co

# %%
data_Th1
# Out:
#     day_0_Th2_PHA  day_0_IL17A_PT biological_sex  day_0_Th2_PT  \
# 0        0.038217        0.002116         Female      0.127659
# 1        1.872613        0.392593         Female      2.489356
# 2        2.133760        0.104762         Female      0.127659
# 3        2.509555        1.423633         Female      5.063817
# 4        2.019110        0.323457           Male      2.595741
# 5        0.503184        1.000000           Male      0.319148
# 6        0.038217        0.129806         Female      0.127659
# 7        5.076437        0.057143         Female      0.127659
# 8        0.700638        0.216226         Female      0.127659
# 9        1.019108        0.215520         Female      0.127659
# 10       2.171977        1.886420           Male      6.234031
# 11       0.713376        1.467372         Female      6.808498
# 12       0.821657        1.382363           Male      1.297867
# 13       7.273891        1.592240         Female     32.319078
# 14       4.254780        1.916049           Male      1.000000
# 15       1.000000        0.958377         Female      0.127659
# 16       0.420382        0.003175         Female      0.319148
# 17       0.038217        0.360141         Female      0.127659
# 18       2.076435        0.437743         Female      4.340416
# 19       3.668792        1.797884           Male      1.446808
# 20       3.541403        1.538624         Female      1.468082
# 21       0.337580        1.343563         Female      1.638297
# 22       0.535032        2.241270           Male      1.021274
# 23       0.350318        1.889594         Female      0.127659
# 24       0.038217        2.477954           Male      0.127659
# 25       9.620681        0.232748           Male      3.931031
# 26      18.775846        0.845614         Female      1.465514
# 27       0.051724        2.271345         Female      6.465512
# 28       0.491379        1.383626           Male      0.931034
# 29       1.000000        0.444445         Female      0.655174
# 30       0.051724        0.007018         Female      0.103448
# 31       0.896552        1.238596         Female      0.931034
# 32      10.844817        2.518129         Female      4.086203
# 33       2.060344        2.591813         Female      2.310345
# 34       3.905169        3.024561         Female      3.086206
# 35       2.068964        0.984795           Male      0.844825
# 36       7.698270        2.837427           Male      1.965516
# 37       1.637929        0.007018           Male      0.103448
# 38       0.482759        0.297076         Female      0.103448
# 39       0.051724        0.007018           Male      0.103448
# 40       0.318964        0.130994           Male      1.620687
#
#     day_0_IL17A_PHA  day_0_Th1_PHA  day_0_Th1_PT  age infancy_vac  \
# 0          0.025064       0.065490      0.006795   32          wP
# 1          0.943766       0.511916      0.342016   25          wP
# 2          0.804949       1.663089      1.255946   42          wP
# 3          1.728149       1.642350      2.908268   47          wP
# 4          0.418059       1.000000      2.246886   47          wP
# 5          1.456298       0.260870      0.147225   21          aP
# 6          0.286311       0.275787      0.259343   21          aP
# 7          0.220437       1.566309      0.182333   28          wP
# 8          0.480398       0.785155      1.920725   24          wP
# 9          0.610540       1.131890      0.520951   24          wP
# 10         1.974614       1.379298      3.106456   31          wP
# 11         1.421594       1.186465      4.075878   26          wP
# 12         1.684126       1.279243      2.109853   32          wP
# 13         1.000000       0.135347      0.003398   27          wP
# 14         2.855399       2.229580      4.074746   26          wP
# 15         1.281491       0.380207      1.000000   21          aP
# 16         0.140746       0.375841      0.007927   21          aP
# 17         0.001928       0.668365      0.231031   22          aP
# 18         0.653599       1.122430      2.437146   20          aP
# 19         1.446658       1.301437      2.287656   21          aP
# 20         2.273458       1.400400      0.886750   19          aP
# 21         1.089010       0.981990      2.831257   23          aP
# 22         2.282776       1.051119      0.514156   20          aP
# 23         1.391710       0.934692      2.540204   21          aP
# 24         0.001928       0.086229      0.118913   19          aP
# 25         0.915352       1.147427      2.631497   35          wP
# 26         1.743428       1.049606      1.743988   28          wP
# 27         1.000000       0.096430      1.452288   20          aP
# 28         1.509464       0.350487      0.068270   18          aP
# 29         0.662986       1.000000      0.408068   27          wP
# 30         0.003155       0.002782      0.009310   27          wP
# 31         0.967403       1.086694      4.052754   25          aP
# 32         2.283386       1.455262      0.840962   23          aP
# 33         1.643533       1.049606      1.743988   32          wP
# 34         1.187697       0.719982      1.159038   24          aP
# 35         1.729758       1.190079      0.575640   25          wP
# 36         1.995268       1.334261      1.775019   25          aP
# 37         0.353838       0.014372      0.009310   31          wP
# 38         1.183491       1.097357      1.849495   19          aP
# 39         0.003155       0.002782      0.009310   21          aP
# 40         0.279180       0.108020      0.662529   24          aP
#
#     day_30_Th1_PT
# 0        1.762176
# 1        0.041901
# 2        2.134767
# 3        0.862967
# 4        0.961495
# 5        0.086069
# 6        3.291055
# 7        1.830126
# 8        0.117781
# 9        1.656853
# 10       3.740657
# 11       4.346545
# 12       3.147225
# 13       0.006795
# 14       3.361268
# 15       0.138166
# 16       0.083806
# 17       0.437147
# 18       2.383920
# 19       1.375991
# 20       0.644395
# 21       2.840317
# 22       1.204984
# 23       2.978484
# 24       0.180068
# 25       2.830101
# 26       2.400312
# 27       0.052753
# 28       0.004655
# 29       0.009310
# 30       0.043444
# 31       3.407292
# 32       0.178433
# 33       2.400310
# 34       1.523661
# 35       0.633049
# 36       0.690458
# 37       0.352211
# 38       3.498836
# 39       2.909232
# 40       0.038790

# %%
def calculate_predictions(model, pred_column='Label'):
    """
    Calculate predictions for a model and return the predictions column.
    """
    predictions = predict_model(model)
    predictions = predictions.reset_index(drop=True)
    
    # Identify the prediction column
    pred_col = pred_column if pred_column in predictions.columns else predictions.select_dtypes(include=np.number).columns[-1]
    print(f"Predictions column for model {model}: {pred_col}")  # Debugging statement
    return predictions[[pred_col]].rename(columns={pred_col: f'Prediction_{model}'})

def merge_predictions(pred_Th1, pred_Th2):
    """
    Merge the predictions for two models and calculate the derived fold change (FC).
    """
    merged_predictions = pd.merge(
        pred_Th1, 
        pred_Th2, 
        left_index=True, 
        right_index=True
    )
    derived_FC = merged_predictions.iloc[:, 0] / merged_predictions.iloc[:, 1]
    return derived_FC

def calculate_spearman_correlation(model_Th1, model_Th2, original_target):
    """
    Calculate the Spearman correlation for two models.
    """
    predictions_Th1 = calculate_predictions(model_Th1)
    predictions_Th2 = calculate_predictions(model_Th2)
    
    # Calculate the derived fold change for Th1 and Th2 predictions
    derived_FC = merge_predictions(predictions_Th1, predictions_Th2)
    
    # Calculate Spearman correlation with the original target
    spearman_corr = spearman_metric(original_target, derived_FC)
    return model_Th1, model_Th2, spearman_corr

# Main code block
spearman_results = []
original_target = df[['FC_day_30_Th1/Th2']]

for model_Th1, model_Th2 in zip(top_models_Th1, top_models_Th2):
    result = calculate_spearman_correlation(model_Th1, model_Th2, original_target)
    spearman_results.append(result)

# Sort and display models by Spearman correlation
sorted_spearman_results = sorted(spearman_results, key=lambda x: x[2], reverse=True)
for model_Th1, model_Th2, spearman_corr in sorted_spearman_results:
    print(f"Model Th1: {model_Th1}, Model Th2: {model_Th2}, Spearman Correlation: {spearman_corr}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_182c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_182c7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_182c7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_182c7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_182c7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_182c7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_182c7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_182c7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_182c7_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_182c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_182c7_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_182c7_row0_col1" class="data row0 col1" >3.0009</td>
#       <td id="T_182c7_row0_col2" class="data row0 col2" >35.3816</td>
#       <td id="T_182c7_row0_col3" class="data row0 col3" >5.9482</td>
#       <td id="T_182c7_row0_col4" class="data row0 col4" >-0.1115</td>
#       <td id="T_182c7_row0_col5" class="data row0 col5" >1.0788</td>
#       <td id="T_182c7_row0_col6" class="data row0 col6" >8.5902</td>
#       <td id="T_182c7_row0_col7" class="data row0 col7" >0.0675</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model RandomForestRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_fc0f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc0f4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fc0f4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fc0f4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fc0f4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fc0f4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fc0f4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fc0f4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fc0f4_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc0f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc0f4_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_fc0f4_row0_col1" class="data row0 col1" >2.6516</td>
#       <td id="T_fc0f4_row0_col2" class="data row0 col2" >30.3164</td>
#       <td id="T_fc0f4_row0_col3" class="data row0 col3" >5.5060</td>
#       <td id="T_fc0f4_row0_col4" class="data row0 col4" >0.0476</td>
#       <td id="T_fc0f4_row0_col5" class="data row0 col5" >0.8929</td>
#       <td id="T_fc0f4_row0_col6" class="data row0 col6" >4.7857</td>
#       <td id="T_fc0f4_row0_col7" class="data row0 col7" >0.2997</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model KNeighborsRegressor(n_jobs=-1): prediction_label
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/jrollins/cmipb-challenge/task4-1_basemodels_11052024 copy.ipynb Cell 17 line 4
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a> original_target = df[['FC_day_30_Th1/Th2']]
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=43'>44</a> for model_Th1, model_Th2 in zip(top_models_Th1, top_models_Th2):
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=44'>45</a>     result = calculate_spearman_correlation(model_Th1, model_Th2, original_target)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a>     spearman_results.append(result)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=47'>48</a> # Sort and display models by Spearman correlation
#
# /home/jrollins/cmipb-challenge/task4-1_basemodels_11052024 copy.ipynb Cell 17 line 3
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a> derived_FC = merge_predictions(predictions_Th1, predictions_Th2)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a> # Calculate Spearman correlation with the original target
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=36'>37</a> spearman_corr = spearman_metric(original_target, derived_FC)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a> return model_Th1, model_Th2, spearman_corr
#
# /home/jrollins/cmipb-challenge/task4-1_basemodels_11052024 copy.ipynb Cell 17 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> def spearman_metric(y_true, y_pred):
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     return spearmanr(y_true, y_pred)[0]
#
# File ~/miniforge3/envs/py3.10/lib/python3.10/site-packages/scipy/stats/_stats_py.py:5427, in spearmanr(a, b, axis, nan_policy, alternative)
#    5425 b, _ = _chk_asarray(b, axis)
#    5426 if axisout == 0:
# -> 5427     a = np.column_stack((a, b))
#    5428 else:
#    5429     a = np.row_stack((a, b))
#
# File ~/miniforge3/envs/py3.10/lib/python3.10/site-packages/numpy/lib/shape_base.py:652, in column_stack(tup)
#     650         arr = array(arr, copy=False, subok=True, ndmin=2).T
#     651     arrays.append(arr)
# --> 652 return _nx.concatenate(arrays, 1)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 41 and the array at index 1 has size 13

# %%
def calculate_spearman_correlation(model_Th1, model_Th2, original_target):
    """
    Calculate the Spearman correlation for two models.
    """
    predictions_Th1 = calculate_predictions(model_Th1)
    predictions_Th2 = calculate_predictions(model_Th2)
    
    # Calculate the derived fold change for Th1 and Th2 predictions
    derived_FC = merge_predictions(predictions_Th1, predictions_Th2)
    
    # Align derived_FC with original_target
    aligned_data = pd.concat([original_target.reset_index(drop=True), derived_FC.reset_index(drop=True)], axis=1)
    aligned_data.dropna(inplace=True)  # Drop any rows with NaN values if predictions or targets don't align
    target_aligned, derived_FC_aligned = aligned_data.iloc[:, 0], aligned_data.iloc[:, 1]

    # Debugging output: print shapes to verify alignment
    print(f"Original target shape: {target_aligned.shape}, Derived FC shape: {derived_FC_aligned.shape}")
    
    # Calculate Spearman correlation
    spearman_corr = spearman_metric(target_aligned, derived_FC_aligned)
    return model_Th1, model_Th2, spearman_corr

# Main code block
spearman_results = []
original_target = df[['FC_day_30_Th1/Th2']]

for model_Th1, model_Th2 in zip(top_models_Th1, top_models_Th2):
    result = calculate_spearman_correlation(model_Th1, model_Th2, original_target)
    spearman_results.append(result)

# Sort and display models by Spearman correlation
sorted_spearman_results = sorted(spearman_results, key=lambda x: x[2], reverse=True)
for model_Th1, model_Th2, spearman_corr in sorted_spearman_results:
    print(f"Model Th1: {model_Th1}, Model Th2: {model_Th2}, Spearman Correlation: {spearman_corr}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e763b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e763b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e763b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e763b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e763b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e763b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e763b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e763b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e763b_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e763b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e763b_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_e763b_row0_col1" class="data row0 col1" >3.0009</td>
#       <td id="T_e763b_row0_col2" class="data row0 col2" >35.3816</td>
#       <td id="T_e763b_row0_col3" class="data row0 col3" >5.9482</td>
#       <td id="T_e763b_row0_col4" class="data row0 col4" >-0.1115</td>
#       <td id="T_e763b_row0_col5" class="data row0 col5" >1.0788</td>
#       <td id="T_e763b_row0_col6" class="data row0 col6" >8.5902</td>
#       <td id="T_e763b_row0_col7" class="data row0 col7" >0.0675</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model RandomForestRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_fc727">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc727_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fc727_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fc727_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fc727_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fc727_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fc727_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fc727_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fc727_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc727_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc727_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_fc727_row0_col1" class="data row0 col1" >2.6516</td>
#       <td id="T_fc727_row0_col2" class="data row0 col2" >30.3164</td>
#       <td id="T_fc727_row0_col3" class="data row0 col3" >5.5060</td>
#       <td id="T_fc727_row0_col4" class="data row0 col4" >0.0476</td>
#       <td id="T_fc727_row0_col5" class="data row0 col5" >0.8929</td>
#       <td id="T_fc727_row0_col6" class="data row0 col6" >4.7857</td>
#       <td id="T_fc727_row0_col7" class="data row0 col7" >0.2997</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model KNeighborsRegressor(n_jobs=-1): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_1368d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1368d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1368d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1368d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1368d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1368d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1368d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1368d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1368d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1368d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1368d_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_1368d_row0_col1" class="data row0 col1" >3.1775</td>
#       <td id="T_1368d_row0_col2" class="data row0 col2" >32.7977</td>
#       <td id="T_1368d_row0_col3" class="data row0 col3" >5.7269</td>
#       <td id="T_1368d_row0_col4" class="data row0 col4" >-0.0303</td>
#       <td id="T_1368d_row0_col5" class="data row0 col5" >1.0130</td>
#       <td id="T_1368d_row0_col6" class="data row0 col6" >10.1715</td>
#       <td id="T_1368d_row0_col7" class="data row0 col7" >0.0458</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model OrthogonalMatchingPursuit(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_07726">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07726_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_07726_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_07726_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_07726_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_07726_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_07726_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_07726_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_07726_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07726_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07726_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_07726_row0_col1" class="data row0 col1" >2.5973</td>
#       <td id="T_07726_row0_col2" class="data row0 col2" >24.4577</td>
#       <td id="T_07726_row0_col3" class="data row0 col3" >4.9455</td>
#       <td id="T_07726_row0_col4" class="data row0 col4" >0.2317</td>
#       <td id="T_07726_row0_col5" class="data row0 col5" >0.8417</td>
#       <td id="T_07726_row0_col6" class="data row0 col6" >6.7666</td>
#       <td id="T_07726_row0_col7" class="data row0 col7" >0.0692</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model AdaBoostRegressor(random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_23c3e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23c3e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_23c3e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_23c3e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_23c3e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_23c3e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_23c3e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_23c3e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_23c3e_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23c3e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23c3e_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_23c3e_row0_col1" class="data row0 col1" >3.1608</td>
#       <td id="T_23c3e_row0_col2" class="data row0 col2" >36.7896</td>
#       <td id="T_23c3e_row0_col3" class="data row0 col3" >6.0654</td>
#       <td id="T_23c3e_row0_col4" class="data row0 col4" >-0.1558</td>
#       <td id="T_23c3e_row0_col5" class="data row0 col5" >1.1784</td>
#       <td id="T_23c3e_row0_col6" class="data row0 col6" >9.3884</td>
#       <td id="T_23c3e_row0_col7" class="data row0 col7" >-0.0352</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model GradientBoostingRegressor(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_ff667">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff667_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff667_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ff667_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ff667_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ff667_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ff667_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ff667_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ff667_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff667_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff667_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_ff667_row0_col1" class="data row0 col1" >2.6454</td>
#       <td id="T_ff667_row0_col2" class="data row0 col2" >24.0143</td>
#       <td id="T_ff667_row0_col3" class="data row0 col3" >4.9004</td>
#       <td id="T_ff667_row0_col4" class="data row0 col4" >0.2456</td>
#       <td id="T_ff667_row0_col5" class="data row0 col5" >0.8158</td>
#       <td id="T_ff667_row0_col6" class="data row0 col6" >7.8242</td>
#       <td id="T_ff667_row0_col7" class="data row0 col7" >0.2700</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model RandomForestRegressor(n_jobs=-1, random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_513fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_513fb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_513fb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_513fb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_513fb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_513fb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_513fb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_513fb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_513fb_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_513fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_513fb_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_513fb_row0_col1" class="data row0 col1" >2.9597</td>
#       <td id="T_513fb_row0_col2" class="data row0 col2" >36.0958</td>
#       <td id="T_513fb_row0_col3" class="data row0 col3" >6.0080</td>
#       <td id="T_513fb_row0_col4" class="data row0 col4" >-0.1340</td>
#       <td id="T_513fb_row0_col5" class="data row0 col5" >1.1211</td>
#       <td id="T_513fb_row0_col6" class="data row0 col6" >7.4801</td>
#       <td id="T_513fb_row0_col7" class="data row0 col7" >0.1115</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ExtraTreesRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_d67d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d67d7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d67d7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d67d7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d67d7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d67d7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d67d7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d67d7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d67d7_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d67d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d67d7_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_d67d7_row0_col1" class="data row0 col1" >2.9850</td>
#       <td id="T_d67d7_row0_col2" class="data row0 col2" >27.3063</td>
#       <td id="T_d67d7_row0_col3" class="data row0 col3" >5.2255</td>
#       <td id="T_d67d7_row0_col4" class="data row0 col4" >0.1422</td>
#       <td id="T_d67d7_row0_col5" class="data row0 col5" >0.9845</td>
#       <td id="T_d67d7_row0_col6" class="data row0 col6" >10.0778</td>
#       <td id="T_d67d7_row0_col7" class="data row0 col7" >0.0928</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DecisionTreeRegressor(random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_3dc7d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dc7d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3dc7d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3dc7d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3dc7d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3dc7d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3dc7d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3dc7d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3dc7d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dc7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3dc7d_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_3dc7d_row0_col1" class="data row0 col1" >3.0857</td>
#       <td id="T_3dc7d_row0_col2" class="data row0 col2" >32.7598</td>
#       <td id="T_3dc7d_row0_col3" class="data row0 col3" >5.7236</td>
#       <td id="T_3dc7d_row0_col4" class="data row0 col4" >-0.0292</td>
#       <td id="T_3dc7d_row0_col5" class="data row0 col5" >0.9892</td>
#       <td id="T_3dc7d_row0_col6" class="data row0 col6" >9.6214</td>
#       <td id="T_3dc7d_row0_col7" class="data row0 col7" >-0.2172</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Lasso(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_05196">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05196_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_05196_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_05196_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_05196_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_05196_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_05196_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_05196_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_05196_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05196_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05196_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_05196_row0_col1" class="data row0 col1" >2.7364</td>
#       <td id="T_05196_row0_col2" class="data row0 col2" >21.7204</td>
#       <td id="T_05196_row0_col3" class="data row0 col3" >4.6605</td>
#       <td id="T_05196_row0_col4" class="data row0 col4" >0.3176</td>
#       <td id="T_05196_row0_col5" class="data row0 col5" >0.9104</td>
#       <td id="T_05196_row0_col6" class="data row0 col6" >9.4035</td>
#       <td id="T_05196_row0_col7" class="data row0 col7" >0.2377</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model GradientBoostingRegressor(random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_0d540">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d540_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0d540_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0d540_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0d540_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0d540_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0d540_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0d540_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0d540_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d540_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d540_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_0d540_row0_col1" class="data row0 col1" >3.0857</td>
#       <td id="T_0d540_row0_col2" class="data row0 col2" >32.7598</td>
#       <td id="T_0d540_row0_col3" class="data row0 col3" >5.7236</td>
#       <td id="T_0d540_row0_col4" class="data row0 col4" >-0.0292</td>
#       <td id="T_0d540_row0_col5" class="data row0 col5" >0.9892</td>
#       <td id="T_0d540_row0_col6" class="data row0 col6" >9.6214</td>
#       <td id="T_0d540_row0_col7" class="data row0 col7" >-0.2172</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LassoLars(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_6976d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6976d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6976d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6976d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6976d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6976d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6976d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6976d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6976d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6976d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6976d_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_6976d_row0_col1" class="data row0 col1" >2.4520</td>
#       <td id="T_6976d_row0_col2" class="data row0 col2" >24.5548</td>
#       <td id="T_6976d_row0_col3" class="data row0 col3" >4.9553</td>
#       <td id="T_6976d_row0_col4" class="data row0 col4" >0.2286</td>
#       <td id="T_6976d_row0_col5" class="data row0 col5" >0.7503</td>
#       <td id="T_6976d_row0_col6" class="data row0 col6" >6.0588</td>
#       <td id="T_6976d_row0_col7" class="data row0 col7" >0.3052</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ExtraTreesRegressor(n_jobs=-1, random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_2d95a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d95a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2d95a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2d95a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2d95a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2d95a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2d95a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2d95a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_2d95a_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d95a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d95a_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_2d95a_row0_col1" class="data row0 col1" >3.1332</td>
#       <td id="T_2d95a_row0_col2" class="data row0 col2" >32.6777</td>
#       <td id="T_2d95a_row0_col3" class="data row0 col3" >5.7164</td>
#       <td id="T_2d95a_row0_col4" class="data row0 col4" >-0.0266</td>
#       <td id="T_2d95a_row0_col5" class="data row0 col5" >1.0025</td>
#       <td id="T_2d95a_row0_col6" class="data row0 col6" >10.0620</td>
#       <td id="T_2d95a_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DummyRegressor(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_45d05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45d05_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_45d05_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_45d05_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_45d05_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_45d05_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_45d05_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_45d05_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_45d05_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45d05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45d05_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_45d05_row0_col1" class="data row0 col1" >3.2518</td>
#       <td id="T_45d05_row0_col2" class="data row0 col2" >34.3643</td>
#       <td id="T_45d05_row0_col3" class="data row0 col3" >5.8621</td>
#       <td id="T_45d05_row0_col4" class="data row0 col4" >-0.0796</td>
#       <td id="T_45d05_row0_col5" class="data row0 col5" >1.0764</td>
#       <td id="T_45d05_row0_col6" class="data row0 col6" >9.6987</td>
#       <td id="T_45d05_row0_col7" class="data row0 col7" >0.0458</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model OrthogonalMatchingPursuit(): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_ce485">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce485_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ce485_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ce485_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ce485_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ce485_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ce485_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ce485_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ce485_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce485_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce485_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ce485_row0_col1" class="data row0 col1" >3.1332</td>
#       <td id="T_ce485_row0_col2" class="data row0 col2" >32.6777</td>
#       <td id="T_ce485_row0_col3" class="data row0 col3" >5.7164</td>
#       <td id="T_ce485_row0_col4" class="data row0 col4" >-0.0266</td>
#       <td id="T_ce485_row0_col5" class="data row0 col5" >1.0025</td>
#       <td id="T_ce485_row0_col6" class="data row0 col6" >10.0620</td>
#       <td id="T_ce485_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LGBMRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_bcfb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcfb0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bcfb0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bcfb0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bcfb0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bcfb0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bcfb0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bcfb0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_bcfb0_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcfb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bcfb0_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_bcfb0_row0_col1" class="data row0 col1" >2.4727</td>
#       <td id="T_bcfb0_row0_col2" class="data row0 col2" >14.4349</td>
#       <td id="T_bcfb0_row0_col3" class="data row0 col3" >3.7993</td>
#       <td id="T_bcfb0_row0_col4" class="data row0 col4" >0.5465</td>
#       <td id="T_bcfb0_row0_col5" class="data row0 col5" >0.8786</td>
#       <td id="T_bcfb0_row0_col6" class="data row0 col6" >8.3720</td>
#       <td id="T_bcfb0_row0_col7" class="data row0 col7" >0.0939</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LassoLars(random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_f6674">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6674_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f6674_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f6674_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f6674_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f6674_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f6674_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f6674_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f6674_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6674_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6674_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_f6674_row0_col1" class="data row0 col1" >2.7042</td>
#       <td id="T_f6674_row0_col2" class="data row0 col2" >28.6096</td>
#       <td id="T_f6674_row0_col3" class="data row0 col3" >5.3488</td>
#       <td id="T_f6674_row0_col4" class="data row0 col4" >0.1012</td>
#       <td id="T_f6674_row0_col5" class="data row0 col5" >0.8295</td>
#       <td id="T_f6674_row0_col6" class="data row0 col6" >6.9795</td>
#       <td id="T_f6674_row0_col7" class="data row0 col7" >0.6386</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model KNeighborsRegressor(n_jobs=-1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_8410e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8410e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8410e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8410e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8410e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8410e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8410e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8410e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_8410e_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8410e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8410e_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_8410e_row0_col1" class="data row0 col1" >2.4727</td>
#       <td id="T_8410e_row0_col2" class="data row0 col2" >14.4348</td>
#       <td id="T_8410e_row0_col3" class="data row0 col3" >3.7993</td>
#       <td id="T_8410e_row0_col4" class="data row0 col4" >0.5465</td>
#       <td id="T_8410e_row0_col5" class="data row0 col5" >0.8786</td>
#       <td id="T_8410e_row0_col6" class="data row0 col6" >8.3720</td>
#       <td id="T_8410e_row0_col7" class="data row0 col7" >0.0939</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Lasso(random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_e7e78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7e78_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e7e78_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e7e78_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e7e78_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e7e78_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e7e78_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e7e78_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e7e78_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7e78_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7e78_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_e7e78_row0_col1" class="data row0 col1" >3.0207</td>
#       <td id="T_e7e78_row0_col2" class="data row0 col2" >35.4451</td>
#       <td id="T_e7e78_row0_col3" class="data row0 col3" >5.9536</td>
#       <td id="T_e7e78_row0_col4" class="data row0 col4" >-0.1135</td>
#       <td id="T_e7e78_row0_col5" class="data row0 col5" >1.0905</td>
#       <td id="T_e7e78_row0_col6" class="data row0 col6" >8.3825</td>
#       <td id="T_e7e78_row0_col7" class="data row0 col7" >0.0059</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model AdaBoostRegressor(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_401de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_401de_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_401de_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_401de_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_401de_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_401de_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_401de_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_401de_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_401de_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_401de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_401de_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_401de_row0_col1" class="data row0 col1" >2.2456</td>
#       <td id="T_401de_row0_col2" class="data row0 col2" >10.4243</td>
#       <td id="T_401de_row0_col3" class="data row0 col3" >3.2287</td>
#       <td id="T_401de_row0_col4" class="data row0 col4" >0.6725</td>
#       <td id="T_401de_row0_col5" class="data row0 col5" >0.8706</td>
#       <td id="T_401de_row0_col6" class="data row0 col6" >8.2260</td>
#       <td id="T_401de_row0_col7" class="data row0 col7" >0.0939</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ElasticNet(random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_43de6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43de6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_43de6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_43de6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_43de6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_43de6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_43de6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_43de6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_43de6_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43de6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43de6_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_43de6_row0_col1" class="data row0 col1" >3.0029</td>
#       <td id="T_43de6_row0_col2" class="data row0 col2" >33.0586</td>
#       <td id="T_43de6_row0_col3" class="data row0 col3" >5.7497</td>
#       <td id="T_43de6_row0_col4" class="data row0 col4" >-0.0385</td>
#       <td id="T_43de6_row0_col5" class="data row0 col5" >0.9772</td>
#       <td id="T_43de6_row0_col6" class="data row0 col6" >8.9067</td>
#       <td id="T_43de6_row0_col7" class="data row0 col7" >-0.1849</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ElasticNet(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_b67b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b67b5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b67b5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b67b5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b67b5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b67b5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b67b5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b67b5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_b67b5_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b67b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b67b5_row0_col0" class="data row0 col0" >Passive Aggressive Regressor</td>
#       <td id="T_b67b5_row0_col1" class="data row0 col1" >2.2102</td>
#       <td id="T_b67b5_row0_col2" class="data row0 col2" >9.7371</td>
#       <td id="T_b67b5_row0_col3" class="data row0 col3" >3.1204</td>
#       <td id="T_b67b5_row0_col4" class="data row0 col4" >0.6941</td>
#       <td id="T_b67b5_row0_col5" class="data row0 col5" >0.7797</td>
#       <td id="T_b67b5_row0_col6" class="data row0 col6" >9.0094</td>
#       <td id="T_b67b5_row0_col7" class="data row0 col7" >0.1233</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model PassiveAggressiveRegressor(random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_d5db9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5db9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d5db9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d5db9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d5db9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d5db9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d5db9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d5db9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d5db9_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5db9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5db9_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_d5db9_row0_col1" class="data row0 col1" >3.0753</td>
#       <td id="T_d5db9_row0_col2" class="data row0 col2" >36.9154</td>
#       <td id="T_d5db9_row0_col3" class="data row0 col3" >6.0758</td>
#       <td id="T_d5db9_row0_col4" class="data row0 col4" >-0.1597</td>
#       <td id="T_d5db9_row0_col5" class="data row0 col5" >1.1608</td>
#       <td id="T_d5db9_row0_col6" class="data row0 col6" >8.4957</td>
#       <td id="T_d5db9_row0_col7" class="data row0 col7" >0.0898</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DecisionTreeRegressor(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_472b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_472b1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_472b1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_472b1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_472b1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_472b1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_472b1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_472b1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_472b1_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_472b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_472b1_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_472b1_row0_col1" class="data row0 col1" >2.0843</td>
#       <td id="T_472b1_row0_col2" class="data row0 col2" >9.9657</td>
#       <td id="T_472b1_row0_col3" class="data row0 col3" >3.1569</td>
#       <td id="T_472b1_row0_col4" class="data row0 col4" >0.6869</td>
#       <td id="T_472b1_row0_col5" class="data row0 col5" >0.7405</td>
#       <td id="T_472b1_row0_col6" class="data row0 col6" >6.8728</td>
#       <td id="T_472b1_row0_col7" class="data row0 col7" >0.1908</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model BayesianRidge(): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_8ecf3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ecf3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8ecf3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8ecf3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8ecf3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8ecf3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8ecf3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8ecf3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_8ecf3_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ecf3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ecf3_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_8ecf3_row0_col1" class="data row0 col1" >2.8952</td>
#       <td id="T_8ecf3_row0_col2" class="data row0 col2" >35.3754</td>
#       <td id="T_8ecf3_row0_col3" class="data row0 col3" >5.9477</td>
#       <td id="T_8ecf3_row0_col4" class="data row0 col4" >-0.1113</td>
#       <td id="T_8ecf3_row0_col5" class="data row0 col5" >1.0775</td>
#       <td id="T_8ecf3_row0_col6" class="data row0 col6" >7.5003</td>
#       <td id="T_8ecf3_row0_col7" class="data row0 col7" >-0.1673</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model HuberRegressor(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_c8c0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8c0b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c8c0b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c8c0b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c8c0b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c8c0b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c8c0b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c8c0b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c8c0b_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8c0b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8c0b_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c8c0b_row0_col1" class="data row0 col1" >3.0157</td>
#       <td id="T_c8c0b_row0_col2" class="data row0 col2" >33.1268</td>
#       <td id="T_c8c0b_row0_col3" class="data row0 col3" >5.7556</td>
#       <td id="T_c8c0b_row0_col4" class="data row0 col4" >-0.0407</td>
#       <td id="T_c8c0b_row0_col5" class="data row0 col5" >0.9749</td>
#       <td id="T_c8c0b_row0_col6" class="data row0 col6" >8.5710</td>
#       <td id="T_c8c0b_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LGBMRegressor(n_jobs=-1, random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_c0d08">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0d08_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c0d08_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c0d08_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c0d08_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c0d08_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c0d08_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c0d08_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c0d08_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0d08_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0d08_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_c0d08_row0_col1" class="data row0 col1" >2.8924</td>
#       <td id="T_c0d08_row0_col2" class="data row0 col2" >35.0560</td>
#       <td id="T_c0d08_row0_col3" class="data row0 col3" >5.9208</td>
#       <td id="T_c0d08_row0_col4" class="data row0 col4" >-0.1013</td>
#       <td id="T_c0d08_row0_col5" class="data row0 col5" >1.0463</td>
#       <td id="T_c0d08_row0_col6" class="data row0 col6" >7.6822</td>
#       <td id="T_c0d08_row0_col7" class="data row0 col7" >-0.2260</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Ridge(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_5ab3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ab3d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5ab3d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5ab3d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5ab3d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5ab3d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5ab3d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5ab3d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5ab3d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ab3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ab3d_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_5ab3d_row0_col1" class="data row0 col1" >3.0157</td>
#       <td id="T_5ab3d_row0_col2" class="data row0 col2" >33.1268</td>
#       <td id="T_5ab3d_row0_col3" class="data row0 col3" >5.7556</td>
#       <td id="T_5ab3d_row0_col4" class="data row0 col4" >-0.0407</td>
#       <td id="T_5ab3d_row0_col5" class="data row0 col5" >0.9749</td>
#       <td id="T_5ab3d_row0_col6" class="data row0 col6" >8.5710</td>
#       <td id="T_5ab3d_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DummyRegressor(): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# <style type="text/css">
# </style>
# <table id="T_dedba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dedba_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dedba_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_dedba_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_dedba_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_dedba_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_dedba_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_dedba_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_dedba_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dedba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dedba_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_dedba_row0_col1" class="data row0 col1" >2.8724</td>
#       <td id="T_dedba_row0_col2" class="data row0 col2" >35.0366</td>
#       <td id="T_dedba_row0_col3" class="data row0 col3" >5.9192</td>
#       <td id="T_dedba_row0_col4" class="data row0 col4" >-0.1007</td>
#       <td id="T_dedba_row0_col5" class="data row0 col5" >1.0431</td>
#       <td id="T_dedba_row0_col6" class="data row0 col6" >7.5739</td>
#       <td id="T_dedba_row0_col7" class="data row0 col7" >-0.2553</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LinearRegression(n_jobs=-1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_87bba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87bba_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_87bba_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_87bba_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_87bba_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_87bba_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_87bba_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_87bba_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_87bba_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87bba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87bba_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_87bba_row0_col1" class="data row0 col1" >1.8958</td>
#       <td id="T_87bba_row0_col2" class="data row0 col2" >7.7968</td>
#       <td id="T_87bba_row0_col3" class="data row0 col3" >2.7923</td>
#       <td id="T_87bba_row0_col4" class="data row0 col4" >0.7551</td>
#       <td id="T_87bba_row0_col5" class="data row0 col5" >0.6065</td>
#       <td id="T_87bba_row0_col6" class="data row0 col6" >6.0743</td>
#       <td id="T_87bba_row0_col7" class="data row0 col7" >0.2700</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Ridge(random_state=2): prediction_label
# Original target shape: (13,), Derived FC shape: (13,)
# Model Th1: DummyRegressor(), Model Th2: OrthogonalMatchingPursuit(), Spearman Correlation: 0.0746905827751051
# Model Th1: AdaBoostRegressor(random_state=1), Model Th2: ElasticNet(random_state=2), Spearman Correlation: 0.010989010989010988
# Model Th1: Ridge(random_state=1), Model Th2: DummyRegressor(), Spearman Correlation: -0.1043956043956044
# Model Th1: KNeighborsRegressor(n_jobs=-1), Model Th2: Lasso(random_state=2), Spearman Correlation: -0.1758241758241758
# Model Th1: LinearRegression(n_jobs=-1), Model Th2: Ridge(random_state=2), Spearman Correlation: -0.23626373626373626
# Model Th1: ElasticNet(random_state=1), Model Th2: PassiveAggressiveRegressor(random_state=2), Spearman Correlation: -0.2582417582417582
# Model Th1: HuberRegressor(), Model Th2: LGBMRegressor(n_jobs=-1, random_state=2), Spearman Correlation: -0.2747252747252747
# Model Th1: LGBMRegressor(n_jobs=-1, random_state=1), Model Th2: LassoLars(random_state=2), Spearman Correlation: -0.2967032967032967
# Model Th1: Lasso(random_state=1), Model Th2: GradientBoostingRegressor(random_state=2), Spearman Correlation: -0.30769230769230765
# Model Th1: RandomForestRegressor(n_jobs=-1, random_state=1), Model Th2: KNeighborsRegressor(n_jobs=-1), Spearman Correlation: -0.3736263736263736
# Model Th1: GradientBoostingRegressor(random_state=1), Model Th2: RandomForestRegressor(n_jobs=-1, random_state=2), Spearman Correlation: -0.4340659340659341
# Model Th1: ExtraTreesRegressor(n_jobs=-1, random_state=1), Model Th2: DecisionTreeRegressor(random_state=2), Spearman Correlation: -0.46153846153846156
# Model Th1: DecisionTreeRegressor(random_state=1), Model Th2: BayesianRidge(), Spearman Correlation: -0.4725274725274725
# Model Th1: OrthogonalMatchingPursuit(), Model Th2: AdaBoostRegressor(random_state=2), Spearman Correlation: -0.47802197802197804
# Model Th1: LassoLars(random_state=1), Model Th2: ExtraTreesRegressor(n_jobs=-1, random_state=2), Spearman Correlation: -0.5879120879120878

# %%
def calculate_spearman_correlation(model_Th1, model_Th2, original_target, invert=False):
    """
    Calculate the Spearman correlation for two models with an optional inversion.
    """
    predictions_Th1 = calculate_predictions(model_Th1)
    predictions_Th2 = calculate_predictions(model_Th2)
    
    # Calculate the derived fold change, allowing for an inversion
    derived_FC = merge_predictions(predictions_Th1, predictions_Th2)
    if invert:
        derived_FC = 1 / derived_FC  # Invert the fold change if needed
    
    # Align derived_FC with original_target
    aligned_data = pd.concat([original_target.reset_index(drop=True), derived_FC.reset_index(drop=True)], axis=1)
    aligned_data.dropna(inplace=True)
    target_aligned, derived_FC_aligned = aligned_data.iloc[:, 0], aligned_data.iloc[:, 1]
    
    # Calculate Spearman correlation
    spearman_corr = spearman_metric(target_aligned, derived_FC_aligned)
    return spearman_corr

# Main code block
spearman_results = []
original_target = df[['FC_day_30_Th1/Th2']]

for model_Th1, model_Th2 in zip(top_models_Th1, top_models_Th2):
    spearman_corr = calculate_spearman_correlation(model_Th1, model_Th2, original_target, invert=False)
    
    # If the correlation is negative, try the inversion
    if spearman_corr < 0:
        spearman_corr = calculate_spearman_correlation(model_Th1, model_Th2, original_target, invert=True)
    
    spearman_results.append((model_Th1, model_Th2, spearman_corr))

# Sort and display positive Spearman correlations
sorted_spearman_results = sorted(spearman_results, key=lambda x: x[2], reverse=True)
for model_Th1, model_Th2, spearman_corr in sorted_spearman_results:
    print(f"Spearman Correlation between Original Target and Derived FC for {model_Th1} and {model_Th2}: {spearman_corr}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_50819">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50819_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_50819_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_50819_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_50819_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_50819_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_50819_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_50819_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_50819_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50819_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50819_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_50819_row0_col1" class="data row0 col1" >3.0009</td>
#       <td id="T_50819_row0_col2" class="data row0 col2" >35.3816</td>
#       <td id="T_50819_row0_col3" class="data row0 col3" >5.9482</td>
#       <td id="T_50819_row0_col4" class="data row0 col4" >-0.1115</td>
#       <td id="T_50819_row0_col5" class="data row0 col5" >1.0788</td>
#       <td id="T_50819_row0_col6" class="data row0 col6" >8.5902</td>
#       <td id="T_50819_row0_col7" class="data row0 col7" >0.0675</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model RandomForestRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_f612f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f612f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f612f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f612f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f612f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f612f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f612f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f612f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f612f_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f612f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f612f_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_f612f_row0_col1" class="data row0 col1" >2.6516</td>
#       <td id="T_f612f_row0_col2" class="data row0 col2" >30.3164</td>
#       <td id="T_f612f_row0_col3" class="data row0 col3" >5.5060</td>
#       <td id="T_f612f_row0_col4" class="data row0 col4" >0.0476</td>
#       <td id="T_f612f_row0_col5" class="data row0 col5" >0.8929</td>
#       <td id="T_f612f_row0_col6" class="data row0 col6" >4.7857</td>
#       <td id="T_f612f_row0_col7" class="data row0 col7" >0.2997</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model KNeighborsRegressor(n_jobs=-1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_54b6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54b6d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_54b6d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_54b6d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_54b6d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_54b6d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_54b6d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_54b6d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_54b6d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54b6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54b6d_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_54b6d_row0_col1" class="data row0 col1" >3.0009</td>
#       <td id="T_54b6d_row0_col2" class="data row0 col2" >35.3816</td>
#       <td id="T_54b6d_row0_col3" class="data row0 col3" >5.9482</td>
#       <td id="T_54b6d_row0_col4" class="data row0 col4" >-0.1115</td>
#       <td id="T_54b6d_row0_col5" class="data row0 col5" >1.0788</td>
#       <td id="T_54b6d_row0_col6" class="data row0 col6" >8.5902</td>
#       <td id="T_54b6d_row0_col7" class="data row0 col7" >0.0675</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model RandomForestRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_be366">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be366_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_be366_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_be366_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_be366_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_be366_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_be366_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_be366_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_be366_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be366_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be366_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_be366_row0_col1" class="data row0 col1" >2.6516</td>
#       <td id="T_be366_row0_col2" class="data row0 col2" >30.3164</td>
#       <td id="T_be366_row0_col3" class="data row0 col3" >5.5060</td>
#       <td id="T_be366_row0_col4" class="data row0 col4" >0.0476</td>
#       <td id="T_be366_row0_col5" class="data row0 col5" >0.8929</td>
#       <td id="T_be366_row0_col6" class="data row0 col6" >4.7857</td>
#       <td id="T_be366_row0_col7" class="data row0 col7" >0.2997</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model KNeighborsRegressor(n_jobs=-1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_ba2f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba2f5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ba2f5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ba2f5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ba2f5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ba2f5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ba2f5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ba2f5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ba2f5_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba2f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba2f5_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_ba2f5_row0_col1" class="data row0 col1" >3.1775</td>
#       <td id="T_ba2f5_row0_col2" class="data row0 col2" >32.7977</td>
#       <td id="T_ba2f5_row0_col3" class="data row0 col3" >5.7269</td>
#       <td id="T_ba2f5_row0_col4" class="data row0 col4" >-0.0303</td>
#       <td id="T_ba2f5_row0_col5" class="data row0 col5" >1.0130</td>
#       <td id="T_ba2f5_row0_col6" class="data row0 col6" >10.1715</td>
#       <td id="T_ba2f5_row0_col7" class="data row0 col7" >0.0458</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model OrthogonalMatchingPursuit(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_93fa1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93fa1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_93fa1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_93fa1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_93fa1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_93fa1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_93fa1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_93fa1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_93fa1_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93fa1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93fa1_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_93fa1_row0_col1" class="data row0 col1" >2.5973</td>
#       <td id="T_93fa1_row0_col2" class="data row0 col2" >24.4577</td>
#       <td id="T_93fa1_row0_col3" class="data row0 col3" >4.9455</td>
#       <td id="T_93fa1_row0_col4" class="data row0 col4" >0.2317</td>
#       <td id="T_93fa1_row0_col5" class="data row0 col5" >0.8417</td>
#       <td id="T_93fa1_row0_col6" class="data row0 col6" >6.7666</td>
#       <td id="T_93fa1_row0_col7" class="data row0 col7" >0.0692</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model AdaBoostRegressor(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_1aa02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1aa02_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1aa02_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1aa02_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1aa02_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1aa02_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1aa02_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1aa02_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1aa02_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1aa02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1aa02_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_1aa02_row0_col1" class="data row0 col1" >3.1775</td>
#       <td id="T_1aa02_row0_col2" class="data row0 col2" >32.7977</td>
#       <td id="T_1aa02_row0_col3" class="data row0 col3" >5.7269</td>
#       <td id="T_1aa02_row0_col4" class="data row0 col4" >-0.0303</td>
#       <td id="T_1aa02_row0_col5" class="data row0 col5" >1.0130</td>
#       <td id="T_1aa02_row0_col6" class="data row0 col6" >10.1715</td>
#       <td id="T_1aa02_row0_col7" class="data row0 col7" >0.0458</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model OrthogonalMatchingPursuit(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_833ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_833ee_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_833ee_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_833ee_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_833ee_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_833ee_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_833ee_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_833ee_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_833ee_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_833ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_833ee_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_833ee_row0_col1" class="data row0 col1" >2.5973</td>
#       <td id="T_833ee_row0_col2" class="data row0 col2" >24.4577</td>
#       <td id="T_833ee_row0_col3" class="data row0 col3" >4.9455</td>
#       <td id="T_833ee_row0_col4" class="data row0 col4" >0.2317</td>
#       <td id="T_833ee_row0_col5" class="data row0 col5" >0.8417</td>
#       <td id="T_833ee_row0_col6" class="data row0 col6" >6.7666</td>
#       <td id="T_833ee_row0_col7" class="data row0 col7" >0.0692</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model AdaBoostRegressor(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_f72d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f72d4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f72d4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f72d4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f72d4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f72d4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f72d4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f72d4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f72d4_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f72d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f72d4_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_f72d4_row0_col1" class="data row0 col1" >3.1608</td>
#       <td id="T_f72d4_row0_col2" class="data row0 col2" >36.7896</td>
#       <td id="T_f72d4_row0_col3" class="data row0 col3" >6.0654</td>
#       <td id="T_f72d4_row0_col4" class="data row0 col4" >-0.1558</td>
#       <td id="T_f72d4_row0_col5" class="data row0 col5" >1.1784</td>
#       <td id="T_f72d4_row0_col6" class="data row0 col6" >9.3884</td>
#       <td id="T_f72d4_row0_col7" class="data row0 col7" >-0.0352</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model GradientBoostingRegressor(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_01398">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01398_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_01398_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_01398_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_01398_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_01398_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_01398_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_01398_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_01398_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01398_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01398_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_01398_row0_col1" class="data row0 col1" >2.6454</td>
#       <td id="T_01398_row0_col2" class="data row0 col2" >24.0143</td>
#       <td id="T_01398_row0_col3" class="data row0 col3" >4.9004</td>
#       <td id="T_01398_row0_col4" class="data row0 col4" >0.2456</td>
#       <td id="T_01398_row0_col5" class="data row0 col5" >0.8158</td>
#       <td id="T_01398_row0_col6" class="data row0 col6" >7.8242</td>
#       <td id="T_01398_row0_col7" class="data row0 col7" >0.2700</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model RandomForestRegressor(n_jobs=-1, random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_ff982">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff982_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff982_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ff982_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ff982_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ff982_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ff982_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ff982_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ff982_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff982_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff982_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ff982_row0_col1" class="data row0 col1" >3.1608</td>
#       <td id="T_ff982_row0_col2" class="data row0 col2" >36.7896</td>
#       <td id="T_ff982_row0_col3" class="data row0 col3" >6.0654</td>
#       <td id="T_ff982_row0_col4" class="data row0 col4" >-0.1558</td>
#       <td id="T_ff982_row0_col5" class="data row0 col5" >1.1784</td>
#       <td id="T_ff982_row0_col6" class="data row0 col6" >9.3884</td>
#       <td id="T_ff982_row0_col7" class="data row0 col7" >-0.0352</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model GradientBoostingRegressor(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_f176d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f176d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f176d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f176d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f176d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f176d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f176d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f176d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f176d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f176d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f176d_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_f176d_row0_col1" class="data row0 col1" >2.6454</td>
#       <td id="T_f176d_row0_col2" class="data row0 col2" >24.0143</td>
#       <td id="T_f176d_row0_col3" class="data row0 col3" >4.9004</td>
#       <td id="T_f176d_row0_col4" class="data row0 col4" >0.2456</td>
#       <td id="T_f176d_row0_col5" class="data row0 col5" >0.8158</td>
#       <td id="T_f176d_row0_col6" class="data row0 col6" >7.8242</td>
#       <td id="T_f176d_row0_col7" class="data row0 col7" >0.2700</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model RandomForestRegressor(n_jobs=-1, random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_1cd18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1cd18_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1cd18_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1cd18_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1cd18_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1cd18_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1cd18_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1cd18_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1cd18_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cd18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1cd18_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_1cd18_row0_col1" class="data row0 col1" >2.9597</td>
#       <td id="T_1cd18_row0_col2" class="data row0 col2" >36.0958</td>
#       <td id="T_1cd18_row0_col3" class="data row0 col3" >6.0080</td>
#       <td id="T_1cd18_row0_col4" class="data row0 col4" >-0.1340</td>
#       <td id="T_1cd18_row0_col5" class="data row0 col5" >1.1211</td>
#       <td id="T_1cd18_row0_col6" class="data row0 col6" >7.4801</td>
#       <td id="T_1cd18_row0_col7" class="data row0 col7" >0.1115</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ExtraTreesRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_3caf4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3caf4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3caf4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3caf4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3caf4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3caf4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3caf4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3caf4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3caf4_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3caf4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3caf4_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_3caf4_row0_col1" class="data row0 col1" >2.9850</td>
#       <td id="T_3caf4_row0_col2" class="data row0 col2" >27.3063</td>
#       <td id="T_3caf4_row0_col3" class="data row0 col3" >5.2255</td>
#       <td id="T_3caf4_row0_col4" class="data row0 col4" >0.1422</td>
#       <td id="T_3caf4_row0_col5" class="data row0 col5" >0.9845</td>
#       <td id="T_3caf4_row0_col6" class="data row0 col6" >10.0778</td>
#       <td id="T_3caf4_row0_col7" class="data row0 col7" >0.0928</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DecisionTreeRegressor(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_13512">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13512_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_13512_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_13512_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_13512_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_13512_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_13512_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_13512_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_13512_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13512_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13512_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_13512_row0_col1" class="data row0 col1" >2.9597</td>
#       <td id="T_13512_row0_col2" class="data row0 col2" >36.0958</td>
#       <td id="T_13512_row0_col3" class="data row0 col3" >6.0080</td>
#       <td id="T_13512_row0_col4" class="data row0 col4" >-0.1340</td>
#       <td id="T_13512_row0_col5" class="data row0 col5" >1.1211</td>
#       <td id="T_13512_row0_col6" class="data row0 col6" >7.4801</td>
#       <td id="T_13512_row0_col7" class="data row0 col7" >0.1115</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ExtraTreesRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_a767e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a767e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a767e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a767e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a767e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a767e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a767e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a767e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a767e_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a767e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a767e_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_a767e_row0_col1" class="data row0 col1" >2.9850</td>
#       <td id="T_a767e_row0_col2" class="data row0 col2" >27.3063</td>
#       <td id="T_a767e_row0_col3" class="data row0 col3" >5.2255</td>
#       <td id="T_a767e_row0_col4" class="data row0 col4" >0.1422</td>
#       <td id="T_a767e_row0_col5" class="data row0 col5" >0.9845</td>
#       <td id="T_a767e_row0_col6" class="data row0 col6" >10.0778</td>
#       <td id="T_a767e_row0_col7" class="data row0 col7" >0.0928</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DecisionTreeRegressor(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_80d67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80d67_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_80d67_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_80d67_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_80d67_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_80d67_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_80d67_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_80d67_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_80d67_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80d67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80d67_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_80d67_row0_col1" class="data row0 col1" >3.0857</td>
#       <td id="T_80d67_row0_col2" class="data row0 col2" >32.7598</td>
#       <td id="T_80d67_row0_col3" class="data row0 col3" >5.7236</td>
#       <td id="T_80d67_row0_col4" class="data row0 col4" >-0.0292</td>
#       <td id="T_80d67_row0_col5" class="data row0 col5" >0.9892</td>
#       <td id="T_80d67_row0_col6" class="data row0 col6" >9.6214</td>
#       <td id="T_80d67_row0_col7" class="data row0 col7" >-0.2172</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Lasso(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_a25f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a25f0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a25f0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a25f0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a25f0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a25f0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a25f0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a25f0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a25f0_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a25f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a25f0_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_a25f0_row0_col1" class="data row0 col1" >2.7364</td>
#       <td id="T_a25f0_row0_col2" class="data row0 col2" >21.7204</td>
#       <td id="T_a25f0_row0_col3" class="data row0 col3" >4.6605</td>
#       <td id="T_a25f0_row0_col4" class="data row0 col4" >0.3176</td>
#       <td id="T_a25f0_row0_col5" class="data row0 col5" >0.9104</td>
#       <td id="T_a25f0_row0_col6" class="data row0 col6" >9.4035</td>
#       <td id="T_a25f0_row0_col7" class="data row0 col7" >0.2377</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model GradientBoostingRegressor(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_910ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_910ab_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_910ab_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_910ab_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_910ab_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_910ab_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_910ab_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_910ab_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_910ab_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_910ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_910ab_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_910ab_row0_col1" class="data row0 col1" >3.0857</td>
#       <td id="T_910ab_row0_col2" class="data row0 col2" >32.7598</td>
#       <td id="T_910ab_row0_col3" class="data row0 col3" >5.7236</td>
#       <td id="T_910ab_row0_col4" class="data row0 col4" >-0.0292</td>
#       <td id="T_910ab_row0_col5" class="data row0 col5" >0.9892</td>
#       <td id="T_910ab_row0_col6" class="data row0 col6" >9.6214</td>
#       <td id="T_910ab_row0_col7" class="data row0 col7" >-0.2172</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Lasso(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_51053">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51053_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_51053_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_51053_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_51053_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_51053_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_51053_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_51053_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_51053_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51053_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51053_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_51053_row0_col1" class="data row0 col1" >2.7364</td>
#       <td id="T_51053_row0_col2" class="data row0 col2" >21.7204</td>
#       <td id="T_51053_row0_col3" class="data row0 col3" >4.6605</td>
#       <td id="T_51053_row0_col4" class="data row0 col4" >0.3176</td>
#       <td id="T_51053_row0_col5" class="data row0 col5" >0.9104</td>
#       <td id="T_51053_row0_col6" class="data row0 col6" >9.4035</td>
#       <td id="T_51053_row0_col7" class="data row0 col7" >0.2377</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model GradientBoostingRegressor(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_833b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_833b0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_833b0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_833b0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_833b0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_833b0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_833b0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_833b0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_833b0_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_833b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_833b0_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_833b0_row0_col1" class="data row0 col1" >3.0857</td>
#       <td id="T_833b0_row0_col2" class="data row0 col2" >32.7598</td>
#       <td id="T_833b0_row0_col3" class="data row0 col3" >5.7236</td>
#       <td id="T_833b0_row0_col4" class="data row0 col4" >-0.0292</td>
#       <td id="T_833b0_row0_col5" class="data row0 col5" >0.9892</td>
#       <td id="T_833b0_row0_col6" class="data row0 col6" >9.6214</td>
#       <td id="T_833b0_row0_col7" class="data row0 col7" >-0.2172</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LassoLars(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_7c6da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c6da_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7c6da_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7c6da_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7c6da_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7c6da_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7c6da_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7c6da_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7c6da_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c6da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c6da_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_7c6da_row0_col1" class="data row0 col1" >2.4520</td>
#       <td id="T_7c6da_row0_col2" class="data row0 col2" >24.5548</td>
#       <td id="T_7c6da_row0_col3" class="data row0 col3" >4.9553</td>
#       <td id="T_7c6da_row0_col4" class="data row0 col4" >0.2286</td>
#       <td id="T_7c6da_row0_col5" class="data row0 col5" >0.7503</td>
#       <td id="T_7c6da_row0_col6" class="data row0 col6" >6.0588</td>
#       <td id="T_7c6da_row0_col7" class="data row0 col7" >0.3052</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ExtraTreesRegressor(n_jobs=-1, random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_28a6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28a6b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_28a6b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_28a6b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_28a6b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_28a6b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_28a6b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_28a6b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_28a6b_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28a6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28a6b_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_28a6b_row0_col1" class="data row0 col1" >3.0857</td>
#       <td id="T_28a6b_row0_col2" class="data row0 col2" >32.7598</td>
#       <td id="T_28a6b_row0_col3" class="data row0 col3" >5.7236</td>
#       <td id="T_28a6b_row0_col4" class="data row0 col4" >-0.0292</td>
#       <td id="T_28a6b_row0_col5" class="data row0 col5" >0.9892</td>
#       <td id="T_28a6b_row0_col6" class="data row0 col6" >9.6214</td>
#       <td id="T_28a6b_row0_col7" class="data row0 col7" >-0.2172</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LassoLars(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_90db5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90db5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_90db5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_90db5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_90db5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_90db5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_90db5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_90db5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_90db5_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90db5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90db5_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_90db5_row0_col1" class="data row0 col1" >2.4520</td>
#       <td id="T_90db5_row0_col2" class="data row0 col2" >24.5548</td>
#       <td id="T_90db5_row0_col3" class="data row0 col3" >4.9553</td>
#       <td id="T_90db5_row0_col4" class="data row0 col4" >0.2286</td>
#       <td id="T_90db5_row0_col5" class="data row0 col5" >0.7503</td>
#       <td id="T_90db5_row0_col6" class="data row0 col6" >6.0588</td>
#       <td id="T_90db5_row0_col7" class="data row0 col7" >0.3052</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ExtraTreesRegressor(n_jobs=-1, random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_10819">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10819_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_10819_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_10819_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_10819_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_10819_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_10819_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_10819_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_10819_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10819_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10819_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_10819_row0_col1" class="data row0 col1" >3.1332</td>
#       <td id="T_10819_row0_col2" class="data row0 col2" >32.6777</td>
#       <td id="T_10819_row0_col3" class="data row0 col3" >5.7164</td>
#       <td id="T_10819_row0_col4" class="data row0 col4" >-0.0266</td>
#       <td id="T_10819_row0_col5" class="data row0 col5" >1.0025</td>
#       <td id="T_10819_row0_col6" class="data row0 col6" >10.0620</td>
#       <td id="T_10819_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DummyRegressor(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_4b883">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b883_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4b883_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4b883_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4b883_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4b883_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4b883_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4b883_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4b883_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b883_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b883_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_4b883_row0_col1" class="data row0 col1" >3.2518</td>
#       <td id="T_4b883_row0_col2" class="data row0 col2" >34.3643</td>
#       <td id="T_4b883_row0_col3" class="data row0 col3" >5.8621</td>
#       <td id="T_4b883_row0_col4" class="data row0 col4" >-0.0796</td>
#       <td id="T_4b883_row0_col5" class="data row0 col5" >1.0764</td>
#       <td id="T_4b883_row0_col6" class="data row0 col6" >9.6987</td>
#       <td id="T_4b883_row0_col7" class="data row0 col7" >0.0458</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model OrthogonalMatchingPursuit(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_3204b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3204b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3204b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3204b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3204b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3204b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3204b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3204b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3204b_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3204b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3204b_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3204b_row0_col1" class="data row0 col1" >3.1332</td>
#       <td id="T_3204b_row0_col2" class="data row0 col2" >32.6777</td>
#       <td id="T_3204b_row0_col3" class="data row0 col3" >5.7164</td>
#       <td id="T_3204b_row0_col4" class="data row0 col4" >-0.0266</td>
#       <td id="T_3204b_row0_col5" class="data row0 col5" >1.0025</td>
#       <td id="T_3204b_row0_col6" class="data row0 col6" >10.0620</td>
#       <td id="T_3204b_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LGBMRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_ac854">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac854_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ac854_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ac854_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ac854_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ac854_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ac854_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ac854_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ac854_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac854_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac854_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_ac854_row0_col1" class="data row0 col1" >2.4727</td>
#       <td id="T_ac854_row0_col2" class="data row0 col2" >14.4349</td>
#       <td id="T_ac854_row0_col3" class="data row0 col3" >3.7993</td>
#       <td id="T_ac854_row0_col4" class="data row0 col4" >0.5465</td>
#       <td id="T_ac854_row0_col5" class="data row0 col5" >0.8786</td>
#       <td id="T_ac854_row0_col6" class="data row0 col6" >8.3720</td>
#       <td id="T_ac854_row0_col7" class="data row0 col7" >0.0939</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LassoLars(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_07e90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07e90_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_07e90_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_07e90_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_07e90_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_07e90_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_07e90_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_07e90_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_07e90_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07e90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07e90_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_07e90_row0_col1" class="data row0 col1" >3.1332</td>
#       <td id="T_07e90_row0_col2" class="data row0 col2" >32.6777</td>
#       <td id="T_07e90_row0_col3" class="data row0 col3" >5.7164</td>
#       <td id="T_07e90_row0_col4" class="data row0 col4" >-0.0266</td>
#       <td id="T_07e90_row0_col5" class="data row0 col5" >1.0025</td>
#       <td id="T_07e90_row0_col6" class="data row0 col6" >10.0620</td>
#       <td id="T_07e90_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LGBMRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_571c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_571c8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_571c8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_571c8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_571c8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_571c8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_571c8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_571c8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_571c8_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_571c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_571c8_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_571c8_row0_col1" class="data row0 col1" >2.4727</td>
#       <td id="T_571c8_row0_col2" class="data row0 col2" >14.4349</td>
#       <td id="T_571c8_row0_col3" class="data row0 col3" >3.7993</td>
#       <td id="T_571c8_row0_col4" class="data row0 col4" >0.5465</td>
#       <td id="T_571c8_row0_col5" class="data row0 col5" >0.8786</td>
#       <td id="T_571c8_row0_col6" class="data row0 col6" >8.3720</td>
#       <td id="T_571c8_row0_col7" class="data row0 col7" >0.0939</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LassoLars(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_56745">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56745_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_56745_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_56745_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_56745_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_56745_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_56745_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_56745_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_56745_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56745_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56745_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_56745_row0_col1" class="data row0 col1" >2.7042</td>
#       <td id="T_56745_row0_col2" class="data row0 col2" >28.6096</td>
#       <td id="T_56745_row0_col3" class="data row0 col3" >5.3488</td>
#       <td id="T_56745_row0_col4" class="data row0 col4" >0.1012</td>
#       <td id="T_56745_row0_col5" class="data row0 col5" >0.8295</td>
# ...
#       <th id="T_8f1a9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8f1a9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8f1a9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8f1a9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8f1a9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8f1a9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8f1a9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_8f1a9_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f1a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f1a9_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8f1a9_row0_col1" class="data row0 col1" >3.0157</td>
#       <td id="T_8f1a9_row0_col2" class="data row0 col2" >33.1268</td>
#       <td id="T_8f1a9_row0_col3" class="data row0 col3" >5.7556</td>
#       <td id="T_8f1a9_row0_col4" class="data row0 col4" >-0.0407</td>
#       <td id="T_8f1a9_row0_col5" class="data row0 col5" >0.9749</td>
#       <td id="T_8f1a9_row0_col6" class="data row0 col6" >8.5710</td>
#       <td id="T_8f1a9_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LGBMRegressor(n_jobs=-1, random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_a3e14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3e14_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a3e14_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a3e14_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a3e14_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a3e14_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a3e14_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a3e14_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a3e14_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3e14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3e14_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_a3e14_row0_col1" class="data row0 col1" >2.8924</td>
#       <td id="T_a3e14_row0_col2" class="data row0 col2" >35.0560</td>
#       <td id="T_a3e14_row0_col3" class="data row0 col3" >5.9208</td>
#       <td id="T_a3e14_row0_col4" class="data row0 col4" >-0.1013</td>
#       <td id="T_a3e14_row0_col5" class="data row0 col5" >1.0463</td>
#       <td id="T_a3e14_row0_col6" class="data row0 col6" >7.6822</td>
#       <td id="T_a3e14_row0_col7" class="data row0 col7" >-0.2260</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Ridge(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_3cbed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cbed_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3cbed_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3cbed_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3cbed_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3cbed_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3cbed_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3cbed_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3cbed_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cbed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3cbed_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_3cbed_row0_col1" class="data row0 col1" >3.0157</td>
#       <td id="T_3cbed_row0_col2" class="data row0 col2" >33.1268</td>
#       <td id="T_3cbed_row0_col3" class="data row0 col3" >5.7556</td>
#       <td id="T_3cbed_row0_col4" class="data row0 col4" >-0.0407</td>
#       <td id="T_3cbed_row0_col5" class="data row0 col5" >0.9749</td>
#       <td id="T_3cbed_row0_col6" class="data row0 col6" >8.5710</td>
#       <td id="T_3cbed_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DummyRegressor(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_fe0f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe0f2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fe0f2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fe0f2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fe0f2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fe0f2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fe0f2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fe0f2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fe0f2_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe0f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe0f2_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_fe0f2_row0_col1" class="data row0 col1" >2.8924</td>
#       <td id="T_fe0f2_row0_col2" class="data row0 col2" >35.0560</td>
#       <td id="T_fe0f2_row0_col3" class="data row0 col3" >5.9208</td>
#       <td id="T_fe0f2_row0_col4" class="data row0 col4" >-0.1013</td>
#       <td id="T_fe0f2_row0_col5" class="data row0 col5" >1.0463</td>
#       <td id="T_fe0f2_row0_col6" class="data row0 col6" >7.6822</td>
#       <td id="T_fe0f2_row0_col7" class="data row0 col7" >-0.2260</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Ridge(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_11ac9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11ac9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_11ac9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_11ac9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_11ac9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_11ac9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_11ac9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_11ac9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_11ac9_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11ac9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11ac9_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_11ac9_row0_col1" class="data row0 col1" >3.0157</td>
#       <td id="T_11ac9_row0_col2" class="data row0 col2" >33.1268</td>
#       <td id="T_11ac9_row0_col3" class="data row0 col3" >5.7556</td>
#       <td id="T_11ac9_row0_col4" class="data row0 col4" >-0.0407</td>
#       <td id="T_11ac9_row0_col5" class="data row0 col5" >0.9749</td>
#       <td id="T_11ac9_row0_col6" class="data row0 col6" >8.5710</td>
#       <td id="T_11ac9_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DummyRegressor(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_621ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_621ad_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_621ad_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_621ad_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_621ad_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_621ad_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_621ad_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_621ad_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_621ad_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_621ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_621ad_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_621ad_row0_col1" class="data row0 col1" >2.8724</td>
#       <td id="T_621ad_row0_col2" class="data row0 col2" >35.0366</td>
#       <td id="T_621ad_row0_col3" class="data row0 col3" >5.9192</td>
#       <td id="T_621ad_row0_col4" class="data row0 col4" >-0.1007</td>
#       <td id="T_621ad_row0_col5" class="data row0 col5" >1.0431</td>
#       <td id="T_621ad_row0_col6" class="data row0 col6" >7.5739</td>
#       <td id="T_621ad_row0_col7" class="data row0 col7" >-0.2553</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LinearRegression(n_jobs=-1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_98ba6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98ba6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_98ba6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_98ba6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_98ba6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_98ba6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_98ba6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_98ba6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_98ba6_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98ba6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98ba6_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_98ba6_row0_col1" class="data row0 col1" >1.8958</td>
#       <td id="T_98ba6_row0_col2" class="data row0 col2" >7.7968</td>
#       <td id="T_98ba6_row0_col3" class="data row0 col3" >2.7923</td>
#       <td id="T_98ba6_row0_col4" class="data row0 col4" >0.7551</td>
#       <td id="T_98ba6_row0_col5" class="data row0 col5" >0.6065</td>
#       <td id="T_98ba6_row0_col6" class="data row0 col6" >6.0743</td>
#       <td id="T_98ba6_row0_col7" class="data row0 col7" >0.2700</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Ridge(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_87a7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87a7f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_87a7f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_87a7f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_87a7f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_87a7f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_87a7f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_87a7f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_87a7f_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87a7f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87a7f_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_87a7f_row0_col1" class="data row0 col1" >2.8724</td>
#       <td id="T_87a7f_row0_col2" class="data row0 col2" >35.0366</td>
#       <td id="T_87a7f_row0_col3" class="data row0 col3" >5.9192</td>
#       <td id="T_87a7f_row0_col4" class="data row0 col4" >-0.1007</td>
#       <td id="T_87a7f_row0_col5" class="data row0 col5" >1.0431</td>
#       <td id="T_87a7f_row0_col6" class="data row0 col6" >7.5739</td>
#       <td id="T_87a7f_row0_col7" class="data row0 col7" >-0.2553</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LinearRegression(n_jobs=-1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_97473">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97473_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_97473_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_97473_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_97473_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_97473_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_97473_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_97473_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_97473_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97473_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97473_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_97473_row0_col1" class="data row0 col1" >1.8958</td>
#       <td id="T_97473_row0_col2" class="data row0 col2" >7.7968</td>
#       <td id="T_97473_row0_col3" class="data row0 col3" >2.7923</td>
#       <td id="T_97473_row0_col4" class="data row0 col4" >0.7551</td>
#       <td id="T_97473_row0_col5" class="data row0 col5" >0.6065</td>
#       <td id="T_97473_row0_col6" class="data row0 col6" >6.0743</td>
#       <td id="T_97473_row0_col7" class="data row0 col7" >0.2700</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Ridge(random_state=2): prediction_label
# Spearman Correlation between Original Target and Derived FC for LassoLars(random_state=1) and ExtraTreesRegressor(n_jobs=-1, random_state=2): 0.5879120879120878
# Spearman Correlation between Original Target and Derived FC for OrthogonalMatchingPursuit() and AdaBoostRegressor(random_state=2): 0.47802197802197804
# Spearman Correlation between Original Target and Derived FC for ExtraTreesRegressor(n_jobs=-1, random_state=1) and DecisionTreeRegressor(random_state=2): 0.46153846153846156
# Spearman Correlation between Original Target and Derived FC for GradientBoostingRegressor(random_state=1) and RandomForestRegressor(n_jobs=-1, random_state=2): 0.4340659340659341
# Spearman Correlation between Original Target and Derived FC for DecisionTreeRegressor(random_state=1) and BayesianRidge(): 0.4010989010989011
# Spearman Correlation between Original Target and Derived FC for RandomForestRegressor(n_jobs=-1, random_state=1) and KNeighborsRegressor(n_jobs=-1): 0.3736263736263736
# Spearman Correlation between Original Target and Derived FC for Lasso(random_state=1) and GradientBoostingRegressor(random_state=2): 0.30769230769230765
# Spearman Correlation between Original Target and Derived FC for LGBMRegressor(n_jobs=-1, random_state=1) and LassoLars(random_state=2): 0.2967032967032967
# Spearman Correlation between Original Target and Derived FC for HuberRegressor() and LGBMRegressor(n_jobs=-1, random_state=2): 0.2747252747252747
# Spearman Correlation between Original Target and Derived FC for ElasticNet(random_state=1) and PassiveAggressiveRegressor(random_state=2): 0.2582417582417582
# Spearman Correlation between Original Target and Derived FC for KNeighborsRegressor(n_jobs=-1) and Lasso(random_state=2): 0.1758241758241758
# Spearman Correlation between Original Target and Derived FC for LinearRegression(n_jobs=-1) and Ridge(random_state=2): 0.16483516483516483
# Spearman Correlation between Original Target and Derived FC for Ridge(random_state=1) and DummyRegressor(): 0.1043956043956044
# Spearman Correlation between Original Target and Derived FC for DummyRegressor() and OrthogonalMatchingPursuit(): 0.0746905827751051
# Spearman Correlation between Original Target and Derived FC for AdaBoostRegressor(random_state=1) and ElasticNet(random_state=2): 0.010989010989010988

# %%
sorted_spearman_results[0]
# Out:
# (LassoLars(random_state=1),
#  ExtraTreesRegressor(n_jobs=-1, random_state=2),
#  0.5879120879120878)

# %%
# save sorted_spearman_results[0][0]
save_model(sorted_spearman_results[0][0], 'Th1_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['day_0_Th2_PHA', 'day_0_IL17A_PT',
#                                               'day_0_Th2_PT', 'day_0_IL17A_PHA',
#                                               'day_0_Th1_PHA', 'day_0_Th1_PT',
#                                               'age'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['infancy_vac', 'biological_sex'],
#                                      transformer=SimpleImputer(strategy='mos...
#                   TransformerWrapper(include=['infancy_vac', 'biological_sex'],
#                                      transformer=OrdinalEncoder(cols=['infancy_vac',
#                                                                       'biological_sex'],
#                                                                 handle_missing='return_nan',
#                                                                 mapping=[{'col': 'infancy_vac',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': aP     0
#  wP     1
#  NaN   -1
#  dtype: int64},
#                                                                          {'col': 'biological_sex',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': Female    0
#  Male      1
#  NaN      -1
#  dtype: int64}]))),
#                  ('trained_model', LassoLars(random_state=1))]),
#  'Th1_model.pkl')

# %%
# save sorted_spearman_results[0][1]
save_model(sorted_spearman_results[0][1], 'Th2_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['day_0_Th2_PHA', 'day_0_IL17A_PT',
#                                               'day_0_Th2_PT', 'day_0_IL17A_PHA',
#                                               'day_0_Th1_PHA', 'day_0_Th1_PT',
#                                               'age'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['infancy_vac', 'biological_sex'],
#                                      transformer=SimpleImputer(strategy='mos...
#                   TransformerWrapper(include=['infancy_vac', 'biological_sex'],
#                                      transformer=OrdinalEncoder(cols=['infancy_vac',
#                                                                       'biological_sex'],
#                                                                 handle_missing='return_nan',
#                                                                 mapping=[{'col': 'infancy_vac',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': aP     0
#  wP     1
#  NaN   -1
#  dtype: int64},
#                                                                          {'col': 'biological_sex',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': Female    0
#  Male      1
#  NaN      -1
#  dtype: int64}]))),
#                  ('trained_model',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=2))]),
#  'Th2_model.pkl')

# %%
def calculate_spearman_correlation(model_Th1, model_Th2, original_target):
    """
    Calculate the Spearman correlation for two models.
    """
    predictions_Th1 = calculate_predictions(model_Th1)
    predictions_Th2 = calculate_predictions(model_Th2)
    
    # Calculate the derived fold change for Th1 and Th2 predictions
    derived_FC = merge_predictions(predictions_Th1, predictions_Th2)
    
    # Align derived_FC with original_target
    aligned_data = pd.concat([original_target.reset_index(drop=True), derived_FC.reset_index(drop=True)], axis=1)
    aligned_data.dropna(inplace=True)  # Drop any rows with NaN values if predictions or targets don't align
    target_aligned, derived_FC_aligned = aligned_data.iloc[:, 0], aligned_data.iloc[:, 1]
    
    # Calculate Spearman correlation
    spearman_corr = spearman_metric(target_aligned, derived_FC_aligned)
    return spearman_corr

# Main code block
spearman_results = []
original_target = df[['FC_day_30_Th1/Th2']]

for model_Th1, model_Th2 in zip(top_models_Th1, top_models_Th2):
    spearman_corr = calculate_spearman_correlation(model_Th1, model_Th2, original_target)
    spearman_results.append((model_Th1, model_Th2, spearman_corr))

# Sort and display Spearman correlations only
sorted_spearman_results = sorted(spearman_results, key=lambda x: x[2], reverse=True)
for model_Th1, model_Th2, spearman_corr in sorted_spearman_results:
    print(f"Spearman Correlation between Original Target and Derived FC for {model_Th1} and {model_Th2}: {spearman_corr}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_40e3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40e3b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_40e3b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_40e3b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_40e3b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_40e3b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_40e3b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_40e3b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_40e3b_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40e3b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40e3b_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_40e3b_row0_col1" class="data row0 col1" >3.0009</td>
#       <td id="T_40e3b_row0_col2" class="data row0 col2" >35.3816</td>
#       <td id="T_40e3b_row0_col3" class="data row0 col3" >5.9482</td>
#       <td id="T_40e3b_row0_col4" class="data row0 col4" >-0.1115</td>
#       <td id="T_40e3b_row0_col5" class="data row0 col5" >1.0788</td>
#       <td id="T_40e3b_row0_col6" class="data row0 col6" >8.5902</td>
#       <td id="T_40e3b_row0_col7" class="data row0 col7" >0.0675</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model RandomForestRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_ea5a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea5a4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ea5a4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ea5a4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ea5a4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ea5a4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ea5a4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ea5a4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_ea5a4_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea5a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea5a4_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_ea5a4_row0_col1" class="data row0 col1" >2.6516</td>
#       <td id="T_ea5a4_row0_col2" class="data row0 col2" >30.3164</td>
#       <td id="T_ea5a4_row0_col3" class="data row0 col3" >5.5060</td>
#       <td id="T_ea5a4_row0_col4" class="data row0 col4" >0.0476</td>
#       <td id="T_ea5a4_row0_col5" class="data row0 col5" >0.8929</td>
#       <td id="T_ea5a4_row0_col6" class="data row0 col6" >4.7857</td>
#       <td id="T_ea5a4_row0_col7" class="data row0 col7" >0.2997</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model KNeighborsRegressor(n_jobs=-1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_26b7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26b7e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_26b7e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_26b7e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_26b7e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_26b7e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_26b7e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_26b7e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_26b7e_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26b7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26b7e_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_26b7e_row0_col1" class="data row0 col1" >3.1775</td>
#       <td id="T_26b7e_row0_col2" class="data row0 col2" >32.7977</td>
#       <td id="T_26b7e_row0_col3" class="data row0 col3" >5.7269</td>
#       <td id="T_26b7e_row0_col4" class="data row0 col4" >-0.0303</td>
#       <td id="T_26b7e_row0_col5" class="data row0 col5" >1.0130</td>
#       <td id="T_26b7e_row0_col6" class="data row0 col6" >10.1715</td>
#       <td id="T_26b7e_row0_col7" class="data row0 col7" >0.0458</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model OrthogonalMatchingPursuit(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_a7b8c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7b8c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a7b8c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a7b8c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a7b8c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a7b8c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a7b8c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a7b8c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a7b8c_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7b8c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7b8c_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_a7b8c_row0_col1" class="data row0 col1" >2.5973</td>
#       <td id="T_a7b8c_row0_col2" class="data row0 col2" >24.4577</td>
#       <td id="T_a7b8c_row0_col3" class="data row0 col3" >4.9455</td>
#       <td id="T_a7b8c_row0_col4" class="data row0 col4" >0.2317</td>
#       <td id="T_a7b8c_row0_col5" class="data row0 col5" >0.8417</td>
#       <td id="T_a7b8c_row0_col6" class="data row0 col6" >6.7666</td>
#       <td id="T_a7b8c_row0_col7" class="data row0 col7" >0.0692</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model AdaBoostRegressor(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_b9836">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9836_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b9836_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b9836_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b9836_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b9836_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b9836_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b9836_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_b9836_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9836_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9836_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_b9836_row0_col1" class="data row0 col1" >3.1608</td>
#       <td id="T_b9836_row0_col2" class="data row0 col2" >36.7896</td>
#       <td id="T_b9836_row0_col3" class="data row0 col3" >6.0654</td>
#       <td id="T_b9836_row0_col4" class="data row0 col4" >-0.1558</td>
#       <td id="T_b9836_row0_col5" class="data row0 col5" >1.1784</td>
#       <td id="T_b9836_row0_col6" class="data row0 col6" >9.3884</td>
#       <td id="T_b9836_row0_col7" class="data row0 col7" >-0.0352</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model GradientBoostingRegressor(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_46d75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46d75_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_46d75_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_46d75_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_46d75_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_46d75_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_46d75_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_46d75_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_46d75_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46d75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46d75_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_46d75_row0_col1" class="data row0 col1" >2.6454</td>
#       <td id="T_46d75_row0_col2" class="data row0 col2" >24.0143</td>
#       <td id="T_46d75_row0_col3" class="data row0 col3" >4.9004</td>
#       <td id="T_46d75_row0_col4" class="data row0 col4" >0.2456</td>
#       <td id="T_46d75_row0_col5" class="data row0 col5" >0.8158</td>
#       <td id="T_46d75_row0_col6" class="data row0 col6" >7.8242</td>
#       <td id="T_46d75_row0_col7" class="data row0 col7" >0.2700</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model RandomForestRegressor(n_jobs=-1, random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_2b882">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b882_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2b882_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2b882_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2b882_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2b882_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2b882_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2b882_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_2b882_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b882_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b882_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_2b882_row0_col1" class="data row0 col1" >2.9597</td>
#       <td id="T_2b882_row0_col2" class="data row0 col2" >36.0958</td>
#       <td id="T_2b882_row0_col3" class="data row0 col3" >6.0080</td>
#       <td id="T_2b882_row0_col4" class="data row0 col4" >-0.1340</td>
#       <td id="T_2b882_row0_col5" class="data row0 col5" >1.1211</td>
#       <td id="T_2b882_row0_col6" class="data row0 col6" >7.4801</td>
#       <td id="T_2b882_row0_col7" class="data row0 col7" >0.1115</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ExtraTreesRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_9054e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9054e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9054e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9054e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9054e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9054e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9054e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9054e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9054e_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9054e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9054e_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_9054e_row0_col1" class="data row0 col1" >2.9850</td>
#       <td id="T_9054e_row0_col2" class="data row0 col2" >27.3063</td>
#       <td id="T_9054e_row0_col3" class="data row0 col3" >5.2255</td>
#       <td id="T_9054e_row0_col4" class="data row0 col4" >0.1422</td>
#       <td id="T_9054e_row0_col5" class="data row0 col5" >0.9845</td>
#       <td id="T_9054e_row0_col6" class="data row0 col6" >10.0778</td>
#       <td id="T_9054e_row0_col7" class="data row0 col7" >0.0928</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DecisionTreeRegressor(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_4c644">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c644_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4c644_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4c644_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4c644_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4c644_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4c644_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4c644_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4c644_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c644_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c644_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_4c644_row0_col1" class="data row0 col1" >3.0857</td>
#       <td id="T_4c644_row0_col2" class="data row0 col2" >32.7598</td>
#       <td id="T_4c644_row0_col3" class="data row0 col3" >5.7236</td>
#       <td id="T_4c644_row0_col4" class="data row0 col4" >-0.0292</td>
#       <td id="T_4c644_row0_col5" class="data row0 col5" >0.9892</td>
#       <td id="T_4c644_row0_col6" class="data row0 col6" >9.6214</td>
#       <td id="T_4c644_row0_col7" class="data row0 col7" >-0.2172</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Lasso(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_b772d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b772d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b772d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b772d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b772d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b772d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b772d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b772d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_b772d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b772d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b772d_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_b772d_row0_col1" class="data row0 col1" >2.7364</td>
#       <td id="T_b772d_row0_col2" class="data row0 col2" >21.7204</td>
#       <td id="T_b772d_row0_col3" class="data row0 col3" >4.6605</td>
#       <td id="T_b772d_row0_col4" class="data row0 col4" >0.3176</td>
#       <td id="T_b772d_row0_col5" class="data row0 col5" >0.9104</td>
#       <td id="T_b772d_row0_col6" class="data row0 col6" >9.4035</td>
#       <td id="T_b772d_row0_col7" class="data row0 col7" >0.2377</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model GradientBoostingRegressor(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_9579d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9579d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9579d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9579d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9579d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9579d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9579d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9579d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9579d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9579d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9579d_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_9579d_row0_col1" class="data row0 col1" >3.0857</td>
#       <td id="T_9579d_row0_col2" class="data row0 col2" >32.7598</td>
#       <td id="T_9579d_row0_col3" class="data row0 col3" >5.7236</td>
#       <td id="T_9579d_row0_col4" class="data row0 col4" >-0.0292</td>
#       <td id="T_9579d_row0_col5" class="data row0 col5" >0.9892</td>
#       <td id="T_9579d_row0_col6" class="data row0 col6" >9.6214</td>
#       <td id="T_9579d_row0_col7" class="data row0 col7" >-0.2172</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LassoLars(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_96c67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96c67_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_96c67_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_96c67_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_96c67_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_96c67_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_96c67_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_96c67_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_96c67_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96c67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96c67_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_96c67_row0_col1" class="data row0 col1" >2.4520</td>
#       <td id="T_96c67_row0_col2" class="data row0 col2" >24.5548</td>
#       <td id="T_96c67_row0_col3" class="data row0 col3" >4.9553</td>
#       <td id="T_96c67_row0_col4" class="data row0 col4" >0.2286</td>
#       <td id="T_96c67_row0_col5" class="data row0 col5" >0.7503</td>
#       <td id="T_96c67_row0_col6" class="data row0 col6" >6.0588</td>
#       <td id="T_96c67_row0_col7" class="data row0 col7" >0.3052</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ExtraTreesRegressor(n_jobs=-1, random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_7cbf1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cbf1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7cbf1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7cbf1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7cbf1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7cbf1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7cbf1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7cbf1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7cbf1_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cbf1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7cbf1_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_7cbf1_row0_col1" class="data row0 col1" >3.1332</td>
#       <td id="T_7cbf1_row0_col2" class="data row0 col2" >32.6777</td>
#       <td id="T_7cbf1_row0_col3" class="data row0 col3" >5.7164</td>
#       <td id="T_7cbf1_row0_col4" class="data row0 col4" >-0.0266</td>
#       <td id="T_7cbf1_row0_col5" class="data row0 col5" >1.0025</td>
#       <td id="T_7cbf1_row0_col6" class="data row0 col6" >10.0620</td>
#       <td id="T_7cbf1_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DummyRegressor(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_2f694">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f694_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2f694_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2f694_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2f694_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2f694_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2f694_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2f694_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_2f694_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f694_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f694_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_2f694_row0_col1" class="data row0 col1" >3.2518</td>
#       <td id="T_2f694_row0_col2" class="data row0 col2" >34.3643</td>
#       <td id="T_2f694_row0_col3" class="data row0 col3" >5.8621</td>
#       <td id="T_2f694_row0_col4" class="data row0 col4" >-0.0796</td>
#       <td id="T_2f694_row0_col5" class="data row0 col5" >1.0764</td>
#       <td id="T_2f694_row0_col6" class="data row0 col6" >9.6987</td>
#       <td id="T_2f694_row0_col7" class="data row0 col7" >0.0458</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model OrthogonalMatchingPursuit(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_a5b58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5b58_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a5b58_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a5b58_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a5b58_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a5b58_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a5b58_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a5b58_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a5b58_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5b58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5b58_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a5b58_row0_col1" class="data row0 col1" >3.1332</td>
#       <td id="T_a5b58_row0_col2" class="data row0 col2" >32.6777</td>
#       <td id="T_a5b58_row0_col3" class="data row0 col3" >5.7164</td>
#       <td id="T_a5b58_row0_col4" class="data row0 col4" >-0.0266</td>
#       <td id="T_a5b58_row0_col5" class="data row0 col5" >1.0025</td>
#       <td id="T_a5b58_row0_col6" class="data row0 col6" >10.0620</td>
#       <td id="T_a5b58_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LGBMRegressor(n_jobs=-1, random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_caf07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_caf07_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_caf07_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_caf07_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_caf07_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_caf07_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_caf07_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_caf07_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_caf07_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_caf07_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_caf07_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_caf07_row0_col1" class="data row0 col1" >2.4727</td>
#       <td id="T_caf07_row0_col2" class="data row0 col2" >14.4349</td>
#       <td id="T_caf07_row0_col3" class="data row0 col3" >3.7993</td>
#       <td id="T_caf07_row0_col4" class="data row0 col4" >0.5465</td>
#       <td id="T_caf07_row0_col5" class="data row0 col5" >0.8786</td>
#       <td id="T_caf07_row0_col6" class="data row0 col6" >8.3720</td>
#       <td id="T_caf07_row0_col7" class="data row0 col7" >0.0939</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LassoLars(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_1951d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1951d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1951d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1951d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1951d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1951d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1951d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1951d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1951d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1951d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1951d_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_1951d_row0_col1" class="data row0 col1" >2.7042</td>
#       <td id="T_1951d_row0_col2" class="data row0 col2" >28.6096</td>
#       <td id="T_1951d_row0_col3" class="data row0 col3" >5.3488</td>
#       <td id="T_1951d_row0_col4" class="data row0 col4" >0.1012</td>
#       <td id="T_1951d_row0_col5" class="data row0 col5" >0.8295</td>
#       <td id="T_1951d_row0_col6" class="data row0 col6" >6.9795</td>
#       <td id="T_1951d_row0_col7" class="data row0 col7" >0.6386</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model KNeighborsRegressor(n_jobs=-1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_a22da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a22da_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a22da_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a22da_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a22da_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a22da_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a22da_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a22da_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a22da_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a22da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a22da_row0_col0" class="data row0 col0" >Lasso Regression</td>
#       <td id="T_a22da_row0_col1" class="data row0 col1" >2.4727</td>
#       <td id="T_a22da_row0_col2" class="data row0 col2" >14.4348</td>
#       <td id="T_a22da_row0_col3" class="data row0 col3" >3.7993</td>
#       <td id="T_a22da_row0_col4" class="data row0 col4" >0.5465</td>
#       <td id="T_a22da_row0_col5" class="data row0 col5" >0.8786</td>
#       <td id="T_a22da_row0_col6" class="data row0 col6" >8.3720</td>
#       <td id="T_a22da_row0_col7" class="data row0 col7" >0.0939</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Lasso(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_0a7da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a7da_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0a7da_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0a7da_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0a7da_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0a7da_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0a7da_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0a7da_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0a7da_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a7da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a7da_row0_col0" class="data row0 col0" >AdaBoost Regressor</td>
#       <td id="T_0a7da_row0_col1" class="data row0 col1" >3.0207</td>
#       <td id="T_0a7da_row0_col2" class="data row0 col2" >35.4451</td>
#       <td id="T_0a7da_row0_col3" class="data row0 col3" >5.9536</td>
#       <td id="T_0a7da_row0_col4" class="data row0 col4" >-0.1135</td>
#       <td id="T_0a7da_row0_col5" class="data row0 col5" >1.0905</td>
#       <td id="T_0a7da_row0_col6" class="data row0 col6" >8.3825</td>
#       <td id="T_0a7da_row0_col7" class="data row0 col7" >0.0059</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model AdaBoostRegressor(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_3ed1e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ed1e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3ed1e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3ed1e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3ed1e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3ed1e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3ed1e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3ed1e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3ed1e_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ed1e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ed1e_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_3ed1e_row0_col1" class="data row0 col1" >2.2456</td>
#       <td id="T_3ed1e_row0_col2" class="data row0 col2" >10.4243</td>
#       <td id="T_3ed1e_row0_col3" class="data row0 col3" >3.2287</td>
#       <td id="T_3ed1e_row0_col4" class="data row0 col4" >0.6725</td>
#       <td id="T_3ed1e_row0_col5" class="data row0 col5" >0.8706</td>
#       <td id="T_3ed1e_row0_col6" class="data row0 col6" >8.2260</td>
#       <td id="T_3ed1e_row0_col7" class="data row0 col7" >0.0939</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ElasticNet(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_16fdb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16fdb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_16fdb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_16fdb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_16fdb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_16fdb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_16fdb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_16fdb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_16fdb_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16fdb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16fdb_row0_col0" class="data row0 col0" >Elastic Net</td>
#       <td id="T_16fdb_row0_col1" class="data row0 col1" >3.0029</td>
#       <td id="T_16fdb_row0_col2" class="data row0 col2" >33.0586</td>
#       <td id="T_16fdb_row0_col3" class="data row0 col3" >5.7497</td>
#       <td id="T_16fdb_row0_col4" class="data row0 col4" >-0.0385</td>
#       <td id="T_16fdb_row0_col5" class="data row0 col5" >0.9772</td>
#       <td id="T_16fdb_row0_col6" class="data row0 col6" >8.9067</td>
#       <td id="T_16fdb_row0_col7" class="data row0 col7" >-0.1849</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model ElasticNet(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_62c17">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62c17_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_62c17_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_62c17_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_62c17_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_62c17_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_62c17_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_62c17_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_62c17_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62c17_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62c17_row0_col0" class="data row0 col0" >Passive Aggressive Regressor</td>
#       <td id="T_62c17_row0_col1" class="data row0 col1" >2.2102</td>
#       <td id="T_62c17_row0_col2" class="data row0 col2" >9.7371</td>
#       <td id="T_62c17_row0_col3" class="data row0 col3" >3.1204</td>
#       <td id="T_62c17_row0_col4" class="data row0 col4" >0.6941</td>
#       <td id="T_62c17_row0_col5" class="data row0 col5" >0.7797</td>
#       <td id="T_62c17_row0_col6" class="data row0 col6" >9.0094</td>
#       <td id="T_62c17_row0_col7" class="data row0 col7" >0.1233</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model PassiveAggressiveRegressor(random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_42b12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42b12_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_42b12_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_42b12_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_42b12_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_42b12_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_42b12_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_42b12_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_42b12_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42b12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42b12_row0_col0" class="data row0 col0" >Decision Tree Regressor</td>
#       <td id="T_42b12_row0_col1" class="data row0 col1" >3.0753</td>
#       <td id="T_42b12_row0_col2" class="data row0 col2" >36.9154</td>
#       <td id="T_42b12_row0_col3" class="data row0 col3" >6.0758</td>
#       <td id="T_42b12_row0_col4" class="data row0 col4" >-0.1597</td>
#       <td id="T_42b12_row0_col5" class="data row0 col5" >1.1608</td>
#       <td id="T_42b12_row0_col6" class="data row0 col6" >8.4957</td>
#       <td id="T_42b12_row0_col7" class="data row0 col7" >0.0898</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DecisionTreeRegressor(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_1cc29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1cc29_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1cc29_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1cc29_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1cc29_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1cc29_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1cc29_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1cc29_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1cc29_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cc29_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1cc29_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_1cc29_row0_col1" class="data row0 col1" >2.0843</td>
#       <td id="T_1cc29_row0_col2" class="data row0 col2" >9.9657</td>
#       <td id="T_1cc29_row0_col3" class="data row0 col3" >3.1569</td>
#       <td id="T_1cc29_row0_col4" class="data row0 col4" >0.6869</td>
#       <td id="T_1cc29_row0_col5" class="data row0 col5" >0.7405</td>
#       <td id="T_1cc29_row0_col6" class="data row0 col6" >6.8728</td>
#       <td id="T_1cc29_row0_col7" class="data row0 col7" >0.1908</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model BayesianRidge(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_9c6e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c6e9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9c6e9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9c6e9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9c6e9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9c6e9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9c6e9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9c6e9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_9c6e9_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c6e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c6e9_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_9c6e9_row0_col1" class="data row0 col1" >2.8952</td>
#       <td id="T_9c6e9_row0_col2" class="data row0 col2" >35.3754</td>
#       <td id="T_9c6e9_row0_col3" class="data row0 col3" >5.9477</td>
#       <td id="T_9c6e9_row0_col4" class="data row0 col4" >-0.1113</td>
#       <td id="T_9c6e9_row0_col5" class="data row0 col5" >1.0775</td>
#       <td id="T_9c6e9_row0_col6" class="data row0 col6" >7.5003</td>
#       <td id="T_9c6e9_row0_col7" class="data row0 col7" >-0.1673</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model HuberRegressor(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_d8978">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8978_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d8978_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d8978_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d8978_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d8978_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d8978_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d8978_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d8978_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8978_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8978_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d8978_row0_col1" class="data row0 col1" >3.0157</td>
#       <td id="T_d8978_row0_col2" class="data row0 col2" >33.1268</td>
#       <td id="T_d8978_row0_col3" class="data row0 col3" >5.7556</td>
#       <td id="T_d8978_row0_col4" class="data row0 col4" >-0.0407</td>
#       <td id="T_d8978_row0_col5" class="data row0 col5" >0.9749</td>
#       <td id="T_d8978_row0_col6" class="data row0 col6" >8.5710</td>
#       <td id="T_d8978_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LGBMRegressor(n_jobs=-1, random_state=2): prediction_label
# <style type="text/css">
# </style>
# <table id="T_4646d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4646d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4646d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4646d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4646d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4646d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4646d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4646d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4646d_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4646d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4646d_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_4646d_row0_col1" class="data row0 col1" >2.8924</td>
#       <td id="T_4646d_row0_col2" class="data row0 col2" >35.0560</td>
#       <td id="T_4646d_row0_col3" class="data row0 col3" >5.9208</td>
#       <td id="T_4646d_row0_col4" class="data row0 col4" >-0.1013</td>
#       <td id="T_4646d_row0_col5" class="data row0 col5" >1.0463</td>
#       <td id="T_4646d_row0_col6" class="data row0 col6" >7.6822</td>
#       <td id="T_4646d_row0_col7" class="data row0 col7" >-0.2260</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Ridge(random_state=1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_8b28b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b28b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8b28b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8b28b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8b28b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8b28b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8b28b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8b28b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_8b28b_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b28b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b28b_row0_col0" class="data row0 col0" >Dummy Regressor</td>
#       <td id="T_8b28b_row0_col1" class="data row0 col1" >3.0157</td>
#       <td id="T_8b28b_row0_col2" class="data row0 col2" >33.1268</td>
#       <td id="T_8b28b_row0_col3" class="data row0 col3" >5.7556</td>
#       <td id="T_8b28b_row0_col4" class="data row0 col4" >-0.0407</td>
#       <td id="T_8b28b_row0_col5" class="data row0 col5" >0.9749</td>
#       <td id="T_8b28b_row0_col6" class="data row0 col6" >8.5710</td>
#       <td id="T_8b28b_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model DummyRegressor(): prediction_label
# <style type="text/css">
# </style>
# <table id="T_a77ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a77ae_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a77ae_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a77ae_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a77ae_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a77ae_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a77ae_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a77ae_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a77ae_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a77ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a77ae_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_a77ae_row0_col1" class="data row0 col1" >2.8724</td>
#       <td id="T_a77ae_row0_col2" class="data row0 col2" >35.0366</td>
#       <td id="T_a77ae_row0_col3" class="data row0 col3" >5.9192</td>
#       <td id="T_a77ae_row0_col4" class="data row0 col4" >-0.1007</td>
#       <td id="T_a77ae_row0_col5" class="data row0 col5" >1.0431</td>
#       <td id="T_a77ae_row0_col6" class="data row0 col6" >7.5739</td>
#       <td id="T_a77ae_row0_col7" class="data row0 col7" >-0.2553</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model LinearRegression(n_jobs=-1): prediction_label
# <style type="text/css">
# </style>
# <table id="T_0d193">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d193_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0d193_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0d193_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0d193_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0d193_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0d193_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0d193_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0d193_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d193_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d193_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_0d193_row0_col1" class="data row0 col1" >1.8958</td>
#       <td id="T_0d193_row0_col2" class="data row0 col2" >7.7968</td>
#       <td id="T_0d193_row0_col3" class="data row0 col3" >2.7923</td>
#       <td id="T_0d193_row0_col4" class="data row0 col4" >0.7551</td>
#       <td id="T_0d193_row0_col5" class="data row0 col5" >0.6065</td>
#       <td id="T_0d193_row0_col6" class="data row0 col6" >6.0743</td>
#       <td id="T_0d193_row0_col7" class="data row0 col7" >0.2700</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for model Ridge(random_state=2): prediction_label
# Spearman Correlation between Original Target and Derived FC for DummyRegressor() and OrthogonalMatchingPursuit(): 0.0746905827751051
# Spearman Correlation between Original Target and Derived FC for AdaBoostRegressor(random_state=1) and ElasticNet(random_state=2): 0.010989010989010988
# Spearman Correlation between Original Target and Derived FC for Ridge(random_state=1) and DummyRegressor(): -0.1043956043956044
# Spearman Correlation between Original Target and Derived FC for KNeighborsRegressor(n_jobs=-1) and Lasso(random_state=2): -0.1758241758241758
# Spearman Correlation between Original Target and Derived FC for LinearRegression(n_jobs=-1) and Ridge(random_state=2): -0.23626373626373626
# Spearman Correlation between Original Target and Derived FC for ElasticNet(random_state=1) and PassiveAggressiveRegressor(random_state=2): -0.2582417582417582
# Spearman Correlation between Original Target and Derived FC for HuberRegressor() and LGBMRegressor(n_jobs=-1, random_state=2): -0.2747252747252747
# Spearman Correlation between Original Target and Derived FC for LGBMRegressor(n_jobs=-1, random_state=1) and LassoLars(random_state=2): -0.2967032967032967
# Spearman Correlation between Original Target and Derived FC for Lasso(random_state=1) and GradientBoostingRegressor(random_state=2): -0.30769230769230765
# Spearman Correlation between Original Target and Derived FC for RandomForestRegressor(n_jobs=-1, random_state=1) and KNeighborsRegressor(n_jobs=-1): -0.3736263736263736
# Spearman Correlation between Original Target and Derived FC for GradientBoostingRegressor(random_state=1) and RandomForestRegressor(n_jobs=-1, random_state=2): -0.4340659340659341
# Spearman Correlation between Original Target and Derived FC for ExtraTreesRegressor(n_jobs=-1, random_state=1) and DecisionTreeRegressor(random_state=2): -0.46153846153846156
# Spearman Correlation between Original Target and Derived FC for DecisionTreeRegressor(random_state=1) and BayesianRidge(): -0.4725274725274725
# Spearman Correlation between Original Target and Derived FC for OrthogonalMatchingPursuit() and AdaBoostRegressor(random_state=2): -0.47802197802197804
# Spearman Correlation between Original Target and Derived FC for LassoLars(random_state=1) and ExtraTreesRegressor(n_jobs=-1, random_state=2): -0.5879120879120878

# %%
# Calculate Spearman correlation for each pair of top models
spearman_results = []
for model_Th1, model_Th2 in zip(top_models_Th1, top_models_Th2):
    predictions_Th1 = predict_model(model_Th1)  # Predictions for 'day_30_Th1_PT'
    predictions_Th2 = predict_model(model_Th2)  # Predictions for 'day_30_Th2_PT'
    
    # Reset index and ensure subject_id is included for alignment
    predictions_Th1 = predictions_Th1.reset_index(drop=True)
    predictions_Th2 = predictions_Th2.reset_index(drop=True)
    
    # Identify the prediction column
    pred_Th1 = 'Label' if 'Label' in predictions_Th1.columns else predictions_Th1.select_dtypes(include=np.number).columns[-1]
    pred_Th2 = 'Label' if 'Label' in predictions_Th2.columns else predictions_Th2.select_dtypes(include=np.number).columns[-1]
    
    # Print statements to verify selected columns for debugging
    print(f"Predictions column for Th1: {pred_Th1}, Predictions column for Th2: {pred_Th2}")
    
    # Merge predictions on index for alignment
    merged_predictions = pd.merge(
        predictions_Th1[[pred_Th1]], 
        predictions_Th2[[pred_Th2]], 
        left_index=True, 
        right_index=True,
        suffixes=('_Th1', '_Th2')
    )
    
    # Calculate the derived 'FC_day_30_Th1/Th2' as the ratio of predictions
    derived_FC = merged_predictions[pred_Th1] / merged_predictions[pred_Th2]
    
    # Align with original target using index
    original_target = df[['FC_day_30_Th1/Th2']]
    
    # Calculate Spearman correlation
    spearman_corr = spearman_metric(original_target, derived_FC)
    spearman_results.append((model_Th1, model_Th2, spearman_corr))

# Sort and display models by Spearman correlation
sorted_spearman_results = sorted(spearman_results, key=lambda x: x[2], reverse=True)
for model_Th1, model_Th2, spearman_corr in sorted_spearman_results:
    print(f"Model Th1: {model_Th1}, Model Th2: {model_Th2}, Spearman Correlation: {spearman_corr}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_cee92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cee92_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cee92_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cee92_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cee92_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cee92_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cee92_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cee92_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cee92_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cee92_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cee92_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_cee92_row0_col1" class="data row0 col1" >3.0009</td>
#       <td id="T_cee92_row0_col2" class="data row0 col2" >35.3816</td>
#       <td id="T_cee92_row0_col3" class="data row0 col3" >5.9482</td>
#       <td id="T_cee92_row0_col4" class="data row0 col4" >-0.1115</td>
#       <td id="T_cee92_row0_col5" class="data row0 col5" >1.0788</td>
#       <td id="T_cee92_row0_col6" class="data row0 col6" >8.5902</td>
#       <td id="T_cee92_row0_col7" class="data row0 col7" >0.0675</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_42038">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42038_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_42038_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_42038_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_42038_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_42038_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_42038_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_42038_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_42038_level0_col7" class="col_heading level0 col7" >Spearman Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42038_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42038_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_42038_row0_col1" class="data row0 col1" >2.6516</td>
#       <td id="T_42038_row0_col2" class="data row0 col2" >30.3164</td>
#       <td id="T_42038_row0_col3" class="data row0 col3" >5.5060</td>
#       <td id="T_42038_row0_col4" class="data row0 col4" >0.0476</td>
#       <td id="T_42038_row0_col5" class="data row0 col5" >0.8929</td>
#       <td id="T_42038_row0_col6" class="data row0 col6" >4.7857</td>
#       <td id="T_42038_row0_col7" class="data row0 col7" >0.2997</td>
#     </tr>
#   </tbody>
# </table>
# Predictions column for Th1: prediction_label, Predictions column for Th2: prediction_label
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/py3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prediction_label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /home/jrollins/cmipb-challenge/task4-1_basemodels_11052024 copy.ipynb Cell 18 line 2
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> merged_predictions = pd.merge(
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>     predictions_Th1[[pred_Th1]],
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>     predictions_Th2[[pred_Th2]],
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     suffixes=('_Th1', '_Th2')
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> # Calculate the derived 'FC_day_30_Th1/Th2' as the ratio of predictions
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> derived_FC = merged_predictions[pred_Th1] / merged_predictions[pred_Th2]
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> # Align with original target using index
#      <a href='vscode-notebook-cell://ssh-remote%2Bmercury/home/jrollins/cmipb-challenge/task4-1_basemodels_11052024%20copy.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a> original_target = df[['FC_day_30_Th1/Th2']]
#
# File ~/miniforge3/envs/py3.10/lib/python3.10/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/miniforge3/envs/py3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'prediction_label'

# %%
predictions_Th1
# Out:
#     day_0_Th2_PHA  day_0_IL17A_PT biological_sex  day_0_Th2_PT  \
# 0        0.051724        2.271345         Female      6.465512
# 1        1.019108        0.215520         Female      0.127659
# 2        4.254780        1.916049           Male      1.000000
# 3        0.038217        0.002116         Female      0.127659
# 4        2.133760        0.104762         Female      0.127659
# 5        0.051724        0.007018         Female      0.103448
# 6        7.273890        1.592240         Female     32.319077
# 7        7.698270        2.837427           Male      1.965515
# 8        0.038217        0.360141         Female      0.127659
# 9        1.637929        0.007018           Male      0.103448
# 10       0.482759        0.297076         Female      0.103448
# 11       1.000000        0.444445         Female      0.655174
# 12       0.038217        2.477954           Male      0.127659
#
#     day_0_IL17A_PHA  day_0_Th1_PHA  day_0_Th1_PT  age infancy_vac  \
# 0          1.000000       0.096430      1.452289   20          aP
# 1          0.610540       1.131890      0.520951   24          wP
# 2          2.855399       2.229580      4.074746   26          wP
# 3          0.025064       0.065490      0.006795   32          wP
# 4          0.804949       1.663089      1.255946   42          wP
# 5          0.003155       0.002782      0.009310   27          wP
# 6          1.000000       0.135347      0.003398   27          wP
# 7          1.995268       1.334260      1.775019   25          aP
# 8          0.001928       0.668365      0.231031   22          aP
# 9          0.353838       0.014372      0.009310   31          wP
# 10         1.183491       1.097357      1.849495   19          aP
# 11         0.662986       1.000000      0.408068   27          wP
# 12         0.001928       0.086229      0.118913   19          aP
#
#     day_30_Th2_PT  prediction_label
# 0        0.103448          1.257464
# 1        0.127659          1.408748
# 2        7.382984          3.349277
# 3        0.127659          1.740664
# 4        0.127659          1.734901
# 5        0.103448          1.908869
# 6       20.744637          0.192708
# 7        0.103448          1.200177
# 8        0.127659          1.555578
# 9        0.103448          0.798224
# 10       0.103448          1.572458
# 11       0.103448          0.400698
# 12       2.872334          0.892366

# %%
predictions_Th2
# Out:
#     day_0_Th2_PHA  day_0_IL17A_PT biological_sex  day_0_Th2_PT  \
# 0        0.051724        2.271345         Female      6.465512
# 1        1.019108        0.215520         Female      0.127659
# 2        4.254780        1.916049           Male      1.000000
# 3        0.038217        0.002116         Female      0.127659
# 4        2.133760        0.104762         Female      0.127659
# 5        0.051724        0.007018         Female      0.103448
# 6        7.273890        1.592240         Female     32.319077
# 7        7.698270        2.837427           Male      1.965515
# 8        0.038217        0.360141         Female      0.127659
# 9        1.637929        0.007018           Male      0.103448
# 10       0.482759        0.297076         Female      0.103448
# 11       1.000000        0.444445         Female      0.655174
# 12       0.038217        2.477954           Male      0.127659
#
#     day_0_IL17A_PHA  day_0_Th1_PHA  day_0_Th1_PT  age infancy_vac  \
# 0          1.000000       0.096430      1.452289   20          aP
# 1          0.610540       1.131890      0.520951   24          wP
# 2          2.855399       2.229580      4.074746   26          wP
# 3          0.025064       0.065490      0.006795   32          wP
# 4          0.804949       1.663089      1.255946   42          wP
# 5          0.003155       0.002782      0.009310   27          wP
# 6          1.000000       0.135347      0.003398   27          wP
# 7          1.995268       1.334260      1.775019   25          aP
# 8          0.001928       0.668365      0.231031   22          aP
# 9          0.353838       0.014372      0.009310   31          wP
# 10         1.183491       1.097357      1.849495   19          aP
# 11         0.662986       1.000000      0.408068   27          wP
# 12         0.001928       0.086229      0.118913   19          aP
#
#     day_30_Th2_PT  prediction_label
# 0        0.103448          0.927058
# 1        0.127659          0.139256
# 2        7.382984          0.519005
# 3        0.127659          1.233380
# 4        0.127659          3.230664
# 5        0.103448          0.176228
# 6       20.744637          2.643725
# 7        0.103448          0.443143
# 8        0.127659          0.256864
# 9        0.103448          1.233380
# 10       0.103448          0.156864
# 11       0.103448          0.317979
# 12       2.872334          0.349885
